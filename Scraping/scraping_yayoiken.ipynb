# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import re
from urllib.parse import urljoin
import json

class YayoikenScraper:
    def __init__(self):
        self.base_url = "https://www.yayoiken.com"
        self.menu_list_url = "https://www.yayoiken.com/menu_list/index/13"
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        })
        self.menu_data = []
    
    def get_all_menu_categories(self):
        """メニューページから全カテゴリを取得"""
        try:
            print(f"Fetching menu categories from: {self.menu_list_url}")
            response = self.session.get(self.menu_list_url, timeout=10)
            response.raise_for_status()
            
            soup = BeautifulSoup(response.content, 'html.parser')
            categories = {}
            
            # パターン1: タブメニューを探す
            category_tabs = soup.find_all('a', class_='c-tab-menu__item-inr')
            for tab in category_tabs:
                category_name = tab.text.strip()
                category_url = tab.get('href')
                if category_url:
                    full_url = urljoin(self.base_url, category_url)
                    categories[category_name] = full_url
                    print(f"Found category: {category_name} -> {full_url}")
            
            return categories
            
        except Exception as e:
            print(f"Error fetching categories: {e}")
            import traceback
            traceback.print_exc()
            return {"定食メニュー": self.menu_list_url}
    
    def get_menu_items_from_category(self, category_url):
        """特定のカテゴリからメニューアイテムを取得"""
        try:
            print(f"Fetching menu items from: {category_url}")
            response = self.session.get(category_url, timeout=10)
            response.raise_for_status()
            
            soup = BeautifulSoup(response.content, 'html.parser')
            menu_items = []
            
            # メニューアイテムを取得
            items = soup.find_all('li', class_='c-content-index-menu-list__item')
            
            for item in items:
                try:
                    # リンク要素を取得
                    link = item.find('a', class_='c-content-index-menu-list__item-inr')
                    if not link:
                        continue
                    
                    url = link.get('href')
                    if not url:
                        continue
                    
                    # 商品名を取得
                    title_elem = item.find('p', class_='c-content-index-menu-list__title')
                    product_name = title_elem.text.strip() if title_elem else "N/A"
                    
                    # 価格を取得
                    price_elem = item.find('span', class_='c-content-index-menu-list__price')
                    price = price_elem.text.strip() if price_elem else "N/A"
                    
                    # 価格から「円」、「,」、「"」を削除
                    if price and price != "N/A":
                        price = re.sub(r'[円,"\'"\s　]', '', price)

                    # 画像URLを取得
                    img_elem = item.find('img')
                    picture = img_elem.get('src') if img_elem else "N/A"
                    
                    menu_item = {
                        'product_name': product_name,
                        'price': price,
                        'picture': picture,
                        'url': urljoin(self.base_url, url) if url else "N/A"
                    }
                    
                    menu_items.append(menu_item)
                    print(f"Found: {product_name} - {price}")
                    
                except Exception as e:
                    print(f"Error parsing menu item: {e}")
                    continue
            
            return menu_items
            
        except Exception as e:
            print(f"Error fetching menu items from {category_url}: {e}")
            return []
    
    def get_nutrition_data(self, url):
        """個別商品ページから栄養成分を取得"""
        try:
            print(f"  -> Fetching nutrition data from: {url}")
            response = self.session.get(url, timeout=10)
            response.raise_for_status()
            
            soup = BeautifulSoup(response.content, 'html.parser')
            
            nutrition_data = {
                'calorie': 'N/A',
                'protein': 'N/A',
                'fat': 'N/A',
                'carbohydrate': 'N/A',
                'sugar': 'N/A',
                'fiber': 'N/A',
                'salt': 'N/A'
            }
            
            # パターン1: 新しい構造 - c-table-col9クラス付きのdl要素
            nutrition_table = soup.find('div', class_='c-table__type01')
            if nutrition_table:
                # c-table-col9クラスを持つdl要素を探す
                table_items = nutrition_table.find_all('dl', class_=['c-table__item', 'c-table__item c-table-col9'])
                
                # より広範囲に検索
                if not table_items:
                    table_items = nutrition_table.find_all('dl', class_=re.compile(r'c-table__item'))
                
                print(f"  -> Found {len(table_items)} table items")
                
                for item in table_items:
                    head = item.find('dt', class_='c-table__head')
                    body = item.find('dd', class_='c-table__body')
                    
                    if head and body:
                        head_text = head.get_text(strip=True)
                        body_text = body.get_text(strip=True)
                        
                        print(f"    -> Processing: {head_text} = {body_text}")
                        
                        # 各栄養成分をマッピング（文字の違いも考慮）
                        if '熱量' in head_text:
                            nutrition_data['calorie'] = body_text
                        elif '蛋⽩質' in head_text or 'たんぱく質' in head_text or 'タンパク質' in head_text or '蛋白質' in head_text:
                            nutrition_data['protein'] = body_text
                        elif '脂質' in head_text:
                            nutrition_data['fat'] = body_text
                        elif '炭⽔化物' in head_text or '炭水化物' in head_text:
                            nutrition_data['carbohydrate'] = body_text
                        elif '糖質' in head_text:
                            nutrition_data['sugar'] = body_text
                        elif '食物繊維' in head_text:
                            nutrition_data['fiber'] = body_text
                        elif '⾷塩相当量' in head_text or '食塩相当量' in head_text:
                            nutrition_data['salt'] = body_text
            
            # パターン2: テーブルが見つからない場合、より広範囲に検索
            if nutrition_data['calorie'] == 'N/A':
                print("  -> Trying alternative search methods...")
                
                # すべてのテーブル関連要素を検索
                all_tables = soup.find_all(['table', 'div'], class_=re.compile(r'table'))
                for table in all_tables:
                    table_text = table.get_text()
                    if '熱量' in table_text and '蛋' in table_text:
                        print(f"  -> Found nutrition table: {table.get('class')}")
                        
                        # この要素内からdl要素を検索
                        items = table.find_all('dl')
                        for item in items:
                            head = item.find('dt')
                            body = item.find('dd')
                            if head and body:
                                head_text = head.get_text(strip=True)
                                body_text = body.get_text(strip=True)
                                
                                if '熱量' in head_text:
                                    nutrition_data['calorie'] = body_text
                                elif '蛋⽩質' in head_text or 'たんぱく質' in head_text or 'タンパク質' in head_text or '蛋白質' in head_text:
                                    nutrition_data['protein'] = body_text
                                elif '脂質' in head_text:
                                    nutrition_data['fat'] = body_text
                                elif '炭⽔化物' in head_text or '炭水化物' in head_text:
                                    nutrition_data['carbohydrate'] = body_text
                                elif '糖質' in head_text:
                                    nutrition_data['sugar'] = body_text
                                elif '食物繊維' in head_text:
                                    nutrition_data['fiber'] = body_text
                                elif '⾷塩相当量' in head_text or '食塩相当量' in head_text:
                                    nutrition_data['salt'] = body_text
                        break
            
            # パターン3: 正規表現による直接抽出
            if nutrition_data['calorie'] == 'N/A':
                print("  -> Trying regex extraction...")
                page_text = soup.get_text()
                
                # 各栄養成分を正規表現で抽出
                patterns = {
                    'calorie': r'熱量[^0-9]*?(\d+)',
                    'protein': r'(?:蛋⽩質|たんぱく質|タンパク質|蛋白質)[^0-9]*?([0-9]+\.?[0-9]*)',
                    'fat': r'脂質[^0-9]*?([0-9]+\.?[0-9]*)',
                    'carbohydrate': r'(?:炭⽔化物|炭水化物)[^0-9]*?([0-9]+\.?[0-9]*)',
                    'sugar': r'糖質[^0-9]*?([0-9]+\.?[0-9]*)',
                    'fiber': r'食物繊維[^0-9]*?([0-9]+\.?[0-9]*)',
                    'salt': r'(?:⾷塩相当量|食塩相当量)[^0-9]*?([0-9]+\.?[0-9]*)'
                }
                
                for key, pattern in patterns.items():
                    match = re.search(pattern, page_text)
                    if match:
                        nutrition_data[key] = match.group(1)
                        print(f"    -> Regex found {key}: {match.group(1)}")
            
            print(f"  -> Final nutrition data: {nutrition_data}")
            return nutrition_data
            
        except requests.exceptions.RequestException as e:
            print(f"  -> Request error for {url}: {e}")
            return {
                'calorie': 'Error',
                'protein': 'Error',
                'fat': 'Error',
                'carbohydrate': 'Error',
                'sugar': 'Error',
                'fiber': 'Error',
                'salt': 'Error'
            }
        except Exception as e:
            print(f"  -> Unexpected error for {url}: {e}")
            import traceback
            traceback.print_exc()
            return {
                'calorie': 'Error',
                'protein': 'Error',
                'fat': 'Error',
                'carbohydrate': 'Error',
                'sugar': 'Error',
                'fiber': 'Error',
                'salt': 'Error'
            }
    
    def scrape_all_menus(self):
        """全カテゴリのメニューをスクレイピング"""
        print("Starting comprehensive menu scraping...")
        
        # カテゴリを取得
        categories = self.get_all_menu_categories()
        
        if not categories:
            print("No categories found. Trying to scrape from main page...")
            categories = {"メインメニュー": self.menu_list_url}
        
        all_menu_data = []
        processed_urls = set()  # 重複チェック用
        
        for category_name, category_url in categories.items():
            print(f"\n{'='*60}")
            print(f"Processing Category: {category_name}")
            print(f"{'='*60}")
            
            # カテゴリからメニューアイテムを取得
            menu_items = self.get_menu_items_from_category(category_url)
            
            for i, item in enumerate(menu_items, 1):
                # 重複チェック - URLで判定
                if item['url'] in processed_urls:
                    print(f"  -> Skipping duplicate: {item['product_name']}")
                    continue
                
                processed_urls.add(item['url'])
                
                print(f"\n--- Processing {i}/{len(menu_items)}: {item['product_name']} ---")
                
                # 栄養成分データを取得
                nutrition_data = self.get_nutrition_data(item['url'])
                
                # 指定されたフィールドのみでデータを結合
                complete_data = {
                    'product_name': item['product_name'],
                    'price': item['price'],
                    'picture': item['picture'],
                    'calorie': nutrition_data['calorie'],
                    'protein': nutrition_data['protein'],
                    'fat': nutrition_data['fat'],
                    'carbohydrate': nutrition_data['carbohydrate'],
                    'sugar': nutrition_data['sugar'],
                    'fiber': nutrition_data['fiber'],
                    'salt': nutrition_data['salt'],
                    'url': item['url']
                }
                
                all_menu_data.append(complete_data)
                
                # レート制限対策で少し待機
                time.sleep(0.5)
        
        self.menu_data = all_menu_data
        return all_menu_data
       
    def scrape_from_html(self, html_content):
        """提供されたHTMLからスクレイピングを実行"""
        print("Parsing menu list HTML...")
        menu_items = self.parse_menu_list_html(html_content)
        print(f"Found {len(menu_items)} menu items")
        
        all_data = []
        
        for i, item in enumerate(menu_items, 1):
            print(f"\n--- Processing {i}/{len(menu_items)}: {item['product_name']} ---")
            
            # 栄養成分データを取得
            nutrition_data = self.get_nutrition_data(item['url'])
            
            # 指定されたフィールドのみでデータを結合
            complete_data = {
                'product_name': item['product_name'],
                'price': item['price'],
                'picture': item['picture'],
                'calorie': nutrition_data['calorie'],
                'protein': nutrition_data['protein'],
                'fat': nutrition_data['fat'],
                'carbohydrate': nutrition_data['carbohydrate'],
                'sugar': nutrition_data['sugar'],
                'fiber': nutrition_data['fiber'],
                'salt': nutrition_data['salt'],
                'url': item['url']
            }
            
            all_data.append(complete_data)
            
            # レート制限対策で少し待機
            time.sleep(1)

        self.menu_data = all_data
        return all_data
    
    def parse_menu_list_html(self, html_content):
        """提供されたHTMLから商品URLを抽出"""
        soup = BeautifulSoup(html_content, 'html.parser')
        menu_items = []
        
        # li要素で商品情報を取得
        items = soup.find_all('li', class_='c-content-index-menu-list__item')
        
        for item in items:
            try:
                # リンク要素を取得
                link = item.find('a', class_='c-content-index-menu-list__item-inr')
                if not link:
                    continue
                
                url = link.get('href')
                if not url:
                    continue
                
                # 商品名を取得
                title_elem = item.find('p', class_='c-content-index-menu-list__title')
                product_name = title_elem.text.strip() if title_elem else "N/A"
                
                # 価格を取得
                price_elem = item.find('span', class_='c-content-index-menu-list__price')
                price = price_elem.text.strip() if price_elem else "N/A"
                
                # 価格から「円」、「,」、「"」を削除
                if price and price != "N/A":
                    price = re.sub(r'[円,"\'"\s　]', '', price)
                
                # 画像URLを取得
                img_elem = item.find('img')
                picture = img_elem.get('src') if img_elem else "N/A"
                
                menu_items.append({
                    'product_name': product_name,
                    'price': price,
                    'picture': picture,
                    'url': urljoin(self.base_url, url) if url else "N/A"
                })
                
                print(f"Found: {product_name} - {price}")
                
            except Exception as e:
                print(f"Error parsing menu item: {e}")
                continue
        
        return menu_items
    
    def save_to_csv(self, filename='yayoiken_menu_data.csv'):
        """データをCSVファイルに保存"""
        if not self.menu_data:
            print("No data to save")
            return
        
        fieldnames = ['product_name', 'price', 'picture', 'calorie', 'protein', 'fat', 'carbohydrate', 'sugar', 'fiber', 'salt', 'url']
        
        with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(self.menu_data)
        
        print(f"Data saved to {filename}")
    
    def save_to_json(self, filename='yayoiken_menu_data.json'):
        """データをJSONファイルに保存"""
        if not self.menu_data:
            print("No data to save")
            return
        
        with open(filename, 'w', encoding='utf-8') as jsonfile:
            json.dump(self.menu_data, jsonfile, ensure_ascii=False, indent=2)
        
        print(f"Data saved to {filename}")
    
    def display_data(self):
        """取得したデータを表示"""
        if not self.menu_data:
            print("No data to display")
            return
        
        print("\n" + "="*100)
        print("SCRAPED MENU DATA")
        print("="*100)
        
        for i, item in enumerate(self.menu_data, 1):
            print(f"\n【{i}】 {item['product_name']}")
            print(f"価格: {item['price']}")
            print(f"カロリー: {item['calorie']} kcal")
            print(f"タンパク質: {item['protein']} g")
            print(f"脂質: {item['fat']} g")
            print(f"炭水化物: {item['carbohydrate']} g")
            print(f"糖質: {item['sugar']} g")
            print(f"食物繊維: {item['fiber']} g")
            print(f"食塩相当量: {item['salt']} g")
            print(f"画像: {item['picture']}")
            print(f"URL: {item['url']}")
            print("-" * 80)
        
        print(f"\n総メニュー数: {len(self.menu_data)}件")

def main():
    # スクレイパーのインスタンスを作成
    scraper = YayoikenScraper()
    
    print("やよい軒全メニュー情報スクレイピングを開始...")
    print("取得する情報: product_name, price, picture, calorie, protein, fat, carbohydrate, sugar, fiber, salt, url")
    print("価格: 「円」「,」「\"」を削除して数字のみ保存")
    print("重複: URLベースで重複を自動除去")
    
    try:
        # 全カテゴリのメニューデータを取得
        data = scraper.scrape_all_menus()
        
        if not data:
            print("No data was scraped. Please check the website structure.")
            return
        
        # 結果を表示
        scraper.display_data()
        
        # CSVファイルに保存
        scraper.save_to_csv()
        
        # JSONファイルに保存
        scraper.save_to_json()
        
        print(f"\nスクレイピング完了！ {len(data)} 件のメニューデータを取得しました。")
        print("重複データは自動的に除去されました。")
        print("価格データから「円」「,」「\"」が削除されました。")
        
    except Exception as e:
        print(f"エラーが発生しました: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# やよい軒全メニュー情報スクレイピングを開始...
# 取得する情報: product_name, price, picture, calorie, protein, fat, carbohydrate, sugar, fiber, salt, url
# 価格: 「円」「,」「"」を削除して数字のみ保存
# 重複: URLベースで重複を自動除去
# Starting comprehensive menu scraping...
# Fetching menu categories from: https://www.yayoiken.com/menu_list/index/13
# No categories found. Trying to scrape from main page...
#
# ============================================================
# Processing Category: メインメニュー
# ============================================================
# Fetching menu items from: https://www.yayoiken.com/menu_list/index/13
# Found: さんまの塩焼定食 - 990
# Found: 【揚げ出し茄子小鉢付】さんまの塩焼定食 - 1190
# Found: 【ミニすき焼き小鉢付】さんまの塩焼定食 - 1310
# Found: ～徳島県産阿波尾鶏使用～地鶏まぶし定食 - 1090
# Found: ～徳島県産阿波尾鶏使用～【お肉2倍】地鶏まぶし定食 - 1690
# Found: 牛バターちゃんぽん焼定食 - 1150
# Found: 【お肉２倍】牛バターちゃんぽん焼定食 - 1550
# Found: しょうが焼定食 - 860
# Found: 肉野菜炒め定食 - 950
# Found: チキン南蛮定食 - 990
# Found: から揚げ定食 - 890
# Found: 特から揚げ定食 - 1080
# Found: から揚げ&コロッケ定食 - 890
# Found: 味噌かつ煮定食 - 990
# Found: コク旨ちゃんぽんとから揚げの定食 - 1100
# Found: 大豆ミートのしょうが焼定食 - 830
# Found: 大豆ミートの野菜炒め定食 - 920
# Found: 大豆ミートのなす味噌と焼魚の定食 - 1120
# Found: ブラックアンガスビーフのカットステーキ定食【和風ソース】 - 1430
# Found: ブラックアンガスビーフのカットステーキ定食【おろしぽん酢】 - 1430
# Found: ブラックアンガスビーフの特カットステーキ定食【和風ソース】 - 2080
# Found: ブラックアンガスビーフの特カットステーキ定食【おろしぽん酢】 - 2080
# Found: ブラックアンガスビーフのカットステーキとエビフライの定食【和風ソース】 - 1720
# Found: ブラックアンガスビーフのカットステーキとエビフライの定食【おろしぽん酢】 - 1720
# Found: 和風おろしハンバーグ定食 - 980
# Found: デミハンバーグ定食 - 1030
# Found: 4種のチーズハンバーグ定食 - 1080
# Found: ミックスとじ定食 - 990
# Found: チキン南蛮としょうが焼の人気コンビ定食 - 1240
# Found: ハンバーグとエビフライとから揚げの人気トリオ定食 - 1240
# Found: チキン南蛮とエビフライの定食 - 1220
# Found: ロースとんかつとエビフライの定食 - 1100
# Found: サバの塩焼定食 - 890
# Found: サバの味噌煮定食 - 890
# Found: しまほっけ定食 - 1110
# Found: なす味噌と焼魚の定食 - 1150
# Found: やよい御膳 - 1100
# Found: お子様ランチ - 470
# Found: お子様カレー(低アレルゲン) - 470
# Found: 地鶏親子丼～阿波尾鶏～ - 880
# Found: かつ丼 - 890
# Found: 鉄火丼 - 960
# Found: コク旨ちゃんぽん（単品） - 830
# Found: 納豆朝食 - 410
# Found: しらすおろし朝食 - 430
# Found: ミニすき焼き朝食 - 510
# Found: エッグ&ウインナー朝食 - 520
# Found: しゃけの塩焼朝食 - 550
# Found: サバの塩焼朝食 - 550
# Found: タルタルソース - 50
# Found: 生たまご - 70
# Found: とろろ - 180
# Found: 野菜サラダ - 100
# Found: 納豆 - 110
# Found: 冷奴 - 110
# Found: 【だし茶漬用】ほぐし鮭小鉢 - 160
# Found: 【だし茶漬用】ミニサバ小鉢 - 160
# Found: 蒸し鶏と海藻のぽん酢和え - 130
# Found: 玉子焼き - 290
# Found: 天ぷら小鉢 - 330
# Found: 牛肉のすき焼き小鉢 - 330
# Found: フライドポテト - 260
# Found: フライドポテト&ウインナー - 290
# Found: コロッケ - 170
# Found: イカのから揚げ - 260
# Found: ミニから揚げ - 280
# Found: から揚げ（5個） - 590
# Found: みそ汁 - 100
# Found: 豚汁 - 290
# Found: 貝汁 - 290
# Found: 生ビール - 550
# Found: メガ生ビール - 890
# Found: ハイボール - 430
# Found: メガハイボール - 620
# Found: レモンサワー - 430
# Found: [テイクアウト]～徳島県産阿波尾鶏使用～地鶏まぶし　だし付 - 1020
# Found: ［テイクアウト］肉野菜炒め - 950
# Found: ［テイクアウト］しょうが焼 - 860
# Found: ［テイクアウト］から揚げ - 890
# Found: ［テイクアウト］特から揚げ - 1080
# Found: ［テイクアウト］から揚げ＆コロッケ - 890
# Found: ［テイクアウト］チキン南蛮 - 990
# Found: ［テイクアウト］和風おろしハンバーグ - 980
# Found: ［テイクアウト］サバの塩焼 - 890
# Found: ［テイクアウト］なす味噌と焼魚 - 1150
# Found: ［テイクアウト］ブラックアンガスビーフのカットステーキ - 1430
# Found: ［テイクアウト］チキン南蛮としょうが焼の人気コンビ - 1240
# Found: ［テイクアウト］ハンバーグとエビフライとから揚げの人気トリオ - 1240
# Found: ［テイクアウト］お子様ランチ - 410
# Found: ［テイクアウト］肉野菜炒め　おかずのみ - 800
# Found: ［テイクアウト］しょうが焼　おかずのみ - 710
# Found: ［テイクアウト］から揚げ　おかずのみ - 740
# Found: ［テイクアウト］特から揚げ　おかずのみ - 930
# Found: ［テイクアウト］から揚げ＆コロッケ　おかずのみ - 740
# Found: ［テイクアウト］チキン南蛮　おかずのみ - 840
# Found: ［テイクアウト］和風おろしハンバーグ　おかずのみ - 830
# Found: ［テイクアウト］サバの塩焼　おかずのみ - 740
# Found: ［テイクアウト］なす味噌と焼魚　おかずのみ - 1000
# Found: ［テイクアウト］ブラックアンガスビーフのカットステーキ　おかずのみ - 1280
# Found: ［テイクアウト］チキン南蛮としょうが焼の人気コンビ　おかずのみ - 1090
# Found: ［テイクアウト］ハンバーグとエビフライとから揚げの人気トリオ　おかずのみ - 1090
# Found: ［テイクアウト］地鶏親子丼～阿波尾鶏～ - 780
# Found: ［テイクアウト］かつ丼 - 790
# Found: ［テイクアウト］みそ汁 - 100
# Found: ［テイクアウト］から揚げ（5個） - 590
#
# --- Processing 1/105: さんまの塩焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/508
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 501
#     -> Processing: 蛋⽩質（g） = 35.4
#     -> Processing: 脂質（g） = 13.4
#     -> Processing: 炭⽔化物（g） = 63.9
#     -> Processing: 糖質（g） = 56.7
#     -> Processing: 食物繊維（g） = 7.2
#     -> Processing: ⾷塩相当量（g） = 3.5
#     -> Processing: カリウム（mg） = 599
#     -> Processing: リン（mg） = 399
#   -> Final nutrition data: {'calorie': '501', 'protein': '35.4', 'fat': '13.4', 'carbohydrate': '63.9', 'sugar': '56.7', 'fiber': '7.2', 'salt': '3.5'}
#
# --- Processing 2/105: 【揚げ出し茄子小鉢付】さんまの塩焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/509
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 649
#     -> Processing: 蛋⽩質（g） = 37.1
#     -> Processing: 脂質（g） = 24.0
#     -> Processing: 炭⽔化物（g） = 76.0
#     -> Processing: 糖質（g） = 67.4
#     -> Processing: 食物繊維（g） = 8.6
#     -> Processing: ⾷塩相当量（g） = 4.6
#     -> Processing: カリウム（mg） = 706
#     -> Processing: リン（mg） = 443
#   -> Final nutrition data: {'calorie': '649', 'protein': '37.1', 'fat': '24.0', 'carbohydrate': '76.0', 'sugar': '67.4', 'fiber': '8.6', 'salt': '4.6'}
#
# --- Processing 3/105: 【ミニすき焼き小鉢付】さんまの塩焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/510
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 682
#     -> Processing: 蛋⽩質（g） = 41.6
#     -> Processing: 脂質（g） = 26.6
#     -> Processing: 炭⽔化物（g） = 74.4
#     -> Processing: 糖質（g） = 65.1
#     -> Processing: 食物繊維（g） = 9.3
#     -> Processing: ⾷塩相当量（g） = 4.8
#     -> Processing: カリウム（mg） = 751
#     -> Processing: リン（mg） = 475
#   -> Final nutrition data: {'calorie': '682', 'protein': '41.6', 'fat': '26.6', 'carbohydrate': '74.4', 'sugar': '65.1', 'fiber': '9.3', 'salt': '4.8'}
#
# --- Processing 4/105: ～徳島県産阿波尾鶏使用～地鶏まぶし定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/511
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 672
#     -> Processing: 蛋⽩質（g） = 38.7
#     -> Processing: 脂質（g） = 17.8
#     -> Processing: 炭⽔化物（g） = 93.5
#     -> Processing: 糖質（g） = 88.2
#     -> Processing: 食物繊維（g） = 5.3
#     -> Processing: ⾷塩相当量（g） = 4.0
#     -> Processing: カリウム（mg） = 563
#     -> Processing: リン（mg） = 416
#   -> Final nutrition data: {'calorie': '672', 'protein': '38.7', 'fat': '17.8', 'carbohydrate': '93.5', 'sugar': '88.2', 'fiber': '5.3', 'salt': '4.0'}
#
# --- Processing 5/105: ～徳島県産阿波尾鶏使用～【お肉2倍】地鶏まぶし定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/512
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 877
#     -> Processing: 蛋⽩質（g） = 65.5
#     -> Processing: 脂質（g） = 28.1
#     -> Processing: 炭⽔化物（g） = 94.7
#     -> Processing: 糖質（g） = 89.4
#     -> Processing: 食物繊維（g） = 5.3
#     -> Processing: ⾷塩相当量（g） = 5.0
#     -> Processing: カリウム（mg） = 943
#     -> Processing: リン（mg） = 646
#   -> Final nutrition data: {'calorie': '877', 'protein': '65.5', 'fat': '28.1', 'carbohydrate': '94.7', 'sugar': '89.4', 'fiber': '5.3', 'salt': '5.0'}
#
# --- Processing 6/105: 牛バターちゃんぽん焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/503
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1010
#     -> Processing: 蛋⽩質（g） = 32.3
#     -> Processing: 脂質（g） = 35.4
#     -> Processing: 炭⽔化物（g） = 144.2
#     -> Processing: 糖質（g） = 136.4
#     -> Processing: 食物繊維（g） = 7.8
#     -> Processing: ⾷塩相当量（g） = 6.2
#     -> Processing: カリウム（mg） = 520
#     -> Processing: リン（mg） = 280
#   -> Final nutrition data: {'calorie': '1010', 'protein': '32.3', 'fat': '35.4', 'carbohydrate': '144.2', 'sugar': '136.4', 'fiber': '7.8', 'salt': '6.2'}
#
# --- Processing 7/105: 【お肉２倍】牛バターちゃんぽん焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/504
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1263
#     -> Processing: 蛋⽩質（g） = 43.1
#     -> Processing: 脂質（g） = 56.6
#     -> Processing: 炭⽔化物（g） = 149.5
#     -> Processing: 糖質（g） = 140.9
#     -> Processing: 食物繊維（g） = 8.6
#     -> Processing: ⾷塩相当量（g） = 7.2
#     -> Processing: カリウム（mg） = 730
#     -> Processing: リン（mg） = 380
#   -> Final nutrition data: {'calorie': '1263', 'protein': '43.1', 'fat': '56.6', 'carbohydrate': '149.5', 'sugar': '140.9', 'fiber': '8.6', 'salt': '7.2'}
#
# --- Processing 8/105: しょうが焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/379
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 717
#     -> Processing: 蛋⽩質（g） = 26.2
#     -> Processing: 脂質（g） = 37.1
#     -> Processing: 炭⽔化物（g） = 72.9
#     -> Processing: 糖質（g） = 66.1
#     -> Processing: 食物繊維（g） = 6.8
#     -> Processing: ⾷塩相当量（g） = 5.0
#     -> Processing: カリウム（mg） = 486
#     -> Processing: リン（mg） = 204
#   -> Final nutrition data: {'calorie': '717', 'protein': '26.2', 'fat': '37.1', 'carbohydrate': '72.9', 'sugar': '66.1', 'fiber': '6.8', 'salt': '5.0'}
#
# --- Processing 9/105: 肉野菜炒め定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/380
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 545
#     -> Processing: 蛋⽩質（g） = 26.4
#     -> Processing: 脂質（g） = 18.6
#     -> Processing: 炭⽔化物（g） = 71.4
#     -> Processing: 糖質（g） = 64.2
#     -> Processing: 食物繊維（g） = 7.2
#     -> Processing: ⾷塩相当量（g） = 5.0
#     -> Processing: カリウム（mg） = 685
#     -> Processing: リン（mg） = 247
#   -> Final nutrition data: {'calorie': '545', 'protein': '26.4', 'fat': '18.6', 'carbohydrate': '71.4', 'sugar': '64.2', 'fiber': '7.2', 'salt': '5.0'}
#
# --- Processing 10/105: チキン南蛮定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/421
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1038
#     -> Processing: 蛋⽩質（g） = 29.5
#     -> Processing: 脂質（g） = 57.0
#     -> Processing: 炭⽔化物（g） = 104.5
#     -> Processing: 糖質（g） = 97.5
#     -> Processing: 食物繊維（g） = 7.0
#     -> Processing: ⾷塩相当量（g） = 5.9
#     -> Processing: カリウム（mg） = 673
#     -> Processing: リン（mg） = 387
#   -> Final nutrition data: {'calorie': '1038', 'protein': '29.5', 'fat': '57.0', 'carbohydrate': '104.5', 'sugar': '97.5', 'fiber': '7.0', 'salt': '5.9'}
#
# --- Processing 11/105: から揚げ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/422
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 844
#     -> Processing: 蛋⽩質（g） = 39.7
#     -> Processing: 脂質（g） = 43.4
#     -> Processing: 炭⽔化物（g） = 78.6
#     -> Processing: 糖質（g） = 71.9
#     -> Processing: 食物繊維（g） = 6.7
#     -> Processing: ⾷塩相当量（g） = 6.1
#     -> Processing: カリウム（mg） = 812
#     -> Processing: リン（mg） = 416
#   -> Final nutrition data: {'calorie': '844', 'protein': '39.7', 'fat': '43.4', 'carbohydrate': '78.6', 'sugar': '71.9', 'fiber': '6.7', 'salt': '6.1'}
#
# --- Processing 12/105: 特から揚げ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/423
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 992
#     -> Processing: 蛋⽩質（g） = 51.7
#     -> Processing: 脂質（g） = 52.2
#     -> Processing: 炭⽔化物（g） = 83.8
#     -> Processing: 糖質（g） = 76.7
#     -> Processing: 食物繊維（g） = 7.1
#     -> Processing: ⾷塩相当量（g） = 6.9
#     -> Processing: カリウム（mg） = 1010
#     -> Processing: リン（mg） = 534
#   -> Final nutrition data: {'calorie': '992', 'protein': '51.7', 'fat': '52.2', 'carbohydrate': '83.8', 'sugar': '76.7', 'fiber': '7.1', 'salt': '6.9'}
#
# --- Processing 13/105: から揚げ&コロッケ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/424
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 881
#     -> Processing: 蛋⽩質（g） = 30.4
#     -> Processing: 脂質（g） = 44.8
#     -> Processing: 炭⽔化物（g） = 94.2
#     -> Processing: 糖質（g） = 87.0
#     -> Processing: 食物繊維（g） = 7.2
#     -> Processing: ⾷塩相当量（g） = 6.5
#     -> Processing: カリウム（mg） = 823
#     -> Processing: リン（mg） = 332
#   -> Final nutrition data: {'calorie': '881', 'protein': '30.4', 'fat': '44.8', 'carbohydrate': '94.2', 'sugar': '87.0', 'fiber': '7.2', 'salt': '6.5'}
#
# --- Processing 14/105: 味噌かつ煮定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/425
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 845
#     -> Processing: 蛋⽩質（g） = 40.6
#     -> Processing: 脂質（g） = 33.2
#     -> Processing: 炭⽔化物（g） = 100.2
#     -> Processing: 糖質（g） = 92.3
#     -> Processing: 食物繊維（g） = 7.9
#     -> Processing: ⾷塩相当量（g） = 5.9
#     -> Processing: カリウム（mg） = 765
#     -> Processing: リン（mg） = 436
#   -> Final nutrition data: {'calorie': '845', 'protein': '40.6', 'fat': '33.2', 'carbohydrate': '100.2', 'sugar': '92.3', 'fiber': '7.9', 'salt': '5.9'}
#
# --- Processing 15/105: コク旨ちゃんぽんとから揚げの定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/505
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1099
#     -> Processing: 蛋⽩質（g） = 44.3
#     -> Processing: 脂質（g） = 42.1
#     -> Processing: 炭⽔化物（g） = 140.4
#     -> Processing: 糖質（g） = 130.7
#     -> Processing: 食物繊維（g） = 9.7
#     -> Processing: ⾷塩相当量（g） = 8.7
#     -> Processing: カリウム（mg） = 703
#     -> Processing: リン（mg） = 312
#   -> Final nutrition data: {'calorie': '1099', 'protein': '44.3', 'fat': '42.1', 'carbohydrate': '140.4', 'sugar': '130.7', 'fiber': '9.7', 'salt': '8.7'}
#
# --- Processing 16/105: 大豆ミートのしょうが焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/381
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 572
#     -> Processing: 蛋⽩質（g） = 19.3
#     -> Processing: 脂質（g） = 22.8
#     -> Processing: 炭⽔化物（g） = 77.9
#     -> Processing: 糖質（g） = 70.8
#     -> Processing: 食物繊維（g） = 7.1
#     -> Processing: ⾷塩相当量（g） = 5.4
#     -> Processing: カリウム（mg） = 503
#     -> Processing: リン（mg） = 247
#   -> Final nutrition data: {'calorie': '572', 'protein': '19.3', 'fat': '22.8', 'carbohydrate': '77.9', 'sugar': '70.8', 'fiber': '7.1', 'salt': '5.4'}
#
# --- Processing 17/105: 大豆ミートの野菜炒め定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/382
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 408
#     -> Processing: 蛋⽩質（g） = 18.3
#     -> Processing: 脂質（g） = 5.3
#     -> Processing: 炭⽔化物（g） = 76.0
#     -> Processing: 糖質（g） = 68.1
#     -> Processing: 食物繊維（g） = 7.9
#     -> Processing: ⾷塩相当量（g） = 4.6
#     -> Processing: カリウム（mg） = 534
#     -> Processing: リン（mg） = 238
#   -> Final nutrition data: {'calorie': '408', 'protein': '18.3', 'fat': '5.3', 'carbohydrate': '76.0', 'sugar': '68.1', 'fiber': '7.9', 'salt': '4.6'}
#
# --- Processing 18/105: 大豆ミートのなす味噌と焼魚の定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/383
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 749
#     -> Processing: 蛋⽩質（g） = 27.6
#     -> Processing: 脂質（g） = 37.6
#     -> Processing: 炭⽔化物（g） = 79.7
#     -> Processing: 糖質（g） = 71.2
#     -> Processing: 食物繊維（g） = 8.5
#     -> Processing: ⾷塩相当量（g） = 5.3
#     -> Processing: カリウム（mg） = 746
#     -> Processing: リン（mg） = 330
#   -> Final nutrition data: {'calorie': '749', 'protein': '27.6', 'fat': '37.6', 'carbohydrate': '79.7', 'sugar': '71.2', 'fiber': '8.5', 'salt': '5.3'}
#
# --- Processing 19/105: ブラックアンガスビーフのカットステーキ定食【和風ソース】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/427
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 636
#     -> Processing: 蛋⽩質（g） = 37.0
#     -> Processing: 脂質（g） = 17.8
#     -> Processing: 炭⽔化物（g） = 84.6
#     -> Processing: 糖質（g） = 79.1
#     -> Processing: 食物繊維（g） = 5.5
#     -> Processing: ⾷塩相当量（g） = 6.1
#     -> Processing: カリウム（mg） = 628
#     -> Processing: リン（mg） = 319
#   -> Final nutrition data: {'calorie': '636', 'protein': '37.0', 'fat': '17.8', 'carbohydrate': '84.6', 'sugar': '79.1', 'fiber': '5.5', 'salt': '6.1'}
#
# --- Processing 20/105: ブラックアンガスビーフのカットステーキ定食【おろしぽん酢】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/428
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 622
#     -> Processing: 蛋⽩質（g） = 36.7
#     -> Processing: 脂質（g） = 17.9
#     -> Processing: 炭⽔化物（g） = 82.2
#     -> Processing: 糖質（g） = 75.2
#     -> Processing: 食物繊維（g） = 7.0
#     -> Processing: ⾷塩相当量（g） = 6.3
#     -> Processing: カリウム（mg） = 656
#     -> Processing: リン（mg） = 316
#   -> Final nutrition data: {'calorie': '622', 'protein': '36.7', 'fat': '17.9', 'carbohydrate': '82.2', 'sugar': '75.2', 'fiber': '7.0', 'salt': '6.3'}
#
# --- Processing 21/105: ブラックアンガスビーフの特カットステーキ定食【和風ソース】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/429
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 751
#     -> Processing: 蛋⽩質（g） = 49.9
#     -> Processing: 脂質（g） = 24.5
#     -> Processing: 炭⽔化物（g） = 85.6
#     -> Processing: 糖質（g） = 80.1
#     -> Processing: 食物繊維（g） = 5.5
#     -> Processing: ⾷塩相当量（g） = 6.9
#     -> Processing: カリウム（mg） = 778
#     -> Processing: リン（mg） = 419
#   -> Final nutrition data: {'calorie': '751', 'protein': '49.9', 'fat': '24.5', 'carbohydrate': '85.6', 'sugar': '80.1', 'fiber': '5.5', 'salt': '6.9'}
#
# --- Processing 22/105: ブラックアンガスビーフの特カットステーキ定食【おろしぽん酢】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/430
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 737
#     -> Processing: 蛋⽩質（g） = 49.6
#     -> Processing: 脂質（g） = 24.6
#     -> Processing: 炭⽔化物（g） = 83.2
#     -> Processing: 糖質（g） = 76.2
#     -> Processing: 食物繊維（g） = 7.0
#     -> Processing: ⾷塩相当量（g） = 7.1
#     -> Processing: カリウム（mg） = 806
#     -> Processing: リン（mg） = 416
#   -> Final nutrition data: {'calorie': '737', 'protein': '49.6', 'fat': '24.6', 'carbohydrate': '83.2', 'sugar': '76.2', 'fiber': '7.0', 'salt': '7.1'}
#
# --- Processing 23/105: ブラックアンガスビーフのカットステーキとエビフライの定食【和風ソース】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/431
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 767
#     -> Processing: 蛋⽩質（g） = 40.0
#     -> Processing: 脂質（g） = 28.2
#     -> Processing: 炭⽔化物（g） = 90.9
#     -> Processing: 糖質（g） = 85.0
#     -> Processing: 食物繊維（g） = 5.9
#     -> Processing: ⾷塩相当量（g） = 6.7
#     -> Processing: カリウム（mg） = 651
#     -> Processing: リン（mg） = 350
#   -> Final nutrition data: {'calorie': '767', 'protein': '40.0', 'fat': '28.2', 'carbohydrate': '90.9', 'sugar': '85.0', 'fiber': '5.9', 'salt': '6.7'}
#
# --- Processing 24/105: ブラックアンガスビーフのカットステーキとエビフライの定食【おろしぽん酢】 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/432
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 753
#     -> Processing: 蛋⽩質（g） = 39.7
#     -> Processing: 脂質（g） = 28.3
#     -> Processing: 炭⽔化物（g） = 88.5
#     -> Processing: 糖質（g） = 81.1
#     -> Processing: 食物繊維（g） = 7.4
#     -> Processing: ⾷塩相当量（g） = 6.9
#     -> Processing: カリウム（mg） = 679
#     -> Processing: リン（mg） = 347
#   -> Final nutrition data: {'calorie': '753', 'protein': '39.7', 'fat': '28.3', 'carbohydrate': '88.5', 'sugar': '81.1', 'fiber': '7.4', 'salt': '6.9'}
#
# --- Processing 25/105: 和風おろしハンバーグ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/433
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 753
#     -> Processing: 蛋⽩質（g） = 31.9
#     -> Processing: 脂質（g） = 25.8
#     -> Processing: 炭⽔化物（g） = 104.5
#     -> Processing: 糖質（g） = 92.9
#     -> Processing: 食物繊維（g） = 11.6
#     -> Processing: ⾷塩相当量（g） = 6.3
#     -> Processing: カリウム（mg） = 932
#     -> Processing: リン（mg） = 323
#   -> Final nutrition data: {'calorie': '753', 'protein': '31.9', 'fat': '25.8', 'carbohydrate': '104.5', 'sugar': '92.9', 'fiber': '11.6', 'salt': '6.3'}
#
# --- Processing 26/105: デミハンバーグ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/434
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 740
#     -> Processing: 蛋⽩質（g） = 31.7
#     -> Processing: 脂質（g） = 26.9
#     -> Processing: 炭⽔化物（g） = 97.3
#     -> Processing: 糖質（g） = 87.8
#     -> Processing: 食物繊維（g） = 9.5
#     -> Processing: ⾷塩相当量（g） = 5.4
#     -> Processing: カリウム（mg） = 851
#     -> Processing: リン（mg） = 315
#   -> Final nutrition data: {'calorie': '740', 'protein': '31.7', 'fat': '26.9', 'carbohydrate': '97.3', 'sugar': '87.8', 'fiber': '9.5', 'salt': '5.4'}
#
# --- Processing 27/105: 4種のチーズハンバーグ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/435
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 829
#     -> Processing: 蛋⽩質（g） = 37.9
#     -> Processing: 脂質（g） = 33.9
#     -> Processing: 炭⽔化物（g） = 97.7
#     -> Processing: 糖質（g） = 88.2
#     -> Processing: 食物繊維（g） = 9.5
#     -> Processing: ⾷塩相当量（g） = 5.8
#     -> Processing: カリウム（mg） = 866
#     -> Processing: リン（mg） = 498
#   -> Final nutrition data: {'calorie': '829', 'protein': '37.9', 'fat': '33.9', 'carbohydrate': '97.7', 'sugar': '88.2', 'fiber': '9.5', 'salt': '5.8'}
#
# --- Processing 28/105: ミックスとじ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/436
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 838
#     -> Processing: 蛋⽩質（g） = 40.4
#     -> Processing: 脂質（g） = 36.1
#     -> Processing: 炭⽔化物（g） = 90.8
#     -> Processing: 糖質（g） = 85.3
#     -> Processing: 食物繊維（g） = 5.5
#     -> Processing: ⾷塩相当量（g） = 5.9
#     -> Processing: カリウム（mg） = 575
#     -> Processing: リン（mg） = 476
#   -> Final nutrition data: {'calorie': '838', 'protein': '40.4', 'fat': '36.1', 'carbohydrate': '90.8', 'sugar': '85.3', 'fiber': '5.5', 'salt': '5.9'}
#
# --- Processing 29/105: チキン南蛮としょうが焼の人気コンビ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/437
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1388
#     -> Processing: 蛋⽩質（g） = 46.4
#     -> Processing: 脂質（g） = 84.2
#     -> Processing: 炭⽔化物（g） = 114.9
#     -> Processing: 糖質（g） = 106.4
#     -> Processing: 食物繊維（g） = 8.5
#     -> Processing: ⾷塩相当量（g） = 8.4
#     -> Processing: カリウム（mg） = 868
#     -> Processing: リン（mg） = 478
#   -> Final nutrition data: {'calorie': '1388', 'protein': '46.4', 'fat': '84.2', 'carbohydrate': '114.9', 'sugar': '106.4', 'fiber': '8.5', 'salt': '8.4'}
#
# --- Processing 30/105: ハンバーグとエビフライとから揚げの人気トリオ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/438
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1054
#     -> Processing: 蛋⽩質（g） = 53.1
#     -> Processing: 脂質（g） = 49.1
#     -> Processing: 炭⽔化物（g） = 104.1
#     -> Processing: 糖質（g） = 94.4
#     -> Processing: 食物繊維（g） = 9.7
#     -> Processing: ⾷塩相当量（g） = 8.4
#     -> Processing: カリウム（mg） = 1126
#     -> Processing: リン（mg） = 528
#   -> Final nutrition data: {'calorie': '1054', 'protein': '53.1', 'fat': '49.1', 'carbohydrate': '104.1', 'sugar': '94.4', 'fiber': '9.7', 'salt': '8.4'}
#
# --- Processing 31/105: チキン南蛮とエビフライの定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/439
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 1257
#     -> Processing: 蛋⽩質（g） = 35.3
#     -> Processing: 脂質（g） = 73.8
#     -> Processing: 炭⽔化物（g） = 115.5
#     -> Processing: 糖質（g） = 107.8
#     -> Processing: 食物繊維（g） = 7.7
#     -> Processing: ⾷塩相当量（g） = 6.8
#     -> Processing: カリウム（mg） = 715
#     -> Processing: リン（mg） = 424
#   -> Final nutrition data: {'calorie': '1257', 'protein': '35.3', 'fat': '73.8', 'carbohydrate': '115.5', 'sugar': '107.8', 'fiber': '7.7', 'salt': '6.8'}
#
# --- Processing 32/105: ロースとんかつとエビフライの定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/440
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 992
#     -> Processing: 蛋⽩質（g） = 33.2
#     -> Processing: 脂質（g） = 49.2
#     -> Processing: 炭⽔化物（g） = 107.4
#     -> Processing: 糖質（g） = 100.2
#     -> Processing: 食物繊維（g） = 7.2
#     -> Processing: ⾷塩相当量（g） = 6.4
#     -> Processing: カリウム（mg） = 671
#     -> Processing: リン（mg） = 357
#   -> Final nutrition data: {'calorie': '992', 'protein': '33.2', 'fat': '49.2', 'carbohydrate': '107.4', 'sugar': '100.2', 'fiber': '7.2', 'salt': '6.4'}
#
# --- Processing 33/105: サバの塩焼定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/384
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 686
#     -> Processing: 蛋⽩質（g） = 32.9
#     -> Processing: 脂質（g） = 35.1
#     -> Processing: 炭⽔化物（g） = 61.9
#     -> Processing: 糖質（g） = 57.1
#     -> Processing: 食物繊維（g） = 4.8
#     -> Processing: ⾷塩相当量（g） = 3.8
#     -> Processing: カリウム（mg） = 710
#     -> Processing: リン（mg） = 397
#   -> Final nutrition data: {'calorie': '686', 'protein': '32.9', 'fat': '35.1', 'carbohydrate': '61.9', 'sugar': '57.1', 'fiber': '4.8', 'salt': '3.8'}
#
# --- Processing 34/105: サバの味噌煮定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/385
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 621
#     -> Processing: 蛋⽩質（g） = 30.4
#     -> Processing: 脂質（g） = 24.9
#     -> Processing: 炭⽔化物（g） = 71.4
#     -> Processing: 糖質（g） = 65.8
#     -> Processing: 食物繊維（g） = 5.6
#     -> Processing: ⾷塩相当量（g） = 4.3
#     -> Processing: カリウム（mg） = 356
#     -> Processing: リン（mg） = 259
#   -> Final nutrition data: {'calorie': '621', 'protein': '30.4', 'fat': '24.9', 'carbohydrate': '71.4', 'sugar': '65.8', 'fiber': '5.6', 'salt': '4.3'}
#
# --- Processing 35/105: しまほっけ定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/386
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 631
#     -> Processing: 蛋⽩質（g） = 50.7
#     -> Processing: 脂質（g） = 21.3
#     -> Processing: 炭⽔化物（g） = 61.4
#     -> Processing: 糖質（g） = 56.6
#     -> Processing: 食物繊維（g） = 4.8
#     -> Processing: ⾷塩相当量（g） = 4.2
#     -> Processing: カリウム（mg） = 839
#     -> Processing: リン（mg） = 690
#   -> Final nutrition data: {'calorie': '631', 'protein': '50.7', 'fat': '21.3', 'carbohydrate': '61.4', 'sugar': '56.6', 'fiber': '4.8', 'salt': '4.2'}
#
# --- Processing 36/105: なす味噌と焼魚の定食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/388
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 817
#     -> Processing: 蛋⽩質（g） = 30.3
#     -> Processing: 脂質（g） = 44.8
#     -> Processing: 炭⽔化物（g） = 77.4
#     -> Processing: 糖質（g） = 69.4
#     -> Processing: 食物繊維（g） = 8.0
#     -> Processing: ⾷塩相当量（g） = 5.1
#     -> Processing: カリウム（mg） = 813
#     -> Processing: リン（mg） = 360
#   -> Final nutrition data: {'calorie': '817', 'protein': '30.3', 'fat': '44.8', 'carbohydrate': '77.4', 'sugar': '69.4', 'fiber': '8.0', 'salt': '5.1'}
#
# --- Processing 37/105: やよい御膳 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/442
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 726
#     -> Processing: 蛋⽩質（g） = 28.1
#     -> Processing: 脂質（g） = 30.0
#     -> Processing: 炭⽔化物（g） = 89.9
#     -> Processing: 糖質（g） = 80.8
#     -> Processing: 食物繊維（g） = 9.1
#     -> Processing: ⾷塩相当量（g） = 6.2
#     -> Processing: カリウム（mg） = 714
#     -> Processing: リン（mg） = 351
#   -> Final nutrition data: {'calorie': '726', 'protein': '28.1', 'fat': '30.0', 'carbohydrate': '89.9', 'sugar': '80.8', 'fiber': '9.1', 'salt': '6.2'}
#
# --- Processing 38/105: お子様ランチ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/305
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 529
#     -> Processing: 蛋⽩質（g） = 12.4
#     -> Processing: 脂質（g） = 18.2
#     -> Processing: 炭⽔化物（g） = 80.2
#     -> Processing: 糖質（g） = 74.9
#     -> Processing: 食物繊維（g） = 5.3
#     -> Processing: ⾷塩相当量（g） = 1.4
#     -> Processing: カリウム（mg） = 584
#     -> Processing: リン（mg） = 209
#   -> Final nutrition data: {'calorie': '529', 'protein': '12.4', 'fat': '18.2', 'carbohydrate': '80.2', 'sugar': '74.9', 'fiber': '5.3', 'salt': '1.4'}
#
# --- Processing 39/105: お子様カレー(低アレルゲン) ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/507
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 605
#     -> Processing: 蛋⽩質（g） = 11.7
#     -> Processing: 脂質（g） = 20.3
#     -> Processing: 炭⽔化物（g） = 96.2
#     -> Processing: 糖質（g） = 86.8
#     -> Processing: 食物繊維（g） = 9.4
#     -> Processing: ⾷塩相当量（g） = 2.1
#     -> Processing: カリウム（mg） = 793
#     -> Processing: リン（mg） = 196
#   -> Final nutrition data: {'calorie': '605', 'protein': '11.7', 'fat': '20.3', 'carbohydrate': '96.2', 'sugar': '86.8', 'fiber': '9.4', 'salt': '2.1'}
#
# --- Processing 40/105: 地鶏親子丼～阿波尾鶏～ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/443
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 683
#     -> Processing: 蛋⽩質（g） = 36.1
#     -> Processing: 脂質（g） = 13.8
#     -> Processing: 炭⽔化物（g） = 107.1
#     -> Processing: 糖質（g） = 100.3
#     -> Processing: 食物繊維（g） = 6.8
#     -> Processing: ⾷塩相当量（g） = 5.2
#     -> Processing: カリウム（mg） = 295
#     -> Processing: リン（mg） = 365
#   -> Final nutrition data: {'calorie': '683', 'protein': '36.1', 'fat': '13.8', 'carbohydrate': '107.1', 'sugar': '100.3', 'fiber': '6.8', 'salt': '5.2'}
#
# --- Processing 41/105: かつ丼 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/444
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 857
#     -> Processing: 蛋⽩質（g） = 37.1
#     -> Processing: 脂質（g） = 27.0
#     -> Processing: 炭⽔化物（g） = 119.8
#     -> Processing: 糖質（g） = 112.9
#     -> Processing: 食物繊維（g） = 6.9
#     -> Processing: ⾷塩相当量（g） = 5.9
#     -> Processing: カリウム（mg） = 653
#     -> Processing: リン（mg） = 410
#   -> Final nutrition data: {'calorie': '857', 'protein': '37.1', 'fat': '27.0', 'carbohydrate': '119.8', 'sugar': '112.9', 'fiber': '6.9', 'salt': '5.9'}
#
# --- Processing 42/105: 鉄火丼 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/445
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 520
#     -> Processing: 蛋⽩質（g） = 30.4
#     -> Processing: 脂質（g） = 3.3
#     -> Processing: 炭⽔化物（g） = 94.5
#     -> Processing: 糖質（g） = 88.9
#     -> Processing: 食物繊維（g） = 5.6
#     -> Processing: ⾷塩相当量（g） = 4.9
#     -> Processing: カリウム（mg） = 616
#     -> Processing: リン（mg） = 356
#   -> Final nutrition data: {'calorie': '520', 'protein': '30.4', 'fat': '3.3', 'carbohydrate': '94.5', 'sugar': '88.9', 'fiber': '5.6', 'salt': '4.9'}
#
# --- Processing 43/105: コク旨ちゃんぽん（単品） ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/506
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 699
#     -> Processing: 蛋⽩質（g） = 28.0
#     -> Processing: 脂質（g） = 31.3
#     -> Processing: 炭⽔化物（g） = 79.4
#     -> Processing: 糖質（g） = 73.0
#     -> Processing: 食物繊維（g） = 6.4
#     -> Processing: ⾷塩相当量（g） = 7.2
#     -> Processing: カリウム（mg） = 438
#     -> Processing: リン（mg） = 152
#   -> Final nutrition data: {'calorie': '699', 'protein': '28.0', 'fat': '31.3', 'carbohydrate': '79.4', 'sugar': '73.0', 'fiber': '6.4', 'salt': '7.2'}
#
# --- Processing 44/105: 納豆朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/447
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 370
#     -> Processing: 蛋⽩質（g） = 15.8
#     -> Processing: 脂質（g） = 7.0
#     -> Processing: 炭⽔化物（g） = 62.9
#     -> Processing: 糖質（g） = 55.9
#     -> Processing: 食物繊維（g） = 7.0
#     -> Processing: ⾷塩相当量（g） = 2.4
#     -> Processing: カリウム（mg） = 431
#     -> Processing: リン（mg） = 179
#   -> Final nutrition data: {'calorie': '370', 'protein': '15.8', 'fat': '7.0', 'carbohydrate': '62.9', 'sugar': '55.9', 'fiber': '7.0', 'salt': '2.4'}
#
# --- Processing 45/105: しらすおろし朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/448
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 381
#     -> Processing: 蛋⽩質（g） = 17.2
#     -> Processing: 脂質（g） = 8.4
#     -> Processing: 炭⽔化物（g） = 60.0
#     -> Processing: 糖質（g） = 55.3
#     -> Processing: 食物繊維（g） = 4.7
#     -> Processing: ⾷塩相当量（g） = 2.4
#     -> Processing: カリウム（mg） = 420
#     -> Processing: リン（mg） = 236
#   -> Final nutrition data: {'calorie': '381', 'protein': '17.2', 'fat': '8.4', 'carbohydrate': '60.0', 'sugar': '55.3', 'fiber': '4.7', 'salt': '2.4'}
#
# --- Processing 46/105: ミニすき焼き朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/449
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 525
#     -> Processing: 蛋⽩質（g） = 20.7
#     -> Processing: 脂質（g） = 19.8
#     -> Processing: 炭⽔化物（g） = 68.2
#     -> Processing: 糖質（g） = 62.1
#     -> Processing: 食物繊維（g） = 6.1
#     -> Processing: ⾷塩相当量（g） = 3.4
#     -> Processing: カリウム（mg） = 395
#     -> Processing: リン（mg） = 262
#   -> Final nutrition data: {'calorie': '525', 'protein': '20.7', 'fat': '19.8', 'carbohydrate': '68.2', 'sugar': '62.1', 'fiber': '6.1', 'salt': '3.4'}
#
# --- Processing 47/105: エッグ&ウインナー朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/450
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 538
#     -> Processing: 蛋⽩質（g） = 21.5
#     -> Processing: 脂質（g） = 23.0
#     -> Processing: 炭⽔化物（g） = 63.2
#     -> Processing: 糖質（g） = 58.4
#     -> Processing: 食物繊維（g） = 4.8
#     -> Processing: ⾷塩相当量（g） = 3.3
#     -> Processing: カリウム（mg） = 397
#     -> Processing: リン（mg） = 285
#   -> Final nutrition data: {'calorie': '538', 'protein': '21.5', 'fat': '23.0', 'carbohydrate': '63.2', 'sugar': '58.4', 'fiber': '4.8', 'salt': '3.3'}
#
# --- Processing 48/105: しゃけの塩焼朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/451
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 378
#     -> Processing: 蛋⽩質（g） = 26.2
#     -> Processing: 脂質（g） = 8.2
#     -> Processing: 炭⽔化物（g） = 59.7
#     -> Processing: 糖質（g） = 54.9
#     -> Processing: 食物繊維（g） = 4.8
#     -> Processing: ⾷塩相当量（g） = 3.2
#     -> Processing: カリウム（mg） = 455
#     -> Processing: リン（mg） = 241
#   -> Final nutrition data: {'calorie': '378', 'protein': '26.2', 'fat': '8.2', 'carbohydrate': '59.7', 'sugar': '54.9', 'fiber': '4.8', 'salt': '3.2'}
#
# --- Processing 49/105: サバの塩焼朝食 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/452
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 495
#     -> Processing: 蛋⽩質（g） = 21.7
#     -> Processing: 脂質（g） = 19.3
#     -> Processing: 炭⽔化物（g） = 60.4
#     -> Processing: 糖質（g） = 55.6
#     -> Processing: 食物繊維（g） = 4.8
#     -> Processing: ⾷塩相当量（g） = 3.2
#     -> Processing: カリウム（mg） = 476
#     -> Processing: リン（mg） = 259
#   -> Final nutrition data: {'calorie': '495', 'protein': '21.7', 'fat': '19.3', 'carbohydrate': '60.4', 'sugar': '55.6', 'fiber': '4.8', 'salt': '3.2'}
#
# --- Processing 50/105: タルタルソース ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/78
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 177
#     -> Processing: 蛋⽩質（g） = 2.0
#     -> Processing: 脂質（g） = 17.2
#     -> Processing: 炭⽔化物（g） = 2.7
#     -> Processing: 糖質（g） = 2.5
#     -> Processing: 食物繊維（g） = 0.2
#     -> Processing: ⾷塩相当量（g） = 0.6
#     -> Processing: カリウム（mg） = 26
#     -> Processing: リン（mg） = 30
#   -> Final nutrition data: {'calorie': '177', 'protein': '2.0', 'fat': '17.2', 'carbohydrate': '2.7', 'sugar': '2.5', 'fiber': '0.2', 'salt': '0.6'}
#
# --- Processing 51/105: 生たまご ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/472
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 83
#     -> Processing: 蛋⽩質（g） = 6.8
#     -> Processing: 脂質（g） = 5.7
#     -> Processing: 炭⽔化物（g） = 0.2
#     -> Processing: 糖質（g） = 0.2
#     -> Processing: 食物繊維（g） = 0.0
#     -> Processing: ⾷塩相当量（g） = 0.2
#     -> Processing: カリウム（mg） = 72
#     -> Processing: リン（mg） = 99
#   -> Final nutrition data: {'calorie': '83', 'protein': '6.8', 'fat': '5.7', 'carbohydrate': '0.2', 'sugar': '0.2', 'fiber': '0.0', 'salt': '0.2'}
#
# --- Processing 52/105: とろろ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/480
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 55
#     -> Processing: 蛋⽩質（g） = 1.4
#     -> Processing: 脂質（g） = 0.0
#     -> Processing: 炭⽔化物（g） = 13.3
#     -> Processing: 糖質（g） = 11.5
#     -> Processing: 食物繊維（g） = 1.8
#     -> Processing: ⾷塩相当量（g） = 0.8
#     -> Processing: カリウム（mg） = 291
#     -> Processing: リン（mg） = 66
#   -> Final nutrition data: {'calorie': '55', 'protein': '1.4', 'fat': '0.0', 'carbohydrate': '13.3', 'sugar': '11.5', 'fiber': '1.8', 'salt': '0.8'}
#
# --- Processing 53/105: 野菜サラダ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/473
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 67
#     -> Processing: 蛋⽩質（g） = 1.2
#     -> Processing: 脂質（g） = 5.2
#     -> Processing: 炭⽔化物（g） = 4.7
#     -> Processing: 糖質（g） = 3.3
#     -> Processing: 食物繊維（g） = 1.4
#     -> Processing: ⾷塩相当量（g） = 0.5
#     -> Processing: カリウム（mg） = 118
#     -> Processing: リン（mg） = 24
#   -> Final nutrition data: {'calorie': '67', 'protein': '1.2', 'fat': '5.2', 'carbohydrate': '4.7', 'sugar': '3.3', 'fiber': '1.4', 'salt': '0.5'}
#
# --- Processing 54/105: 納豆 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/474
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 90
#     -> Processing: 蛋⽩質（g） = 7.4
#     -> Processing: 脂質（g） = 4.5
#     -> Processing: 炭⽔化物（g） = 5.4
#     -> Processing: 糖質（g） = 2.4
#     -> Processing: 食物繊維（g） = 3.0
#     -> Processing: ⾷塩相当量（g） = 0.5
#     -> Processing: カリウム（mg） = 248
#     -> Processing: リン（mg） = 86
#   -> Final nutrition data: {'calorie': '90', 'protein': '7.4', 'fat': '4.5', 'carbohydrate': '5.4', 'sugar': '2.4', 'fiber': '3.0', 'salt': '0.5'}
#
# --- Processing 55/105: 冷奴 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/475
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 21
#     -> Processing: 蛋⽩質（g） = 2.0
#     -> Processing: 脂質（g） = 1.3
#     -> Processing: 炭⽔化物（g） = 0.9
#     -> Processing: 糖質（g） = 0.6
#     -> Processing: 食物繊維（g） = 0.3
#     -> Processing: ⾷塩相当量（g） = 0.0
#     -> Processing: カリウム（mg） = 59
#     -> Processing: リン（mg） = 26
#   -> Final nutrition data: {'calorie': '21', 'protein': '2.0', 'fat': '1.3', 'carbohydrate': '0.9', 'sugar': '0.6', 'fiber': '0.3', 'salt': '0.0'}
#
# --- Processing 56/105: 【だし茶漬用】ほぐし鮭小鉢 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/478
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 27
#     -> Processing: 蛋⽩質（g） = 3.4
#     -> Processing: 脂質（g） = 0.8
#     -> Processing: 炭⽔化物（g） = 1.1
#     -> Processing: 糖質（g） = 0.9
#     -> Processing: 食物繊維（g） = 0.3
#     -> Processing: ⾷塩相当量（g） = 0.6
#     -> Processing: カリウム（mg） = 78
#     -> Processing: リン（mg） = 35
#   -> Final nutrition data: {'calorie': '27', 'protein': '3.4', 'fat': '0.8', 'carbohydrate': '1.1', 'sugar': '0.9', 'fiber': '0.3', 'salt': '0.6'}
#
# --- Processing 57/105: 【だし茶漬用】ミニサバ小鉢 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/477
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 105
#     -> Processing: 蛋⽩質（g） = 5.6
#     -> Processing: 脂質（g） = 8.1
#     -> Processing: 炭⽔化物（g） = 0.9
#     -> Processing: 糖質（g） = 0.7
#     -> Processing: 食物繊維（g） = 0.3
#     -> Processing: ⾷塩相当量（g） = 0.2
#     -> Processing: カリウム（mg） = 126
#     -> Processing: リン（mg） = 71
#   -> Final nutrition data: {'calorie': '105', 'protein': '5.6', 'fat': '8.1', 'carbohydrate': '0.9', 'sugar': '0.7', 'fiber': '0.3', 'salt': '0.2'}
#
# --- Processing 58/105: 蒸し鶏と海藻のぽん酢和え ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/476
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 22
#     -> Processing: 蛋⽩質（g） = 3.7
#     -> Processing: 脂質（g） = 0.3
#     -> Processing: 炭⽔化物（g） = 2.2
#     -> Processing: 糖質（g） = 1.1
#     -> Processing: 食物繊維（g） = 1.1
#     -> Processing: ⾷塩相当量（g） = 0.8
#     -> Processing: カリウム（mg） = 151
#     -> Processing: リン（mg） = 36
#   -> Final nutrition data: {'calorie': '22', 'protein': '3.7', 'fat': '0.3', 'carbohydrate': '2.2', 'sugar': '1.1', 'fiber': '1.1', 'salt': '0.8'}
#
# --- Processing 59/105: 玉子焼き ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/485
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 274
#     -> Processing: 蛋⽩質（g） = 13.5
#     -> Processing: 脂質（g） = 21.5
#     -> Processing: 炭⽔化物（g） = 6.6
#     -> Processing: 糖質（g） = 6.6
#     -> Processing: 食物繊維（g） = 0.0
#     -> Processing: ⾷塩相当量（g） = 1.8
#     -> Processing: カリウム（mg） = 154
#     -> Processing: リン（mg） = 191
#   -> Final nutrition data: {'calorie': '274', 'protein': '13.5', 'fat': '21.5', 'carbohydrate': '6.6', 'sugar': '6.6', 'fiber': '0.0', 'salt': '1.8'}
#
# --- Processing 60/105: 天ぷら小鉢 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/487
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 180
#     -> Processing: 蛋⽩質（g） = 4.9
#     -> Processing: 脂質（g） = 10.4
#     -> Processing: 炭⽔化物（g） = 17.3
#     -> Processing: 糖質（g） = 15.7
#     -> Processing: 食物繊維（g） = 1.6
#     -> Processing: ⾷塩相当量（g） = 1.4
#     -> Processing: カリウム（mg） = 157
#     -> Processing: リン（mg） = 96
#   -> Final nutrition data: {'calorie': '180', 'protein': '4.9', 'fat': '10.4', 'carbohydrate': '17.3', 'sugar': '15.7', 'fiber': '1.6', 'salt': '1.4'}
#
# --- Processing 61/105: 牛肉のすき焼き小鉢 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/486
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 181
#     -> Processing: 蛋⽩質（g） = 6.2
#     -> Processing: 脂質（g） = 13.2
#     -> Processing: 炭⽔化物（g） = 10.5
#     -> Processing: 糖質（g） = 8.4
#     -> Processing: 食物繊維（g） = 2.1
#     -> Processing: ⾷塩相当量（g） = 1.3
#     -> Processing: カリウム（mg） = 152
#     -> Processing: リン（mg） = 76
#   -> Final nutrition data: {'calorie': '181', 'protein': '6.2', 'fat': '13.2', 'carbohydrate': '10.5', 'sugar': '8.4', 'fiber': '2.1', 'salt': '1.3'}
#
# --- Processing 62/105: フライドポテト ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/481
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 305
#     -> Processing: 蛋⽩質（g） = 4.3
#     -> Processing: 脂質（g） = 16.1
#     -> Processing: 炭⽔化物（g） = 39.2
#     -> Processing: 糖質（g） = 33.1
#     -> Processing: 食物繊維（g） = 6.1
#     -> Processing: ⾷塩相当量（g） = 0.7
#     -> Processing: カリウム（mg） = 609
#     -> Processing: リン（mg） = 120
#   -> Final nutrition data: {'calorie': '305', 'protein': '4.3', 'fat': '16.1', 'carbohydrate': '39.2', 'sugar': '33.1', 'fiber': '6.1', 'salt': '0.7'}
#
# --- Processing 63/105: フライドポテト&ウインナー ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/482
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 336
#     -> Processing: 蛋⽩質（g） = 7.8
#     -> Processing: 脂質（g） = 21.2
#     -> Processing: 炭⽔化物（g） = 30.2
#     -> Processing: 糖質（g） = 26.0
#     -> Processing: 食物繊維（g） = 4.2
#     -> Processing: ⾷塩相当量（g） = 1.5
#     -> Processing: カリウム（mg） = 463
#     -> Processing: リン（mg） = 124
#   -> Final nutrition data: {'calorie': '336', 'protein': '7.8', 'fat': '21.2', 'carbohydrate': '30.2', 'sugar': '26.0', 'fiber': '4.2', 'salt': '1.5'}
#
# --- Processing 64/105: コロッケ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/479
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 208
#     -> Processing: 蛋⽩質（g） = 3.1
#     -> Processing: 脂質（g） = 11.8
#     -> Processing: 炭⽔化物（g） = 23.5
#     -> Processing: 糖質（g） = 21.7
#     -> Processing: 食物繊維（g） = 1.8
#     -> Processing: ⾷塩相当量（g） = 1.3
#     -> Processing: カリウム（mg） = 256
#     -> Processing: リン（mg） = 42
#   -> Final nutrition data: {'calorie': '208', 'protein': '3.1', 'fat': '11.8', 'carbohydrate': '23.5', 'sugar': '21.7', 'fiber': '1.8', 'salt': '1.3'}
#
# --- Processing 65/105: イカのから揚げ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/484
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 274
#     -> Processing: 蛋⽩質（g） = 10.7
#     -> Processing: 脂質（g） = 20.3
#     -> Processing: 炭⽔化物（g） = 12.6
#     -> Processing: 糖質（g） = 11.1
#     -> Processing: 食物繊維（g） = 1.5
#     -> Processing: ⾷塩相当量（g） = 1.5
#     -> Processing: カリウム（mg） = 103
#     -> Processing: リン（mg） = 79
#   -> Final nutrition data: {'calorie': '274', 'protein': '10.7', 'fat': '20.3', 'carbohydrate': '12.6', 'sugar': '11.1', 'fiber': '1.5', 'salt': '1.5'}
#
# --- Processing 66/105: ミニから揚げ ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/483
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 168
#     -> Processing: 蛋⽩質（g） = 12.3
#     -> Processing: 脂質（g） = 10.3
#     -> Processing: 炭⽔化物（g） = 6.8
#     -> Processing: 糖質（g） = 6.1
#     -> Processing: 食物繊維（g） = 0.7
#     -> Processing: ⾷塩相当量（g） = 1.6
#     -> Processing: カリウム（mg） = 236
#     -> Processing: リン（mg） = 125
#   -> Final nutrition data: {'calorie': '168', 'protein': '12.3', 'fat': '10.3', 'carbohydrate': '6.8', 'sugar': '6.1', 'fiber': '0.7', 'salt': '1.6'}
#
# --- Processing 67/105: から揚げ（5個） ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/488
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 477
#     -> Processing: 蛋⽩質（g） = 30.4
#     -> Processing: 脂質（g） = 33.5
#     -> Processing: 炭⽔化物（g） = 15.5
#     -> Processing: 糖質（g） = 13.8
#     -> Processing: 食物繊維（g） = 1.7
#     -> Processing: ⾷塩相当量（g） = 3.6
#     -> Processing: カリウム（mg） = 522
#     -> Processing: リン（mg） = 303
#   -> Final nutrition data: {'calorie': '477', 'protein': '30.4', 'fat': '33.5', 'carbohydrate': '15.5', 'sugar': '13.8', 'fiber': '1.7', 'salt': '3.6'}
#
# --- Processing 68/105: みそ汁 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/79
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 21
#     -> Processing: 蛋⽩質（g） = 2.0
#     -> Processing: 脂質（g） = 0.7
#     -> Processing: 炭⽔化物（g） = 2.0
#     -> Processing: 糖質（g） = 1.2
#     -> Processing: 食物繊維（g） = 0.8
#     -> Processing: ⾷塩相当量（g） = 1.9
#     -> Processing: カリウム（mg） = 68
#     -> Processing: リン（mg） = 25
#   -> Final nutrition data: {'calorie': '21', 'protein': '2.0', 'fat': '0.7', 'carbohydrate': '2.0', 'sugar': '1.2', 'fiber': '0.8', 'salt': '1.9'}
#
# --- Processing 69/105: 豚汁 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/87
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 84
#     -> Processing: 蛋⽩質（g） = 7.8
#     -> Processing: 脂質（g） = 2.6
#     -> Processing: 炭⽔化物（g） = 8.2
#     -> Processing: 糖質（g） = 6.3
#     -> Processing: 食物繊維（g） = 1.9
#     -> Processing: ⾷塩相当量（g） = 2.8
#     -> Processing: カリウム（mg） = 210
#     -> Processing: リン（mg） = 56
#   -> Final nutrition data: {'calorie': '84', 'protein': '7.8', 'fat': '2.6', 'carbohydrate': '8.2', 'sugar': '6.3', 'fiber': '1.9', 'salt': '2.8'}
#
# --- Processing 70/105: 貝汁 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/88
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 37
#     -> Processing: 蛋⽩質（g） = 3.9
#     -> Processing: 脂質（g） = 0.4
#     -> Processing: 炭⽔化物（g） = 4.4
#     -> Processing: 糖質（g） = 4.4
#     -> Processing: 食物繊維（g） = 0.0
#     -> Processing: ⾷塩相当量（g） = 2.3
#     -> Processing: カリウム（mg） = 100
#     -> Processing: リン（mg） = 40
#   -> Final nutrition data: {'calorie': '37', 'protein': '3.9', 'fat': '0.4', 'carbohydrate': '4.4', 'sugar': '4.4', 'fiber': '0.0', 'salt': '2.3'}
#
# --- Processing 71/105: 生ビール ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/252
#   -> Trying alternative search methods...
#   -> Trying regex extraction...
#   -> Final nutrition data: {'calorie': 'N/A', 'protein': 'N/A', 'fat': 'N/A', 'carbohydrate': 'N/A', 'sugar': 'N/A', 'fiber': 'N/A', 'salt': 'N/A'}
#
# --- Processing 72/105: メガ生ビール ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/256
#   -> Trying alternative search methods...
#   -> Trying regex extraction...
#   -> Final nutrition data: {'calorie': 'N/A', 'protein': 'N/A', 'fat': 'N/A', 'carbohydrate': 'N/A', 'sugar': 'N/A', 'fiber': 'N/A', 'salt': 'N/A'}
#
# --- Processing 73/105: ハイボール ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/369
#   -> Trying alternative search methods...
#   -> Trying regex extraction...
#   -> Final nutrition data: {'calorie': 'N/A', 'protein': 'N/A', 'fat': 'N/A', 'carbohydrate': 'N/A', 'sugar': 'N/A', 'fiber': 'N/A', 'salt': 'N/A'}
#
# --- Processing 74/105: メガハイボール ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/371
#   -> Trying alternative search methods...
#   -> Trying regex extraction...
#   -> Final nutrition data: {'calorie': 'N/A', 'protein': 'N/A', 'fat': 'N/A', 'carbohydrate': 'N/A', 'sugar': 'N/A', 'fiber': 'N/A', 'salt': 'N/A'}
#
# --- Processing 75/105: レモンサワー ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/373
#   -> Trying alternative search methods...
#   -> Trying regex extraction...
#   -> Final nutrition data: {'calorie': 'N/A', 'protein': 'N/A', 'fat': 'N/A', 'carbohydrate': 'N/A', 'sugar': 'N/A', 'fiber': 'N/A', 'salt': 'N/A'}
#
# --- Processing 76/105: [テイクアウト]～徳島県産阿波尾鶏使用～地鶏まぶし　だし付 ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/92
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 606
#     -> Processing: 蛋⽩質（g） = 34.8
#     -> Processing: 脂質（g） = 11.5
#     -> Processing: 炭⽔化物（g） = 93.1
#     -> Processing: 糖質（g） = 88.2
#     -> Processing: 食物繊維（g） = 4.9
#     -> Processing: ⾷塩相当量（g） = 3.6
#     -> Processing: カリウム（mg） = 484
#     -> Processing: リン（mg） = 311
#   -> Final nutrition data: {'calorie': '606', 'protein': '34.8', 'fat': '11.5', 'carbohydrate': '93.1', 'sugar': '88.2', 'fiber': '4.9', 'salt': '3.6'}
#
# --- Processing 77/105: ［テイクアウト］肉野菜炒め ---
#   -> Fetching nutrition data from: https://www.yayoiken.com/menu_list/view/13/389
#   -> Found 9 table items
#     -> Processing: 熱量（kcal） = 525
#     -> Processing: 蛋⽩質（g） = 24.2
#     -> Processing: 脂質（g） = 17.2
#     -> Processing: 炭⽔化物（g） = 71.7
#     -> Processing: 糖質（g） = 64.7
#     -> Processing: 食物繊維（g） = 7.0
#     -> Processing: ⾷塩相当量（g） = 4.9
#     -> Processing: カリウム（mg） = 658
#     -> Processing: リン（mg） = 220
# ...
# 食物繊維: 0.0 g
# 食塩相当量: 0.2 g
# 画像: /files/menu_img/sp_472s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/472
# --------------------------------------------------------------------------------
#
# 【52】 とろろ
# 価格: 180
# カロリー: 55 kcal
# タンパク質: 1.4 g
# 脂質: 0.0 g
# 炭水化物: 13.3 g
# 糖質: 11.5 g
# 食物繊維: 1.8 g
# 食塩相当量: 0.8 g
# 画像: /files/menu_img/sp_480s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/480
# --------------------------------------------------------------------------------
#
# 【53】 野菜サラダ
# 価格: 100
# カロリー: 67 kcal
# タンパク質: 1.2 g
# 脂質: 5.2 g
# 炭水化物: 4.7 g
# 糖質: 3.3 g
# 食物繊維: 1.4 g
# 食塩相当量: 0.5 g
# 画像: /files/menu_img/sp_473s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/473
# --------------------------------------------------------------------------------
#
# 【54】 納豆
# 価格: 110
# カロリー: 90 kcal
# タンパク質: 7.4 g
# 脂質: 4.5 g
# 炭水化物: 5.4 g
# 糖質: 2.4 g
# 食物繊維: 3.0 g
# 食塩相当量: 0.5 g
# 画像: /files/menu_img/sp_474s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/474
# --------------------------------------------------------------------------------
#
# 【55】 冷奴
# 価格: 110
# カロリー: 21 kcal
# タンパク質: 2.0 g
# 脂質: 1.3 g
# 炭水化物: 0.9 g
# 糖質: 0.6 g
# 食物繊維: 0.3 g
# 食塩相当量: 0.0 g
# 画像: /files/menu_img/sp_475s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/475
# --------------------------------------------------------------------------------
#
# 【56】 【だし茶漬用】ほぐし鮭小鉢
# 価格: 160
# カロリー: 27 kcal
# タンパク質: 3.4 g
# 脂質: 0.8 g
# 炭水化物: 1.1 g
# 糖質: 0.9 g
# 食物繊維: 0.3 g
# 食塩相当量: 0.6 g
# 画像: /files/menu_img/sp_478s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/478
# --------------------------------------------------------------------------------
#
# 【57】 【だし茶漬用】ミニサバ小鉢
# 価格: 160
# カロリー: 105 kcal
# タンパク質: 5.6 g
# 脂質: 8.1 g
# 炭水化物: 0.9 g
# 糖質: 0.7 g
# 食物繊維: 0.3 g
# 食塩相当量: 0.2 g
# 画像: /files/menu_img/sp_477s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/477
# --------------------------------------------------------------------------------
#
# 【58】 蒸し鶏と海藻のぽん酢和え
# 価格: 130
# カロリー: 22 kcal
# タンパク質: 3.7 g
# 脂質: 0.3 g
# 炭水化物: 2.2 g
# 糖質: 1.1 g
# 食物繊維: 1.1 g
# 食塩相当量: 0.8 g
# 画像: /files/menu_img/sp_476s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/476
# --------------------------------------------------------------------------------
#
# 【59】 玉子焼き
# 価格: 290
# カロリー: 274 kcal
# タンパク質: 13.5 g
# 脂質: 21.5 g
# 炭水化物: 6.6 g
# 糖質: 6.6 g
# 食物繊維: 0.0 g
# 食塩相当量: 1.8 g
# 画像: /files/menu_img/sp_485s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/485
# --------------------------------------------------------------------------------
#
# 【60】 天ぷら小鉢
# 価格: 330
# カロリー: 180 kcal
# タンパク質: 4.9 g
# 脂質: 10.4 g
# 炭水化物: 17.3 g
# 糖質: 15.7 g
# 食物繊維: 1.6 g
# 食塩相当量: 1.4 g
# 画像: /files/menu_img/sp_487s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/487
# --------------------------------------------------------------------------------
#
# 【61】 牛肉のすき焼き小鉢
# 価格: 330
# カロリー: 181 kcal
# タンパク質: 6.2 g
# 脂質: 13.2 g
# 炭水化物: 10.5 g
# 糖質: 8.4 g
# 食物繊維: 2.1 g
# 食塩相当量: 1.3 g
# 画像: /files/menu_img/sp_486s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/486
# --------------------------------------------------------------------------------
#
# 【62】 フライドポテト
# 価格: 260
# カロリー: 305 kcal
# タンパク質: 4.3 g
# 脂質: 16.1 g
# 炭水化物: 39.2 g
# 糖質: 33.1 g
# 食物繊維: 6.1 g
# 食塩相当量: 0.7 g
# 画像: /files/menu_img/sp_481s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/481
# --------------------------------------------------------------------------------
#
# 【63】 フライドポテト&ウインナー
# 価格: 290
# カロリー: 336 kcal
# タンパク質: 7.8 g
# 脂質: 21.2 g
# 炭水化物: 30.2 g
# 糖質: 26.0 g
# 食物繊維: 4.2 g
# 食塩相当量: 1.5 g
# 画像: /files/menu_img/sp_482s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/482
# --------------------------------------------------------------------------------
#
# 【64】 コロッケ
# 価格: 170
# カロリー: 208 kcal
# タンパク質: 3.1 g
# 脂質: 11.8 g
# 炭水化物: 23.5 g
# 糖質: 21.7 g
# 食物繊維: 1.8 g
# 食塩相当量: 1.3 g
# 画像: /files/menu_img/sp_479s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/479
# --------------------------------------------------------------------------------
#
# 【65】 イカのから揚げ
# 価格: 260
# カロリー: 274 kcal
# タンパク質: 10.7 g
# 脂質: 20.3 g
# 炭水化物: 12.6 g
# 糖質: 11.1 g
# 食物繊維: 1.5 g
# 食塩相当量: 1.5 g
# 画像: /files/menu_img/sp_484s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/484
# --------------------------------------------------------------------------------
#
# 【66】 ミニから揚げ
# 価格: 280
# カロリー: 168 kcal
# タンパク質: 12.3 g
# 脂質: 10.3 g
# 炭水化物: 6.8 g
# 糖質: 6.1 g
# 食物繊維: 0.7 g
# 食塩相当量: 1.6 g
# 画像: /files/menu_img/sp_483s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/483
# --------------------------------------------------------------------------------
#
# 【67】 から揚げ（5個）
# 価格: 590
# カロリー: 477 kcal
# タンパク質: 30.4 g
# 脂質: 33.5 g
# 炭水化物: 15.5 g
# 糖質: 13.8 g
# 食物繊維: 1.7 g
# 食塩相当量: 3.6 g
# 画像: /files/menu_img/sp_488s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/488
# --------------------------------------------------------------------------------
#
# 【68】 みそ汁
# 価格: 100
# カロリー: 21 kcal
# タンパク質: 2.0 g
# 脂質: 0.7 g
# 炭水化物: 2.0 g
# 糖質: 1.2 g
# 食物繊維: 0.8 g
# 食塩相当量: 1.9 g
# 画像: /files/menu_img/sp_79s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/79
# --------------------------------------------------------------------------------
#
# 【69】 豚汁
# 価格: 290
# カロリー: 84 kcal
# タンパク質: 7.8 g
# 脂質: 2.6 g
# 炭水化物: 8.2 g
# 糖質: 6.3 g
# 食物繊維: 1.9 g
# 食塩相当量: 2.8 g
# 画像: /files/menu_img/sp_87s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/87
# --------------------------------------------------------------------------------
#
# 【70】 貝汁
# 価格: 290
# カロリー: 37 kcal
# タンパク質: 3.9 g
# 脂質: 0.4 g
# 炭水化物: 4.4 g
# 糖質: 4.4 g
# 食物繊維: 0.0 g
# 食塩相当量: 2.3 g
# 画像: /files/menu_img/sp_88s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/88
# --------------------------------------------------------------------------------
#
# 【71】 生ビール
# 価格: 550
# カロリー: N/A kcal
# タンパク質: N/A g
# 脂質: N/A g
# 炭水化物: N/A g
# 糖質: N/A g
# 食物繊維: N/A g
# 食塩相当量: N/A g
# 画像: /files/menu_img/sp_252s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/252
# --------------------------------------------------------------------------------
#
# 【72】 メガ生ビール
# 価格: 890
# カロリー: N/A kcal
# タンパク質: N/A g
# 脂質: N/A g
# 炭水化物: N/A g
# 糖質: N/A g
# 食物繊維: N/A g
# 食塩相当量: N/A g
# 画像: /files/menu_img/sp_256s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/256
# --------------------------------------------------------------------------------
#
# 【73】 ハイボール
# 価格: 430
# カロリー: N/A kcal
# タンパク質: N/A g
# 脂質: N/A g
# 炭水化物: N/A g
# 糖質: N/A g
# 食物繊維: N/A g
# 食塩相当量: N/A g
# 画像: /files/menu_img/sp_369s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/369
# --------------------------------------------------------------------------------
#
# 【74】 メガハイボール
# 価格: 620
# カロリー: N/A kcal
# タンパク質: N/A g
# 脂質: N/A g
# 炭水化物: N/A g
# 糖質: N/A g
# 食物繊維: N/A g
# 食塩相当量: N/A g
# 画像: /files/menu_img/sp_371s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/371
# --------------------------------------------------------------------------------
#
# 【75】 レモンサワー
# 価格: 430
# カロリー: N/A kcal
# タンパク質: N/A g
# 脂質: N/A g
# 炭水化物: N/A g
# 糖質: N/A g
# 食物繊維: N/A g
# 食塩相当量: N/A g
# 画像: /files/menu_img/sp_373s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/373
# --------------------------------------------------------------------------------
#
# 【76】 [テイクアウト]～徳島県産阿波尾鶏使用～地鶏まぶし　だし付
# 価格: 1020
# カロリー: 606 kcal
# タンパク質: 34.8 g
# 脂質: 11.5 g
# 炭水化物: 93.1 g
# 糖質: 88.2 g
# 食物繊維: 4.9 g
# 食塩相当量: 3.6 g
# 画像: /files/menu_img/sp_92s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/92
# --------------------------------------------------------------------------------
#
# 【77】 ［テイクアウト］肉野菜炒め
# 価格: 950
# カロリー: 525 kcal
# タンパク質: 24.2 g
# 脂質: 17.2 g
# 炭水化物: 71.7 g
# 糖質: 64.7 g
# 食物繊維: 7.0 g
# 食塩相当量: 4.9 g
# 画像: /files/menu_img/sp_389s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/389
# --------------------------------------------------------------------------------
#
# 【78】 ［テイクアウト］しょうが焼
# 価格: 860
# カロリー: 678 kcal
# タンパク質: 23.8 g
# 脂質: 33.9 g
# 炭水化物: 72.5 g
# 糖質: 66.0 g
# 食物繊維: 6.5 g
# 食塩相当量: 5.3 g
# 画像: /files/menu_img/sp_390s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/390
# --------------------------------------------------------------------------------
#
# 【79】 ［テイクアウト］から揚げ
# 価格: 890
# カロリー: 700 kcal
# タンパク質: 37.2 g
# 脂質: 28.9 g
# 炭水化物: 75.9 g
# 糖質: 69.7 g
# 食物繊維: 6.2 g
# 食塩相当量: 5.0 g
# 画像: /files/menu_img/sp_453s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/453
# --------------------------------------------------------------------------------
#
# 【80】 ［テイクアウト］特から揚げ
# 価格: 1080
# カロリー: 848 kcal
# タンパク質: 49.2 g
# 脂質: 37.7 g
# 炭水化物: 81.1 g
# 糖質: 74.5 g
# 食物繊維: 6.6 g
# 食塩相当量: 5.8 g
# 画像: /files/menu_img/sp_454s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/454
# --------------------------------------------------------------------------------
#
# 【81】 ［テイクアウト］から揚げ＆コロッケ
# 価格: 890
# カロリー: 804 kcal
# タンパク質: 28.0 g
# 脂質: 37.9 g
# 炭水化物: 91.9 g
# 糖質: 85.2 g
# 食物繊維: 6.7 g
# 食塩相当量: 5.5 g
# 画像: /files/menu_img/sp_455s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/455
# --------------------------------------------------------------------------------
#
# 【82】 ［テイクアウト］チキン南蛮
# 価格: 990
# カロリー: 967 kcal
# タンパク質: 26.3 g
# 脂質: 50.1 g
# 炭水化物: 105.1 g
# 糖質: 98.7 g
# 食物繊維: 6.4 g
# 食塩相当量: 6.2 g
# 画像: /files/menu_img/sp_456s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/456
# --------------------------------------------------------------------------------
#
# 【83】 ［テイクアウト］和風おろしハンバーグ
# 価格: 980
# カロリー: 719 kcal
# タンパク質: 31.5 g
# 脂質: 26.0 g
# 炭水化物: 95.7 g
# 糖質: 85.0 g
# 食物繊維: 10.7 g
# 食塩相当量: 6.8 g
# 画像: /files/menu_img/sp_457s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/457
# --------------------------------------------------------------------------------
#
# 【84】 ［テイクアウト］サバの塩焼
# 価格: 890
# カロリー: 742 kcal
# タンパク質: 32.2 g
# 脂質: 39.3 g
# 炭水化物: 68.1 g
# 糖質: 62.3 g
# 食物繊維: 5.8 g
# 食塩相当量: 5.6 g
# 画像: /files/menu_img/sp_391s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/391
# --------------------------------------------------------------------------------
#
# 【85】 ［テイクアウト］なす味噌と焼魚
# 価格: 1150
# カロリー: 755 kcal
# タンパク質: 29.4 g
# 脂質: 37.0 g
# 炭水化物: 81.1 g
# 糖質: 70.9 g
# 食物繊維: 10.2 g
# 食塩相当量: 7.0 g
# 画像: /files/menu_img/sp_392s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/392
# --------------------------------------------------------------------------------
#
# 【86】 ［テイクアウト］ブラックアンガスビーフのカットステーキ
# 価格: 1430
# カロリー: 680 kcal
# タンパク質: 37.4 g
# 脂質: 21.5 g
# 炭水化物: 87.7 g
# 糖質: 81.2 g
# 食物繊維: 6.5 g
# 食塩相当量: 6.9 g
# 画像: /files/menu_img/sp_458s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/458
# --------------------------------------------------------------------------------
#
# 【87】 ［テイクアウト］チキン南蛮としょうが焼の人気コンビ
# 価格: 1240
# カロリー: 1212 kcal
# タンパク質: 42.2 g
# 脂質: 68.0 g
# 炭水化物: 111.1 g
# 糖質: 104.0 g
# 食物繊維: 7.1 g
# 食塩相当量: 8.1 g
# 画像: /files/menu_img/sp_459s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/459
# --------------------------------------------------------------------------------
#
# 【88】 ［テイクアウト］ハンバーグとエビフライとから揚げの人気トリオ
# 価格: 1240
# カロリー: 958 kcal
# タンパク質: 51.6 g
# 脂質: 42.2 g
# 炭水化物: 96.5 g
# 糖質: 87.8 g
# 食物繊維: 8.7 g
# 食塩相当量: 7.0 g
# 画像: /files/menu_img/sp_460s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/460
# --------------------------------------------------------------------------------
#
# 【89】 ［テイクアウト］お子様ランチ
# 価格: 410
# カロリー: 527 kcal
# タンパク質: 17.7 g
# 脂質: 23.3 g
# 炭水化物: 63.4 g
# 糖質: 57.5 g
# 食物繊維: 5.9 g
# 食塩相当量: 2.5 g
# 画像: /files/menu_img/sp_330s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/330
# --------------------------------------------------------------------------------
#
# 【90】 ［テイクアウト］肉野菜炒め　おかずのみ
# 価格: 800
# カロリー: 269 kcal
# タンパク質: 18.4 g
# 脂質: 16.1 g
# 炭水化物: 14.3 g
# 糖質: 10.8 g
# 食物繊維: 3.5 g
# 食塩相当量: 3.1 g
# 画像: /files/menu_img/sp_393s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/393
# --------------------------------------------------------------------------------
#
# 【91】 ［テイクアウト］しょうが焼　おかずのみ
# 価格: 710
# カロリー: 422 kcal
# タンパク質: 18.0 g
# 脂質: 32.8 g
# 炭水化物: 15.1 g
# 糖質: 12.1 g
# 食物繊維: 3.0 g
# 食塩相当量: 3.5 g
# 画像: /files/menu_img/sp_394s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/394
# --------------------------------------------------------------------------------
#
# 【92】 ［テイクアウト］から揚げ　おかずのみ
# 価格: 740
# カロリー: 468 kcal
# タンパク質: 33.2 g
# 脂質: 28.4 g
# 炭水化物: 21.7 g
# 糖質: 18.1 g
# 食物繊維: 3.6 g
# 食塩相当量: 4.9 g
# 画像: /files/menu_img/sp_461s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/461
# --------------------------------------------------------------------------------
#
# 【93】 ［テイクアウト］特から揚げ　おかずのみ
# 価格: 930
# カロリー: 616 kcal
# タンパク質: 45.2 g
# 脂質: 37.2 g
# 炭水化物: 26.9 g
# 糖質: 22.9 g
# 食物繊維: 4.0 g
# 食塩相当量: 5.8 g
# 画像: /files/menu_img/sp_462s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/462
# --------------------------------------------------------------------------------
#
# 【94】 ［テイクアウト］から揚げ＆コロッケ　おかずのみ
# 価格: 740
# カロリー: 572 kcal
# タンパク質: 24.0 g
# 脂質: 37.4 g
# 炭水化物: 37.7 g
# 糖質: 33.6 g
# 食物繊維: 4.1 g
# 食塩相当量: 5.5 g
# 画像: /files/menu_img/sp_463s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/463
# --------------------------------------------------------------------------------
#
# 【95】 ［テイクアウト］チキン南蛮　おかずのみ
# 価格: 840
# カロリー: 711 kcal
# タンパク質: 20.5 g
# 脂質: 49.0 g
# 炭水化物: 47.7 g
# 糖質: 44.8 g
# 食物繊維: 2.9 g
# 食塩相当量: 4.5 g
# 画像: /files/menu_img/sp_464s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/464
# --------------------------------------------------------------------------------
#
# 【96】 ［テイクアウト］和風おろしハンバーグ　おかずのみ
# 価格: 830
# カロリー: 487 kcal
# タンパク質: 27.5 g
# 脂質: 25.5 g
# 炭水化物: 41.5 g
# 糖質: 33.4 g
# 食物繊維: 8.1 g
# 食塩相当量: 6.8 g
# 画像: /files/menu_img/sp_465s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/465
# --------------------------------------------------------------------------------
#
# 【97】 ［テイクアウト］サバの塩焼　おかずのみ
# 価格: 740
# カロリー: 486 kcal
# タンパク質: 26.4 g
# 脂質: 38.2 g
# 炭水化物: 10.7 g
# 糖質: 8.4 g
# 食物繊維: 2.3 g
# 食塩相当量: 3.8 g
# 画像: /files/menu_img/sp_395s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/395
# --------------------------------------------------------------------------------
#
# 【98】 ［テイクアウト］なす味噌と焼魚　おかずのみ
# 価格: 1000
# カロリー: 611 kcal
# タンパク質: 23.3 g
# 脂質: 47.9 g
# 炭水化物: 24.3 g
# 糖質: 19.2 g
# 食物繊維: 5.1 g
# 食塩相当量: 4.2 g
# 画像: /files/menu_img/sp_396s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/396
# --------------------------------------------------------------------------------
#
# 【99】 ［テイクアウト］ブラックアンガスビーフのカットステーキ　おかずのみ
# 価格: 1280
# カロリー: 424 kcal
# タンパク質: 31.6 g
# 脂質: 20.4 g
# 炭水化物: 30.3 g
# 糖質: 27.3 g
# 食物繊維: 3.0 g
# 食塩相当量: 5.1 g
# 画像: /files/menu_img/sp_466s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/466
# --------------------------------------------------------------------------------
#
# 【100】 ［テイクアウト］チキン南蛮としょうが焼の人気コンビ　おかずのみ
# 価格: 1090
# カロリー: 956 kcal
# タンパク質: 36.4 g
# 脂質: 66.9 g
# 炭水化物: 53.7 g
# 糖質: 50.1 g
# 食物繊維: 3.6 g
# 食塩相当量: 6.3 g
# 画像: /files/menu_img/sp_467s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/467
# --------------------------------------------------------------------------------
#
# 【101】 ［テイクアウト］ハンバーグとエビフライとから揚げの人気トリオ　おかずのみ
# 価格: 1090
# カロリー: 726 kcal
# タンパク質: 47.6 g
# 脂質: 41.7 g
# 炭水化物: 42.3 g
# 糖質: 36.2 g
# 食物繊維: 6.1 g
# 食塩相当量: 6.9 g
# 画像: /files/menu_img/sp_468s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/468
# --------------------------------------------------------------------------------
#
# 【102】 ［テイクアウト］地鶏親子丼～阿波尾鶏～
# 価格: 780
# カロリー: 666 kcal
# タンパク質: 34.3 g
# 脂質: 13.2 g
# 炭水化物: 106.0 g
# 糖質: 99.6 g
# 食物繊維: 6.4 g
# 食塩相当量: 3.9 g
# 画像: /files/menu_img/sp_470s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/470
# --------------------------------------------------------------------------------
#
# 【103】 ［テイクアウト］かつ丼
# 価格: 790
# カロリー: 840 kcal
# タンパク質: 35.3 g
# 脂質: 26.4 g
# 炭水化物: 118.7 g
# 糖質: 112.2 g
# 食物繊維: 6.5 g
# 食塩相当量: 4.6 g
# 画像: /files/menu_img/sp_469s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/469
# --------------------------------------------------------------------------------
#
# 【104】 ［テイクアウト］みそ汁
# 価格: 100
# カロリー: 24 kcal
# タンパク質: 1.8 g
# 脂質: 0.6 g
# 炭水化物: 3.2 g
# 糖質: 2.3 g
# 食物繊維: 0.9 g
# 食塩相当量: 1.8 g
# 画像: /files/menu_img/sp_121s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/121
# --------------------------------------------------------------------------------
#
# 【105】 ［テイクアウト］から揚げ（5個）
# 価格: 590
# カロリー: 442 kcal
# タンパク質: 30.2 g
# 脂質: 29.7 g
# 炭水化物: 14.9 g
# 糖質: 13.3 g
# 食物繊維: 1.6 g
# 食塩相当量: 2.2 g
# 画像: /files/menu_img/sp_471s.jpg?id=2314
# URL: https://www.yayoiken.com/menu_list/view/13/471
# --------------------------------------------------------------------------------
#
# 総メニュー数: 105件
# Data saved to yayoiken_menu_data.csv
# Data saved to yayoiken_menu_data.json
#
# スクレイピング完了！ 105 件のメニューデータを取得しました。
# 重複データは自動的に除去されました。
# 価格データから「円」「,」「"」が削除されました。
