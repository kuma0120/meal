# %%
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv
import os

# CSV保存先
filename = "hottomotto_products.csv"

# 栄養成分パース関数
def parse_nutrition(soup):
    nutrition = {
        "calorie": "N/A",
        "protein": "N/A", 
        "fat": "N/A",
        "carbohydrate": "N/A",
        "sugar": "N/A",
        "fiber": "N/A",
        "salt": "N/A",
    }
    
    # 普通盛り（is_showクラス）のタブから栄養成分を取得
    nutrition_selectors = [
        "li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item",
        "li.c-tab__cont-item.js-tab__cont.is_show div.c-table-type01 dl.c-table__item",
        "div.c-table-type01 dl.c-table__item",
        "dl.c-table__item"
    ]
    
    dls = []
    for selector in nutrition_selectors:
        dls = soup.select(selector)
        if dls:
            print(f"栄養成分を {len(dls)} 件発見 (セレクタ: {selector})")
            break
    
    if not dls:
        print("栄養成分が見つかりませんでした")
        return nutrition
    
    for dl in dls:
        dt_elem = dl.select_one("dt.c-table__head, dt")
        dd_elem = dl.select_one("dd.c-table__body, dd")
        
        if dt_elem and dd_elem:
            # dtからテキストを取得（spanタグ内の単位情報は除外）
            dt_text = dt_elem.get_text(strip=True)
            dd_text = dd_elem.get_text(strip=True)
            
            print(f"栄養成分項目: '{dt_text}' = '{dd_text}'")
            
            # 数値部分を抽出
            dd_clean = dd_text.strip()
            
            if "熱量" in dt_text:
                nutrition["calorie"] = dd_clean + "kcal"
            elif ("蛋白質" in dt_text or "蛋⽩質" in dt_text or 
                  "たんぱく質" in dt_text or "タンパク質" in dt_text):
                nutrition["protein"] = dd_clean + "g"
            elif "脂質" in dt_text:
                nutrition["fat"] = dd_clean + "g"
            elif ("炭水化物" in dt_text or "炭⽔化物" in dt_text):
                nutrition["carbohydrate"] = dd_clean + "g"
            elif "糖質" in dt_text:
                nutrition["sugar"] = dd_clean + "g"
            elif "食物繊維" in dt_text:
                nutrition["fiber"] = dd_clean + "g"
            elif ("食塩相当量" in dt_text or "⾷塩相当量" in dt_text or "塩分" in dt_text):
                nutrition["salt"] = dd_clean + "g"
    
    return nutrition

# 商品ページ取得
def scrape_hottomotto_product(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(response.text, "html.parser")
        
        # 商品名
        product_name = "N/A"
        title_selectors = [
            "h1.c-menu__title",
            "h1",
            ".c-menu__title", 
            ".product-title",
            "h2"
        ]
        
        for selector in title_selectors:
            title_tag = soup.select_one(selector)
            if title_tag:
                product_name = title_tag.get_text(strip=True)
                break
        
        # 価格
        price = "N/A"
        price_selectors = [
            ".c-menu__price",
            ".price",
            ".cost",
            "[class*='price']"
        ]
        
        for selector in price_selectors:
            price_tag = soup.select_one(selector)
            if price_tag:
                price_text = price_tag.get_text(strip=True)
                # 価格から余計な文字を除去し、円を付加
                price_clean = ''.join(filter(str.isdigit, price_text))
                if price_clean:
                    price = price_clean + "円"
                break
        
        # 画像URL
        picture_url = "N/A"
        img_selectors = [
            ".c-menu__pic img",
            ".product-image img",
            "img[src*='menu']",
            "img[src*='product']"
        ]
        
        for selector in img_selectors:
            img_tag = soup.select_one(selector)
            if img_tag and img_tag.get("src"):
                src = img_tag["src"]
                if src.startswith("http"):
                    picture_url = src
                else:
                    picture_url = urljoin("https://www.hottomotto.com", src)
                break
        
        # 栄養成分
        nutrients = parse_nutrition(soup)
        
        return {
            "product_name": product_name,
            "price": price, 
            "url": url,
            **nutrients,
        }
        
    except Exception as e:
        print(f"商品ページ取得エラー {url}: {e}")
        return None

# 一覧ページから商品URL取得
def get_product_urls(list_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        response = requests.get(list_url, headers=headers)
        response.encoding = response.apparent_encoding  
        soup = BeautifulSoup(response.text, "html.parser")
        
        urls = set()
        
        # 画像の構造に基づいて、商品へのリンクを検索
        # 複数のパターンを試す
        link_patterns = [
            "a[href*='/products/']",
            "a[href*='/menu/']", 
            "a[href*='/item/']",
            ".c-menu__item a",
            ".product-item a",
            "li a[href]"
        ]
        
        for pattern in link_patterns:
            links = soup.select(pattern)
            for link in links:
                href = link.get("href")
                if href and ("/products/" in href or "/menu/" in href or "/item/" in href):
                    full_url = urljoin("https://www.hottomotto.com", href)
                    urls.add(full_url)
        
        # デバッグ：リンクが見つからない場合
        if not urls:
            print("商品リンクが見つかりません。すべてのリンクを確認中...")
            all_links = soup.find_all('a', href=True)
            print(f"ページ内の全リンク数: {len(all_links)}")
            
            # 商品らしきリンクを探す
            for link in all_links:
                href = link.get('href', '')
                text = link.get_text(strip=True)
                if any(keyword in href.lower() for keyword in ['product', 'menu', 'item', 'donut']):
                    full_url = urljoin("https://www.hottomotto.com", href)
                    urls.add(full_url)
                    print(f"  見つかったリンク: {text} -> {full_url}")
        
        return list(urls)
        
    except Exception as e:
        print(f"一覧ページ取得エラー {list_url}: {e}")
        return []

# CSV保存
def save_to_csv(data, filename=filename):
    if not data:
        print("保存するデータがありません")
        return
        
    fieldnames = [
        "product_name", "price", "url",
        "calorie", "protein", "fat", "carbohydrate", "sugar", "fiber", "salt"
    ]
    
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)

# メイン実行
if __name__ == "__main__":
    # 商品一覧ページURL（画像で見えているページ）
    list_url = "https://www.hottomotto.com/menu_list/index/13"
    
    print(f"一覧ページを取得中: {list_url}")
    product_urls = get_product_urls(list_url)
    print(f"商品URL取得数: {len(product_urls)}")
    
    if not product_urls:
        print("商品URLが見つかりませんでした。URLやページ構造を確認してください。")
        exit(1)
    
    # 最初の数件のURLを表示
    print("\n取得した商品URL（最初の5件）:")
    for i, url in enumerate(product_urls[:5]):
        print(f"  {i+1}. {url}")
    
    # 各商品ページのデータを取得
    all_data = []
    failed_urls = []
    
    for i, url in enumerate(product_urls, 1):
        print(f"\n[{i}/{len(product_urls)}] 処理中: {url}")
        
        try:
            data = scrape_hottomotto_product(url)
            if data:
                all_data.append(data)
                print(f"✓ 成功: {data['product_name']} - {data['price']}")
            else:
                failed_urls.append(url)
                print(f"✗ データ取得失敗")
            
            # サーバー負荷軽減
            time.sleep(1)
            
        except Exception as e:
            failed_urls.append(url)
            print(f"✗ エラー: {e}")
    
    # 結果まとめ
    print(f"\n=== 結果 ===")
    print(f"成功: {len(all_data)} 件")
    print(f"失敗: {len(failed_urls)} 件")
    
    if failed_urls:
        print("\n失敗したURL:")
        for url in failed_urls[:5]:  # 最初の5件のみ表示
            print(f"  - {url}")
    
    # CSV保存
    if all_data:
        save_to_csv(all_data)
        print(f"\nCSV保存完了: {filename} ({len(all_data)}件)")
        
        # サンプルデータ表示
        print(f"\n=== サンプルデータ ===")
        for data in all_data[:3]:  # 最初の3件のみ表示
            print(f"商品名: {data['product_name']}")
            print(f"価格: {data['price']}")
            print(f"カロリー: {data['calorie']}")
            print(f"蛋白質: {data['protein']}")
            print(f"脂質: {data['fat']}")
            print(f"炭水化物: {data['carbohydrate']}")
            print(f"糖質: {data['sugar']}")
            print(f"食物繊維: {data['fiber']}")
            print(f"食塩相当量: {data['salt']}")
            print(f"URL: {data['url']}")
            print("-" * 50)
    else:
        print("保存するデータがありませんでした。")
# Out:
# 一覧ページを取得中: https://www.hottomotto.com/menu_list/index/13
# 商品リンクが見つかりません。すべてのリンクを確認中...
# ページ内の全リンク数: 150
#   見つかったリンク: 印刷用PDFのダウンロード -> https://www.hottomotto.com/menu_list/download_pamphlet/13/09kantouA_toukai_kansaiA.pdf?id=858
#   見つかったリンク: アレルギー -> https://www.hottomotto.com/menu_list/info/13
#   見つかったリンク: 栄養成分 -> https://www.hottomotto.com/menu_list/info/13#!/tab/eiyo
#   見つかったリンク: 原産国 -> https://www.hottomotto.com/menu_list/info/13#!/tab/origin
#   見つかったリンク: ふわっと香る炭火旨だれ焼鳥つくね重660円（税抜：612円） -> https://www.hottomotto.com/menu_list/view/13/1287
#   見つかったリンク: ふわっと香る炭火W旨だれ焼鳥つくね重(肉2倍)1,050円（税抜：973円） -> https://www.hottomotto.com/menu_list/view/13/1288
#   見つかったリンク: とろ～り絡まる温玉付き焼鳥つくね重730円（税抜：676円） -> https://www.hottomotto.com/menu_list/view/13/1289
#   見つかったリンク: とろ～り絡まる温玉付きW焼鳥つくね重(肉2倍)1,120円（税抜：1,038円） -> https://www.hottomotto.com/menu_list/view/13/1290
#   見つかったリンク: 野菜が摂れる！特製ナポリタン＆サラダ500円（税抜：463円） -> https://www.hottomotto.com/menu_list/view/13/1291
#   見つかったリンク: 野菜が摂れる！W特製ナポリタン＆サラダ(麺2倍)650円（税抜：602円） -> https://www.hottomotto.com/menu_list/view/13/1292
#   見つかったリンク: 大盛・小盛変更不可ボリューム満点！特製ナポリタン弁当550円（税抜：510円） -> https://www.hottomotto.com/menu_list/view/13/1293
#   見つかったリンク: 大盛・小盛変更不可ボリューム満点！W特製ナポリタン弁当(麺2倍)700円（税抜：649円） -> https://www.hottomotto.com/menu_list/view/13/1294
#   見つかったリンク: 大盛・小盛変更不可～もち麦ごはんのミニ弁当～もちミニ 海鮮天丼620円（税抜：575円） -> https://www.hottomotto.com/menu_list/view/13/1226
#   見つかったリンク: エビ2尾/イカ/カレイ/野菜3種海鮮天丼680円（税抜：630円） -> https://www.hottomotto.com/menu_list/view/13/1227
#   見つかったリンク: エビ2尾/イカ/カレイ/野菜3種海鮮天とじ丼730円（税抜：676円） -> https://www.hottomotto.com/menu_list/view/13/1228
#   見つかったリンク: 小盛りOKエビ2尾/イカ/カレイ/野菜3種海鮮天ぷら弁当740円（税抜：686円） -> https://www.hottomotto.com/menu_list/view/13/1229
#   見つかったリンク: エビ5尾/イカ/カレイ/野菜3種上・海鮮天丼890円（税抜：825円） -> https://www.hottomotto.com/menu_list/view/13/1230
#   見つかったリンク: 6種のスパイスと牛の旨味夏のよくばり牛カレー670円（税抜：621円） -> https://www.hottomotto.com/menu_list/view/13/1238
#   見つかったリンク: 6種のスパイスと牛の旨味夏のよくばり牛カレー(から揚)850円（税抜：788円） -> https://www.hottomotto.com/menu_list/view/13/1239
#   見つかったリンク: 6種のスパイスと牛の旨味夏のよくばり牛カレー(ロースカツ)890円（税抜：825円） -> https://www.hottomotto.com/menu_list/view/13/1240
#   見つかったリンク: 6種のスパイスと牛の旨味夏のよくばり牛カレー(チーズ)760円（税抜：704円） -> https://www.hottomotto.com/menu_list/view/13/1241
#   見つかったリンク: 温玉と絡めて大判牛焼きすき重(肉2枚)790円（税抜：732円） -> https://www.hottomotto.com/menu_list/view/13/1088
#   見つかったリンク: 温玉と絡めてW大判牛焼きすき重(肉4枚)1,230円（税抜：1,139円） -> https://www.hottomotto.com/menu_list/view/13/1089
#   見つかったリンク: 甘辛牛肉と楽しむ牛すきうな重(2切れ)940円（税抜：871円） -> https://www.hottomotto.com/menu_list/view/13/1103
#   見つかったリンク: 特製だれで味わううな重(3切れ)1,040円（税抜：963円） -> https://www.hottomotto.com/menu_list/view/13/1104
#   見つかったリンク: 贅沢おかずビーフカットステーキ重890円（税抜：825円） -> https://www.hottomotto.com/menu_list/view/13/878
#   見つかったリンク: 贅沢おかずWビーフカットステーキ重（肉2倍)1,500円（税抜：1,389円） -> https://www.hottomotto.com/menu_list/view/13/879
#   見つかったリンク: 野菜をプラス！サラダ＆ビーフカットステーキコンボ980円（税抜：908円） -> https://www.hottomotto.com/menu_list/view/13/880
#   見つかったリンク: 小盛りOK贅沢おかずビーフカットステーキ弁当960円（税抜：889円） -> https://www.hottomotto.com/menu_list/view/13/1250
#   見つかったリンク: ほっともっとイチオシ！のり弁当460円（税抜：426円） -> https://www.hottomotto.com/menu_list/view/13/971
#   見つかったリンク: 3種のフライ特のりタル弁当590円（税抜：547円） -> https://www.hottomotto.com/menu_list/view/13/972
#   見つかったリンク: おかず全部のせ！全部のせのりタル弁当650円（税抜：602円） -> https://www.hottomotto.com/menu_list/view/13/974
#   見つかったリンク: 再登場！BIGのりタル弁当(ナポリタン)740円（税抜：686円） -> https://www.hottomotto.com/menu_list/view/13/1232
#   見つかったリンク: 小盛りOK旨から揚4コ入り から揚弁当570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1255
#   見つかったリンク: 小盛りOK旨から揚6コ入り から揚弁当720円（税抜：667円） -> https://www.hottomotto.com/menu_list/view/13/1256
#   見つかったリンク: 小盛りOKおかずたっぷりしょうが焼き＆から揚弁当920円（税抜：852円） -> https://www.hottomotto.com/menu_list/view/13/1257
#   見つかったリンク: 小盛りOKおかずたっぷり牛焼肉＆から揚弁当970円（税抜：899円） -> https://www.hottomotto.com/menu_list/view/13/1258
#   見つかったリンク: 小盛りOK自慢の特製タルタルチキン南蛮弁当670円（税抜：621円） -> https://www.hottomotto.com/menu_list/view/13/1259
#   見つかったリンク: 小盛りOK甘酸っぱい×まろやか九州チキン南蛮弁当670円（税抜：621円） -> https://www.hottomotto.com/menu_list/view/13/1263
#   見つかったリンク: 小盛りOKザクザクジューシーおろしチキン竜田弁当670円（税抜：621円） -> https://www.hottomotto.com/menu_list/view/13/1268
#   見つかったリンク: 小盛りOKひろがるロースの旨味ロースとんかつ弁当680円（税抜：630円） -> https://www.hottomotto.com/menu_list/view/13/1274
#   見つかったリンク: 小盛りOK国産生姜香るしょうが焼き弁当670円（税抜：621円） -> https://www.hottomotto.com/menu_list/view/13/1264
#   見つかったリンク: 小盛りOK国産生姜香るWしょうが焼き弁当(肉２倍)990円（税抜：917円） -> https://www.hottomotto.com/menu_list/view/13/1265
#   見つかったリンク: 小盛りOKごま油香る牛焼肉弁当720円（税抜：667円） -> https://www.hottomotto.com/menu_list/view/13/1266
#   見つかったリンク: 小盛りOKごま油香るW牛焼肉弁当(肉２倍)1,070円（税抜：991円） -> https://www.hottomotto.com/menu_list/view/13/1267
#   見つかったリンク: 小盛りOK牛すじと野菜をじっくり煮込んだデミソースデミグラスハンバーグ弁当720円（税抜：667円） -> https://www.hottomotto.com/menu_list/view/13/1269
#   見つかったリンク: 小盛りOKたっぷり玉ねぎでさっぱり和風オニオンソースハンバーグ弁当720円（税抜：667円） -> https://www.hottomotto.com/menu_list/view/13/1270
#   見つかったリンク: 小盛りOKとろ～り濃厚チーズハンバーグ弁当800円（税抜：741円） -> https://www.hottomotto.com/menu_list/view/13/1271
#   見つかったリンク: 小盛りOKおかずたっぷりデミグラスハンバーグ＆から揚弁当950円（税抜：880円） -> https://www.hottomotto.com/menu_list/view/13/1272
#   見つかったリンク: 小盛りOKおかずたっぷり和風オニオンソースハンバーグ＆から揚弁当950円（税抜：880円） -> https://www.hottomotto.com/menu_list/view/13/1273
#   見つかったリンク: 小盛りOKおだしがしみるロースかつとじ弁当680円（税抜：630円） -> https://www.hottomotto.com/menu_list/view/13/1276
#   見つかったリンク: 小盛りOK～野菜たっぷり～肉野菜炒め弁当690円（税抜：639円） -> https://www.hottomotto.com/menu_list/view/13/1278
#   見つかったリンク: 甘辛だれがとろりとりめし弁当580円（税抜：538円） -> https://www.hottomotto.com/menu_list/view/13/1038
#   見つかったリンク: ふんわり親子丼570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1147
#   見つかったリンク: おだしがしみるロースかつ丼650円（税抜：602円） -> https://www.hottomotto.com/menu_list/view/13/1149
#   見つかったリンク: 23種のスパイス使用カレー590円（税抜：547円） -> https://www.hottomotto.com/menu_list/view/13/1132
#   見つかったリンク: 23種のスパイス使用ロースカツカレー810円（税抜：750円） -> https://www.hottomotto.com/menu_list/view/13/1133
#   見つかったリンク: 23種のスパイス使用から揚カレー770円（税抜：713円） -> https://www.hottomotto.com/menu_list/view/13/1134
#   見つかったリンク: 彩副菜と海の幸しゃけ弁当640円（税抜：593円） -> https://www.hottomotto.com/menu_list/view/13/970
#   見つかったリンク: 大盛・小盛変更不可～もち麦ごはんのミニ弁当～もちミニ®彩・豆腐ハンバーグ弁当560円（税抜：519円） -> https://www.hottomotto.com/menu_list/view/13/1124
#   見つかったリンク: 大盛・小盛変更不可～もち麦ごはんのミニ弁当～もちミニ®しゃけ弁当590円（税抜：547円） -> https://www.hottomotto.com/menu_list/view/13/1126
#   見つかったリンク: バラエティ豊かなおかず幕の内弁当690円（税抜：639円） -> https://www.hottomotto.com/menu_list/view/13/1280
#   見つかったリンク: ごちそう勢ぞろい！特撰幕の内弁当970円（税抜：899円） -> https://www.hottomotto.com/menu_list/view/13/1281
#   見つかったリンク: 大人のお子様ランチ洋風バラエティ弁当690円（税抜：639円） -> https://www.hottomotto.com/menu_list/view/13/1283
#   見つかったリンク: 大盛・小盛変更不可ドラえもんランチ/ドラミちゃんランチ(ふりかけ)520円（税抜：482円） -> https://www.hottomotto.com/menu_list/view/13/1064
#   見つかったリンク: 大盛・小盛変更不可ドラえもんランチ/ドラミちゃんランチ(カレー)520円（税抜：482円） -> https://www.hottomotto.com/menu_list/view/13/1065
#   見つかったリンク: エビ2尾/イカ/カレイ/野菜3種海鮮天ぷら　おかずのみ640円（税抜：593円） -> https://www.hottomotto.com/menu_list/view/13/1231
#   見つかったリンク: 6種のスパイスと牛の旨味夏のよくばり牛カレールー570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1242
#   見つかったリンク: 贅沢おかずビーフカットステーキ　おかずのみ860円（税抜：797円） -> https://www.hottomotto.com/menu_list/view/13/882
#   見つかったリンク: 旨から揚4コ入り から揚　おかずのみ470円（税抜：436円） -> https://www.hottomotto.com/menu_list/view/13/1044
#   見つかったリンク: 旨から揚6コ入り から揚　おかずのみ620円（税抜：575円） -> https://www.hottomotto.com/menu_list/view/13/1045
#   見つかったリンク: おかずたっぷりしょうが焼き＆から揚　おかずのみ820円（税抜：760円） -> https://www.hottomotto.com/menu_list/view/13/1046
#   見つかったリンク: おかずたっぷり牛焼肉＆から揚　おかずのみ870円（税抜：806円） -> https://www.hottomotto.com/menu_list/view/13/1047
#   見つかったリンク: 自慢の特製タルタルチキン南蛮　おかずのみ570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1164
#   見つかったリンク: 甘酸っぱい×まろやか九州チキン南蛮　おかずのみ570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1166
#   見つかったリンク: ザクザクジューシーおろしチキン竜田　おかずのみ570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1155
#   見つかったリンク: ひろがるロースの旨味ロースとんかつ　おかずのみ580円（税抜：538円） -> https://www.hottomotto.com/menu_list/view/13/1170
#   見つかったリンク: 国産生姜香るしょうが焼き　おかずのみ570円（税抜：528円） -> https://www.hottomotto.com/menu_list/view/13/1156
#   見つかったリンク: 国産生姜香るWしょうが焼き(肉２倍)　おかずのみ890円（税抜：825円） -> https://www.hottomotto.com/menu_list/view/13/1157
#   見つかったリンク: ごま油香る牛焼肉　おかずのみ620円（税抜：575円） -> https://www.hottomotto.com/menu_list/view/13/1158
#   見つかったリンク: ごま油香るW牛焼肉(肉２倍)　おかずのみ970円（税抜：899円） -> https://www.hottomotto.com/menu_list/view/13/1159
#   見つかったリンク: 牛すじと野菜をじっくり煮込んだデミソースデミグラスハンバーグ　おかずのみ620円（税抜：575円） -> https://www.hottomotto.com/menu_list/view/13/1160
#   見つかったリンク: たっぷり玉ねぎでさっぱり和風オニオンソースハンバーグ　おかずのみ620円（税抜：575円） -> https://www.hottomotto.com/menu_list/view/13/1161
#   見つかったリンク: とろ～り濃厚チーズハンバーグ　おかずのみ700円（税抜：649円） -> https://www.hottomotto.com/menu_list/view/13/1225
#   見つかったリンク: おかずたっぷりデミグラスハンバーグ＆から揚　おかずのみ850円（税抜：788円） -> https://www.hottomotto.com/menu_list/view/13/1048
#   見つかったリンク: おかずたっぷり和風オニオンソースハンバーグ＆から揚　おかずのみ850円（税抜：788円） -> https://www.hottomotto.com/menu_list/view/13/1049
#   見つかったリンク: おだしがしみるロースかつとじ　おかずのみ580円（税抜：538円） -> https://www.hottomotto.com/menu_list/view/13/1172
#   見つかったリンク: ～野菜たっぷり～肉野菜炒め　おかずのみ590円（税抜：547円） -> https://www.hottomotto.com/menu_list/view/13/1174
#   見つかったリンク: 23種のスパイス使用カレー　ルーのみ490円（税抜：454円） -> https://www.hottomotto.com/menu_list/view/13/1163
#   見つかったリンク: 8コ入りチキンBOX750円（税抜：695円） -> https://www.hottomotto.com/menu_list/view/13/1008
#   見つかったリンク: 12コ入りチキンBOX990円（税抜：917円） -> https://www.hottomotto.com/menu_list/view/13/1237
#   見つかったリンク: WチキンBOX （から揚＆手羽から揚）820円（税抜：760円） -> https://www.hottomotto.com/menu_list/view/13/1009
#   見つかったリンク: チキポテBOX650円（税抜：602円） -> https://www.hottomotto.com/menu_list/view/13/1010
#   見つかったリンク: フライドポテトBOX500円（税抜：463円） -> https://www.hottomotto.com/menu_list/view/13/1011
#   見つかったリンク: 大盛・小盛変更不可きのこごはん単品300円（税抜：278円） -> https://www.hottomotto.com/menu_list/view/13/1249
#   見つかったリンク: もうすぐ終了讃岐うどん麺使用ミニ冷やしわかめうどん150円（税抜：139円） -> https://www.hottomotto.com/menu_list/view/13/1096
#   見つかったリンク: 旨辛特製豚汁200円（税抜：186円） -> https://www.hottomotto.com/menu_list/view/13/1182
#   見つかったリンク: プラスから揚（2コ入り）210円（税抜：195円） -> https://www.hottomotto.com/menu_list/view/13/1041
#   見つかったリンク: ほっとチキン230円（税抜：213円） -> https://www.hottomotto.com/menu_list/view/13/1183
#   見つかったリンク: 手羽から揚(しお味)5本入り310円（税抜：288円） -> https://www.hottomotto.com/menu_list/view/13/1184
#   見つかったリンク: 手羽から揚(しお味)10本入り560円（税抜：519円） -> https://www.hottomotto.com/menu_list/view/13/1185
#   見つかったリンク: フライドポテト180円（税抜：167円） -> https://www.hottomotto.com/menu_list/view/13/1186
#   見つかったリンク: パリパリ春巻140円（税抜：130円） -> https://www.hottomotto.com/menu_list/view/13/1007
#   見つかったリンク: たっぷりグリーンサラダ170円（税抜：158円） -> https://www.hottomotto.com/menu_list/view/13/1187
#   見つかったリンク: 7品目のミックスサラダ190円（税抜：176円） -> https://www.hottomotto.com/menu_list/view/13/1188
#   見つかったリンク: ポテトサラダ(ツナ＆マカロニ入り)180円（税抜：167円） -> https://www.hottomotto.com/menu_list/view/13/1093
#   見つかったリンク: 6種具材のひじき煮180円（税抜：167円） -> https://www.hottomotto.com/menu_list/view/13/1094
#   見つかったリンク: さっぱりゆず大根180円（税抜：167円） -> https://www.hottomotto.com/menu_list/view/13/1095
#   見つかったリンク: 旨さやみつきキムチ130円（税抜：121円） -> https://www.hottomotto.com/menu_list/view/13/183
#   見つかったリンク: ライス単品(中)190円（税抜：176円） -> https://www.hottomotto.com/menu_list/view/13/1191
#   見つかったリンク: ミニわかめうどん150円（税抜：139円） -> https://www.hottomotto.com/menu_list/view/13/1190
#   見つかったリンク: 特製豚汁170円（税抜：158円） -> https://www.hottomotto.com/menu_list/view/13/1189
#   見つかったリンク: 豚汁160円（税抜：149円） -> https://www.hottomotto.com/menu_list/view/13/1196
#   見つかったリンク: わかめスープ150円（税抜：139円） -> https://www.hottomotto.com/menu_list/view/13/1192
#   見つかったリンク: たまごスープ150円（税抜：139円） -> https://www.hottomotto.com/menu_list/view/13/1193
#   見つかったリンク: しじみのみそ汁160円（税抜：149円） -> https://www.hottomotto.com/menu_list/view/13/1194
#   見つかったリンク: 海苔とあおさのみそ汁160円（税抜：149円） -> https://www.hottomotto.com/menu_list/view/13/1195
#   見つかったリンク: から揚110円（税抜：102円） -> https://www.hottomotto.com/menu_list/view/13/1040
#   見つかったリンク: メンチカツ100円（税抜：93円） -> https://www.hottomotto.com/menu_list/view/13/1197
#   見つかったリンク: 白身フライ150円（税抜：139円） -> https://www.hottomotto.com/menu_list/view/13/986
#   見つかったリンク: エビフライ110円（税抜：102円） -> https://www.hottomotto.com/menu_list/view/13/1198
#   見つかったリンク: ちくわ天80円（税抜：75円） -> https://www.hottomotto.com/menu_list/view/13/985
#   見つかったリンク: ～北口選手の好きなおかずがぎっしり～チキン南蛮スペシャルスポーツ弁当990円（税抜：917円） -> https://www.hottomotto.com/menu_list/view/13/1295
#   見つかったリンク: ～小田選手の好きなおかずがぎっしり～ハンバーグスペシャルスポーツ弁当990円（税抜：917円） -> https://www.hottomotto.com/menu_list/view/13/1296
#   見つかったリンク: オードブル2,200円（税抜：2,038円） -> https://www.hottomotto.com/menu_list/view/13/230
#   見つかったリンク: オードブル3,300円（税抜：3,056円） -> https://www.hottomotto.com/menu_list/view/13/231
#   見つかったリンク: オードブル5,500円（税抜：5,093円） -> https://www.hottomotto.com/menu_list/view/13/1078
#   見つかったリンク: ドラえもんプレート2,000円（税抜：1,852円） -> https://www.hottomotto.com/menu_list/view/13/1079
#   見つかったリンク: おつまみプレート1,600円（税抜：1,482円） -> https://www.hottomotto.com/menu_list/view/13/1080
#   見つかったリンク: 特注弁当　松1,600円（税抜：1,482円） -> https://www.hottomotto.com/menu_list/view/13/1199
#   見つかったリンク: 特注弁当　竹1,300円（税抜：1,204円） -> https://www.hottomotto.com/menu_list/view/13/1200
#   見つかったリンク: 特注弁当　梅1,000円（税抜：926円） -> https://www.hottomotto.com/menu_list/view/13/1201
#   見つかったリンク: ～環境に優しい紙容器～特注弁当1,100円（税抜：1,019円） -> https://www.hottomotto.com/menu_list/view/13/1202
#   見つかったリンク: おにぎりセット500円（税抜：463円） -> https://www.hottomotto.com/menu_list/view/13/1175
#   見つかったリンク: スポーツ弁当　しょうが焼き＆焼売680円（税抜：630円） -> https://www.hottomotto.com/menu_list/view/13/1203
#   見つかったリンク: スポーツ弁当　から揚＆デミメンチ680円（税抜：630円） -> https://www.hottomotto.com/menu_list/view/13/1204
#   見つかったリンク: スポーツ弁当　のり650円（税抜：602円） -> https://www.hottomotto.com/menu_list/view/13/1205
#   見つかったリンク: スポーツ弁当　バラエティ730円（税抜：676円） -> https://www.hottomotto.com/menu_list/view/13/1206
#   見つかったリンク: スポーツ弁当　12品目の幕の内730円（税抜：676円） -> https://www.hottomotto.com/menu_list/view/13/1207
#   見つかったリンク: ～BENTOバーガー～のり弁バーガー400円（税抜：371円） -> https://www.hottomotto.com/menu_list/view/13/891
#   見つかったリンク: ～BENTOバーガー～チキン南蛮バーガー450円（税抜：417円） -> https://www.hottomotto.com/menu_list/view/13/892
# 商品URL取得数: 141
#
# 取得した商品URL（最初の5件）:
#   1. https://www.hottomotto.com/menu_list/view/13/1007
#   2. https://www.hottomotto.com/menu_list/view/13/1182
#   3. https://www.hottomotto.com/menu_list/view/13/1064
#   4. https://www.hottomotto.com/menu_list/view/13/1288
#   5. https://www.hottomotto.com/menu_list/view/13/230
#
# [1/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1007
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '172'
# 栄養成分項目: '蛋⽩質（g）' = '2.6'
# 栄養成分項目: '脂質（g）' = '11.8'
# 栄養成分項目: '炭⽔化物（g）' = '14.6'
# 栄養成分項目: '糖質（g）' = '13.3'
# 栄養成分項目: '食物繊維（g）' = '1.3'
# 栄養成分項目: '⾷塩相当量（g）' = '0.6'
# 栄養成分項目: 'カリウム（mg）' = '53'
# 栄養成分項目: 'リン（mg）' = '31'
# ✓ 成功: パリパリ春巻 - 140円
#
# [2/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1182
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '85'
# 栄養成分項目: '蛋⽩質（g）' = '5.0'
# 栄養成分項目: '脂質（g）' = '2.9'
# 栄養成分項目: '炭⽔化物（g）' = '10.4'
# 栄養成分項目: '糖質（g）' = '8.6'
# 栄養成分項目: '食物繊維（g）' = '1.8'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '162'
# 栄養成分項目: 'リン（mg）' = '63'
# ✓ 成功: 旨辛特製豚汁 - 200円
#
# [3/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1064
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '415'
# 栄養成分項目: '蛋⽩質（g）' = '16.9'
# 栄養成分項目: '脂質（g）' = '16.7'
# 栄養成分項目: '炭⽔化物（g）' = '51.4'
# 栄養成分項目: '糖質（g）' = '47.2'
# 栄養成分項目: '食物繊維（g）' = '4.2'
# 栄養成分項目: '⾷塩相当量（g）' = '2.0'
# 栄養成分項目: 'カリウム（mg）' = '453'
# 栄養成分項目: 'リン（mg）' = '237'
# ✓ 成功: ドラえもんランチ/ドラミちゃんランチ(ふりかけ) - 520円
#
# [4/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1288
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '915'
# 栄養成分項目: '蛋⽩質（g）' = '49.5'
# 栄養成分項目: '脂質（g）' = '35.5'
# 栄養成分項目: '炭⽔化物（g）' = '103.2'
# 栄養成分項目: '糖質（g）' = '94.7'
# 栄養成分項目: '食物繊維（g）' = '8.5'
# 栄養成分項目: '⾷塩相当量（g）' = '6.3'
# 栄養成分項目: 'カリウム（mg）' = '802'
# 栄養成分項目: 'リン（mg）' = '469'
# ✓ 成功: W旨だれ焼鳥つくね重(肉2倍) - 1050円
#
# [5/141] 処理中: https://www.hottomotto.com/menu_list/view/13/230
# 栄養成分が見つかりませんでした
# ✓ 成功: オードブル - 2200円
#
# [6/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1126
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '487'
# 栄養成分項目: '蛋⽩質（g）' = '17.3'
# 栄養成分項目: '脂質（g）' = '12.7'
# 栄養成分項目: '炭⽔化物（g）' = '79.0'
# 栄養成分項目: '糖質（g）' = '73.1'
# 栄養成分項目: '食物繊維（g）' = '5.9'
# 栄養成分項目: '⾷塩相当量（g）' = '2.2'
# 栄養成分項目: 'カリウム（mg）' = '342'
# 栄養成分項目: 'リン（mg）' = '278'
# ✓ 成功: もちミニ®しゃけ弁当 - 590円
#
# [7/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1280
# 栄養成分が見つかりませんでした
# ✓ 成功: 幕の内弁当 - 690円
#
# [8/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1283
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '869'
# 栄養成分項目: '蛋⽩質（g）' = '27.1'
# 栄養成分項目: '脂質（g）' = '31.6'
# 栄養成分項目: '炭⽔化物（g）' = '123.2'
# 栄養成分項目: '糖質（g）' = '114.7'
# 栄養成分項目: '食物繊維（g）' = '8.5'
# 栄養成分項目: '⾷塩相当量（g）' = '4.6'
# 栄養成分項目: 'カリウム（mg）' = '604'
# 栄養成分項目: 'リン（mg）' = '336'
# ✓ 成功: 洋風バラエティ弁当 - 690円
#
# [9/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1264
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '701'
# 栄養成分項目: '蛋⽩質（g）' = '23.7'
# 栄養成分項目: '脂質（g）' = '23.9'
# 栄養成分項目: '炭⽔化物（g）' = '101.9'
# 栄養成分項目: '糖質（g）' = '93.9'
# 栄養成分項目: '食物繊維（g）' = '8.0'
# 栄養成分項目: '⾷塩相当量（g）' = '3.2'
# 栄養成分項目: 'カリウム（mg）' = '533'
# 栄養成分項目: 'リン（mg）' = '254'
# ✓ 成功: しょうが焼き弁当 - 670円
#
# [10/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1164
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '549'
# 栄養成分項目: '蛋⽩質（g）' = '21.4'
# 栄養成分項目: '脂質（g）' = '33.9'
# 栄養成分項目: '炭⽔化物（g）' = '38.9'
# 栄養成分項目: '糖質（g）' = '36.6'
# 栄養成分項目: '食物繊維（g）' = '2.3'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '440'
# 栄養成分項目: 'リン（mg）' = '295'
# ✓ 成功: チキン南蛮　おかずのみ - 570円
#
# [11/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1174
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '281'
# 栄養成分項目: '蛋⽩質（g）' = '16.7'
# 栄養成分項目: '脂質（g）' = '16.4'
# 栄養成分項目: '炭⽔化物（g）' = '19.5'
# 栄養成分項目: '糖質（g）' = '14.0'
# 栄養成分項目: '食物繊維（g）' = '5.5'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '820'
# 栄養成分項目: 'リン（mg）' = '200'
# ✓ 成功: 肉野菜炒め　おかずのみ - 590円
#
# [12/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1268
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '905'
# 栄養成分項目: '蛋⽩質（g）' = '22.7'
# 栄養成分項目: '脂質（g）' = '39.4'
# 栄養成分項目: '炭⽔化物（g）' = '117.7'
# 栄養成分項目: '糖質（g）' = '110.7'
# 栄養成分項目: '食物繊維（g）' = '7.0'
# 栄養成分項目: '⾷塩相当量（g）' = '3.7'
# 栄養成分項目: 'カリウム（mg）' = '496'
# 栄養成分項目: 'リン（mg）' = '246'
# ✓ 成功: おろしチキン竜田弁当 - 670円
#
# [13/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1292
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '770'
# 栄養成分項目: '蛋⽩質（g）' = '34.6'
# 栄養成分項目: '脂質（g）' = '29.1'
# 栄養成分項目: '炭⽔化物（g）' = '100.4'
# 栄養成分項目: '糖質（g）' = '88.7'
# 栄養成分項目: '食物繊維（g）' = '11.7'
# 栄養成分項目: '⾷塩相当量（g）' = '5.5'
# 栄養成分項目: 'カリウム（mg）' = '598'
# 栄養成分項目: 'リン（mg）' = '403'
# ✓ 成功: W特製ナポリタン＆サラダ(麺2倍) - 650円
#
# [14/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1187
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '54'
# 栄養成分項目: '蛋⽩質（g）' = '2.0'
# 栄養成分項目: '脂質（g）' = '3.5'
# 栄養成分項目: '炭⽔化物（g）' = '4.9'
# 栄養成分項目: '糖質（g）' = '3.2'
# 栄養成分項目: '食物繊維（g）' = '1.7'
# 栄養成分項目: '⾷塩相当量（g）' = '0.4'
# 栄養成分項目: 'カリウム（mg）' = '183'
# 栄養成分項目: 'リン（mg）' = '38'
# ✓ 成功: たっぷりグリーンサラダ - 170円
#
# [15/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1255
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '702'
# 栄養成分項目: '蛋⽩質（g）' = '30.2'
# 栄養成分項目: '脂質（g）' = '19.5'
# 栄養成分項目: '炭⽔化物（g）' = '101.5'
# 栄養成分項目: '糖質（g）' = '94.9'
# 栄養成分項目: '食物繊維（g）' = '6.6'
# 栄養成分項目: '⾷塩相当量（g）' = '3.0'
# 栄養成分項目: 'カリウム（mg）' = '532'
# 栄養成分項目: 'リン（mg）' = '336'
# ✓ 成功: 4コ入り から揚弁当 - 570円
#
# [16/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1093
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '70'
# 栄養成分項目: '蛋⽩質（g）' = '1.4'
# 栄養成分項目: '脂質（g）' = '3.9'
# 栄養成分項目: '炭⽔化物（g）' = '7.7'
# 栄養成分項目: '糖質（g）' = '7.1'
# 栄養成分項目: '食物繊維（g）' = '0.6'
# 栄養成分項目: '⾷塩相当量（g）' = '0.4'
# 栄養成分項目: 'カリウム（mg）' = '90'
# 栄養成分項目: 'リン（mg）' = '23'
# ✓ 成功: ポテトサラダ(ツナ＆マカロニ入り) - 180円
#
# [17/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1089
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '731'
# 栄養成分項目: '蛋⽩質（g）' = '36.4'
# 栄養成分項目: '脂質（g）' = '22.1'
# 栄養成分項目: '炭⽔化物（g）' = '99.2'
# 栄養成分項目: '糖質（g）' = '94.5'
# 栄養成分項目: '食物繊維（g）' = '4.7'
# 栄養成分項目: '⾷塩相当量（g）' = '5.1'
# 栄養成分項目: 'カリウム（mg）' = '502'
# 栄養成分項目: 'リン（mg）' = '363'
# ✓ 成功: W大判牛焼きすき重(肉4枚) - 1230円
#
# [18/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1293
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '751'
# 栄養成分項目: '蛋⽩質（g）' = '29.1'
# 栄養成分項目: '脂質（g）' = '23.0'
# 栄養成分項目: '炭⽔化物（g）' = '113.6'
# 栄養成分項目: '糖質（g）' = '104.5'
# 栄養成分項目: '食物繊維（g）' = '9.1'
# 栄養成分項目: '⾷塩相当量（g）' = '3.2'
# 栄養成分項目: 'カリウム（mg）' = '411'
# 栄養成分項目: 'リン（mg）' = '364'
# ✓ 成功: 特製ナポリタン弁当 - 550円
#
# [19/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1041
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '148'
# 栄養成分項目: '蛋⽩質（g）' = '12.0'
# 栄養成分項目: '脂質（g）' = '8.8'
# 栄養成分項目: '炭⽔化物（g）' = '5.2'
# 栄養成分項目: '糖質（g）' = '4.8'
# 栄養成分項目: '食物繊維（g）' = '0.4'
# 栄養成分項目: '⾷塩相当量（g）' = '0.8'
# 栄養成分項目: 'カリウム（mg）' = '198'
# 栄養成分項目: 'リン（mg）' = '118'
# ✓ 成功: プラスから揚（2コ入り） - 210円
#
# [20/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1276
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '810'
# 栄養成分項目: '蛋⽩質（g）' = '34.3'
# 栄養成分項目: '脂質（g）' = '26.0'
# 栄養成分項目: '炭⽔化物（g）' = '113.0'
# 栄養成分項目: '糖質（g）' = '106.3'
# 栄養成分項目: '食物繊維（g）' = '6.7'
# 栄養成分項目: '⾷塩相当量（g）' = '4.1'
# 栄養成分項目: 'カリウム（mg）' = '617'
# 栄養成分項目: 'リン（mg）' = '412'
# ✓ 成功: ロースかつとじ弁当 - 680円
#
# [21/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1289
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '702'
# 栄養成分項目: '蛋⽩質（g）' = '34.6'
# 栄養成分項目: '脂質（g）' = '23.7'
# 栄養成分項目: '炭⽔化物（g）' = '92.1'
# 栄養成分項目: '糖質（g）' = '85.3'
# 栄養成分項目: '食物繊維（g）' = '6.8'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '524'
# 栄養成分項目: 'リン（mg）' = '373'
# ✓ 成功: 温玉付き焼鳥つくね重 - 730円
#
# [22/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1103
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '693'
# 栄養成分項目: '蛋⽩質（g）' = '23.6'
# 栄養成分項目: '脂質（g）' = '23.8'
# 栄養成分項目: '炭⽔化物（g）' = '98.4'
# 栄養成分項目: '糖質（g）' = '94.0'
# 栄養成分項目: '食物繊維（g）' = '4.4'
# 栄養成分項目: '⾷塩相当量（g）' = '4.0'
# 栄養成分項目: 'カリウム（mg）' = '363'
# 栄養成分項目: 'リン（mg）' = '277'
# ✓ 成功: 牛すきうな重(2切れ) - 940円
#
# [23/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1104
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '601'
# 栄養成分項目: '蛋⽩質（g）' = '23.7'
# 栄養成分項目: '脂質（g）' = '17.3'
# 栄養成分項目: '炭⽔化物（g）' = '90.3'
# 栄養成分項目: '糖質（g）' = '85.0'
# 栄養成分項目: '食物繊維（g）' = '5.3'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '306'
# 栄養成分項目: 'リン（mg）' = '289'
# ✓ 成功: うな重(3切れ) - 1040円
#
# [24/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1272
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '833'
# 栄養成分項目: '蛋⽩質（g）' = '40.0'
# 栄養成分項目: '脂質（g）' = '27.4'
# 栄養成分項目: '炭⽔化物（g）' = '110.2'
# 栄養成分項目: '糖質（g）' = '102.2'
# 栄養成分項目: '食物繊維（g）' = '8.0'
# 栄養成分項目: '⾷塩相当量（g）' = '4.6'
# 栄養成分項目: 'カリウム（mg）' = '731'
# 栄養成分項目: 'リン（mg）' = '429'
# ✓ 成功: デミグラスハンバーグ＆から揚弁当 - 950円
#
# [25/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1170
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '489'
# 栄養成分項目: '蛋⽩質（g）' = '20.6'
# 栄養成分項目: '脂質（g）' = '26.8'
# 栄養成分項目: '炭⽔化物（g）' = '42.2'
# 栄養成分項目: '糖質（g）' = '39.6'
# 栄養成分項目: '食物繊維（g）' = '2.6'
# 栄養成分項目: '⾷塩相当量（g）' = '3.3'
# 栄養成分項目: 'カリウム（mg）' = '443'
# 栄養成分項目: 'リン（mg）' = '196'
# ✓ 成功: ロースとんかつ　おかずのみ - 580円
#
# [26/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1265
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '1007'
# 栄養成分項目: '蛋⽩質（g）' = '39.7'
# 栄養成分項目: '脂質（g）' = '45.6'
# 栄養成分項目: '炭⽔化物（g）' = '114.3'
# 栄養成分項目: '糖質（g）' = '104.9'
# 栄養成分項目: '食物繊維（g）' = '9.4'
# 栄養成分項目: '⾷塩相当量（g）' = '5.6'
# 栄養成分項目: 'カリウム（mg）' = '853'
# 栄養成分項目: 'リン（mg）' = '394'
# ✓ 成功: Wしょうが焼き弁当(肉２倍) - 990円
#
# [27/141] 処理中: https://www.hottomotto.com/menu_list/view/13/974
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '1006'
# 栄養成分項目: '蛋⽩質（g）' = '32.0'
# 栄養成分項目: '脂質（g）' = '40.2'
# 栄養成分項目: '炭⽔化物（g）' = '133.3'
# 栄養成分項目: '糖質（g）' = '124.6'
# 栄養成分項目: '食物繊維（g）' = '8.7'
# 栄養成分項目: '⾷塩相当量（g）' = '5.2'
# 栄養成分項目: 'カリウム（mg）' = '583'
# 栄養成分項目: 'リン（mg）' = '356'
# ✓ 成功: 全部のせのりタル弁当 - 650円
#
# [28/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1242
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '241'
# 栄養成分項目: '蛋⽩質（g）' = '7.4'
# 栄養成分項目: '脂質（g）' = '15.7'
# 栄養成分項目: '炭⽔化物（g）' = '17.8'
# 栄養成分項目: '糖質（g）' = '16.5'
# 栄養成分項目: '食物繊維（g）' = '1.3'
# 栄養成分項目: '⾷塩相当量（g）' = '1.9'
# 栄養成分項目: 'カリウム（mg）' = '168'
# 栄養成分項目: 'リン（mg）' = '72'
# ✓ 成功: 夏のよくばり牛カレールー - 570円
#
# [29/141] 処理中: https://www.hottomotto.com/menu_list/view/13/972
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '875'
# 栄養成分項目: '蛋⽩質（g）' = '28.1'
# 栄養成分項目: '脂質（g）' = '32.8'
# 栄養成分項目: '炭⽔化物（g）' = '120.9'
# 栄養成分項目: '糖質（g）' = '112.8'
# 栄養成分項目: '食物繊維（g）' = '8.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '545'
# 栄養成分項目: 'リン（mg）' = '317'
# ✓ 成功: 特のりタル弁当 - 590円
#
# [30/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1271
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '707'
# 栄養成分項目: '蛋⽩質（g）' = '24.6'
# 栄養成分項目: '脂質（g）' = '21.0'
# 栄養成分項目: '炭⽔化物（g）' = '109.9'
# 栄養成分項目: '糖質（g）' = '100.7'
# 栄養成分項目: '食物繊維（g）' = '9.2'
# 栄養成分項目: '⾷塩相当量（g）' = '3.7'
# 栄養成分項目: 'カリウム（mg）' = '633'
# 栄養成分項目: 'リン（mg）' = '366'
# ✓ 成功: チーズハンバーグ弁当 - 800円
#
# [31/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1156
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '365'
# 栄養成分項目: '蛋⽩質（g）' = '18.2'
# 栄養成分項目: '脂質（g）' = '23.4'
# 栄養成分項目: '炭⽔化物（g）' = '22.1'
# 栄養成分項目: '糖質（g）' = '18.7'
# 栄養成分項目: '食物繊維（g）' = '3.4'
# 栄養成分項目: '⾷塩相当量（g）' = '3.2'
# 栄養成分項目: 'カリウム（mg）' = '464'
# 栄養成分項目: 'リン（mg）' = '173'
# ✓ 成功: しょうが焼き　おかずのみ - 570円
#
# [32/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1259
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '885'
# 栄養成分項目: '蛋⽩質（g）' = '26.9'
# 栄養成分項目: '脂質（g）' = '34.4'
# 栄養成分項目: '炭⽔化物（g）' = '118.7'
# 栄養成分項目: '糖質（g）' = '111.8'
# 栄養成分項目: '食物繊維（g）' = '6.9'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '509'
# 栄養成分項目: 'リン（mg）' = '376'
# ✓ 成功: チキン南蛮弁当 - 670円
#
# [33/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1206
# 栄養成分が見つかりませんでした
# ✓ 成功: スポーツ弁当　バラエティ - 730円
#
# [34/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1047
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '582'
# 栄養成分項目: '蛋⽩質（g）' = '30.7'
# 栄養成分項目: '脂質（g）' = '38.7'
# 栄養成分項目: '炭⽔化物（g）' = '29.6'
# 栄養成分項目: '糖質（g）' = '25.1'
# 栄養成分項目: '食物繊維（g）' = '4.5'
# 栄養成分項目: '⾷塩相当量（g）' = '4.5'
# 栄養成分項目: 'カリウム（mg）' = '694'
# 栄養成分項目: 'リン（mg）' = '310'
# ✓ 成功: 牛焼肉＆から揚　おかずのみ - 870円
#
# [35/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1079
# 栄養成分が見つかりませんでした
# ✓ 成功: ドラえもんプレート - 2000円
#
# [36/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1045
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '514'
# 栄養成分項目: '蛋⽩質（g）' = '36.7'
# 栄養成分項目: '脂質（g）' = '27.8'
# 栄養成分項目: '炭⽔化物（g）' = '26.9'
# 栄養成分項目: '糖質（g）' = '24.5'
# 栄養成分項目: '食物繊維（g）' = '2.4'
# 栄養成分項目: '⾷塩相当量（g）' = '3.8'
# 栄養成分項目: 'カリウム（mg）' = '661'
# 栄養成分項目: 'リン（mg）' = '373'
# ✓ 成功: 6コ入り から揚　おかずのみ - 620円
#
# [37/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1010
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '692'
# 栄養成分項目: '蛋⽩質（g）' = '30.3'
# 栄養成分項目: '脂質（g）' = '37.0'
# 栄養成分項目: '炭⽔化物（g）' = '61.7'
# 栄養成分項目: '糖質（g）' = '55.9'
# 栄養成分項目: '食物繊維（g）' = '5.8'
# 栄養成分項目: '⾷塩相当量（g）' = '2.7'
# 栄養成分項目: 'カリウム（mg）' = '981'
# 栄養成分項目: 'リン（mg）' = '380'
# ✓ 成功: チキポテBOX - 650円
#
# [38/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1281
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '911'
# 栄養成分項目: '蛋⽩質（g）' = '36.6'
# 栄養成分項目: '脂質（g）' = '36.7'
# 栄養成分項目: '炭⽔化物（g）' = '112.6'
# 栄養成分項目: '糖質（g）' = '104.5'
# 栄養成分項目: '食物繊維（g）' = '8.1'
# 栄養成分項目: '⾷塩相当量（g）' = '5.0'
# 栄養成分項目: 'カリウム（mg）' = '665'
# 栄養成分項目: 'リン（mg）' = '485'
# ✓ 成功: 特撰幕の内弁当 - 970円
#
# [39/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1088
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '573'
# 栄養成分項目: '蛋⽩質（g）' = '24.3'
# 栄養成分項目: '脂質（g）' = '14.1'
# 栄養成分項目: '炭⽔化物（g）' = '89.7'
# 栄養成分項目: '糖質（g）' = '85.0'
# 栄養成分項目: '食物繊維（g）' = '4.7'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '322'
# 栄養成分項目: 'リン（mg）' = '269'
# ✓ 成功: 大判牛焼きすき重(肉2枚) - 790円
#
# [40/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1147
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '660'
# 栄養成分項目: '蛋⽩質（g）' = '30.1'
# 栄養成分項目: '脂質（g）' = '19.0'
# 栄養成分項目: '炭⽔化物（g）' = '95.1'
# 栄養成分項目: '糖質（g）' = '89.2'
# 栄養成分項目: '食物繊維（g）' = '5.9'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '526'
# 栄養成分項目: 'リン（mg）' = '283'
# ✓ 成功: 親子丼 - 570円
#
# [41/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1225
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '371'
# 栄養成分項目: '蛋⽩質（g）' = '19.1'
# 栄養成分項目: '脂質（g）' = '20.5'
# 栄養成分項目: '炭⽔化物（g）' = '30.1'
# 栄養成分項目: '糖質（g）' = '25.5'
# 栄養成分項目: '食物繊維（g）' = '4.6'
# 栄養成分項目: '⾷塩相当量（g）' = '3.7'
# 栄養成分項目: 'カリウム（mg）' = '564'
# 栄養成分項目: 'リン（mg）' = '285'
# ✓ 成功: チーズハンバーグ　おかずのみ - 700円
#
# [42/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1184
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '200'
# 栄養成分項目: '蛋⽩質（g）' = '13.2'
# 栄養成分項目: '脂質（g）' = '13.7'
# 栄養成分項目: '炭⽔化物（g）' = '5.9'
# 栄養成分項目: '糖質（g）' = '5.7'
# 栄養成分項目: '食物繊維（g）' = '0.2'
# 栄養成分項目: '⾷塩相当量（g）' = '1.6'
# 栄養成分項目: 'カリウム（mg）' = '67'
# 栄養成分項目: 'リン（mg）' = '170'
# ✓ 成功: 手羽から揚(しお味)5本入り - 310円
#
# [43/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1205
# 栄養成分が見つかりませんでした
# ✓ 成功: スポーツ弁当　のり - 650円
#
# [44/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1185
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '400'
# 栄養成分項目: '蛋⽩質（g）' = '26.4'
# 栄養成分項目: '脂質（g）' = '27.4'
# 栄養成分項目: '炭⽔化物（g）' = '11.8'
# 栄養成分項目: '糖質（g）' = '11.4'
# 栄養成分項目: '食物繊維（g）' = '0.4'
# 栄養成分項目: '⾷塩相当量（g）' = '3.2'
# 栄養成分項目: 'カリウム（mg）' = '134'
# 栄養成分項目: 'リン（mg）' = '340'
# ✓ 成功: 手羽から揚(しお味)10本入り - 560円
#
# [45/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1194
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '34'
# 栄養成分項目: '蛋⽩質（g）' = '2.4'
# 栄養成分項目: '脂質（g）' = '0.9'
# 栄養成分項目: '炭⽔化物（g）' = '3.9'
# 栄養成分項目: '糖質（g）' = '3.3'
# 栄養成分項目: '食物繊維（g）' = '0.6'
# 栄養成分項目: '⾷塩相当量（g）' = '2.1'
# 栄養成分項目: 'カリウム（mg）' = '75'
# 栄養成分項目: 'リン（mg）' = '37'
# ✓ 成功: しじみのみそ汁 - 160円
#
# [46/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1203
# 栄養成分が見つかりませんでした
# ✓ 成功: スポーツ弁当　しょうが焼き＆焼売 - 680円
#
# [47/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1161
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '355'
# 栄養成分項目: '蛋⽩質（g）' = '17.7'
# 栄養成分項目: '脂質（g）' = '15.3'
# 栄養成分項目: '炭⽔化物（g）' = '38.5'
# 栄養成分項目: '糖質（g）' = '34.0'
# 栄養成分項目: '食物繊維（g）' = '4.5'
# 栄養成分項目: '⾷塩相当量（g）' = '3.6'
# 栄養成分項目: 'カリウム（mg）' = '574'
# 栄養成分項目: 'リン（mg）' = '213'
# ✓ 成功: 和風オニオンソースハンバーグ　おかずのみ - 620円
#
# [48/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1232
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '1211'
# 栄養成分項目: '蛋⽩質（g）' = '40.0'
# 栄養成分項目: '脂質（g）' = '45.1'
# 栄養成分項目: '炭⽔化物（g）' = '169.4'
# 栄養成分項目: '糖質（g）' = '157.1'
# 栄養成分項目: '食物繊維（g）' = '12.3'
# 栄養成分項目: '⾷塩相当量（g）' = '6.5'
# 栄養成分項目: 'カリウム（mg）' = '587'
# 栄養成分項目: 'リン（mg）' = '483'
# ✓ 成功: BIGのりタル弁当(ナポリタン) - 740円
#
# [49/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1080
# 栄養成分が見つかりませんでした
# ✓ 成功: おつまみプレート - 1600円
#
# [50/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1133
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '842'
# 栄養成分項目: '蛋⽩質（g）' = '28.8'
# 栄養成分項目: '脂質（g）' = '28.5'
# 栄養成分項目: '炭⽔化物（g）' = '121.5'
# 栄養成分項目: '糖質（g）' = '113.5'
# 栄養成分項目: '食物繊維（g）' = '8.0'
# 栄養成分項目: '⾷塩相当量（g）' = '3.6'
# 栄養成分項目: 'カリウム（mg）' = '548'
# 栄養成分項目: 'リン（mg）' = '291'
# ✓ 成功: ロースカツカレー - 810円
#
# [51/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1270
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '691'
# 栄養成分項目: '蛋⽩質（g）' = '23.2'
# 栄養成分項目: '脂質（g）' = '15.8'
# 栄養成分項目: '炭⽔化物（g）' = '118.3'
# 栄養成分項目: '糖質（g）' = '109.2'
# 栄養成分項目: '食物繊維（g）' = '9.1'
# 栄養成分項目: '⾷塩相当量（g）' = '3.6'
# 栄養成分項目: 'カリウム（mg）' = '643'
# 栄養成分項目: 'リン（mg）' = '294'
# ✓ 成功: 和風オニオンソースハンバーグ弁当 - 720円
#
# [52/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1188
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '84'
# 栄養成分項目: '蛋⽩質（g）' = '2.9'
# 栄養成分項目: '脂質（g）' = '4.9'
# 栄養成分項目: '炭⽔化物（g）' = '9.0'
# 栄養成分項目: '糖質（g）' = '6.1'
# 栄養成分項目: '食物繊維（g）' = '2.9'
# 栄養成分項目: '⾷塩相当量（g）' = '0.7'
# 栄養成分項目: 'カリウム（mg）' = '240'
# 栄養成分項目: 'リン（mg）' = '54'
# ✓ 成功: 7品目のミックスサラダ - 190円
#
# [53/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1166
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '499'
# 栄養成分項目: '蛋⽩質（g）' = '18.6'
# 栄養成分項目: '脂質（g）' = '24.0'
# 栄養成分項目: '炭⽔化物（g）' = '49.7'
# 栄養成分項目: '糖質（g）' = '47.4'
# 栄養成分項目: '食物繊維（g）' = '2.3'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '422'
# 栄養成分項目: 'リン（mg）' = '274'
# ✓ 成功: 九州チキン南蛮　おかずのみ - 570円
#
# [54/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1241
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '670'
# 栄養成分項目: '蛋⽩質（g）' = '18.9'
# 栄養成分項目: '脂質（g）' = '23.2'
# 栄養成分項目: '炭⽔化物（g）' = '99.2'
# 栄養成分項目: '糖質（g）' = '93.1'
# 栄養成分項目: '食物繊維（g）' = '6.1'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '268'
# 栄養成分項目: 'リン（mg）' = '273'
# ✓ 成功: 夏のよくばり牛カレー(チーズ) - 760円
#
# [55/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1040
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '74'
# 栄養成分項目: '蛋⽩質（g）' = '6.0'
# 栄養成分項目: '脂質（g）' = '4.4'
# 栄養成分項目: '炭⽔化物（g）' = '2.6'
# 栄養成分項目: '糖質（g）' = '2.4'
# 栄養成分項目: '食物繊維（g）' = '0.2'
# 栄養成分項目: '⾷塩相当量（g）' = '0.4'
# 栄養成分項目: 'カリウム（mg）' = '99'
# 栄養成分項目: 'リン（mg）' = '59'
# ✓ 成功: から揚 - 110円
#
# [56/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1239
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '804'
# 栄養成分項目: '蛋⽩質（g）' = '31.0'
# 栄養成分項目: '脂質（g）' = '29.4'
# 栄養成分項目: '炭⽔化物（g）' = '106.6'
# 栄養成分項目: '糖質（g）' = '99.9'
# 栄養成分項目: '食物繊維（g）' = '6.7'
# 栄養成分項目: '⾷塩相当量（g）' = '3.5'
# 栄養成分項目: 'カリウム（mg）' = '548'
# 栄養成分項目: 'リン（mg）' = '335'
# ✓ 成功: 夏のよくばり牛カレー(から揚) - 850円
#
# [57/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1065
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '433'
# 栄養成分項目: '蛋⽩質（g）' = '17.8'
# 栄養成分項目: '脂質（g）' = '16.2'
# 栄養成分項目: '炭⽔化物（g）' = '56.1'
# 栄養成分項目: '糖質（g）' = '52.0'
# 栄養成分項目: '食物繊維（g）' = '4.1'
# 栄養成分項目: '⾷塩相当量（g）' = '2.3'
# 栄養成分項目: 'カリウム（mg）' = '472'
# 栄養成分項目: 'リン（mg）' = '234'
# ✓ 成功: ドラえもんランチ/ドラミちゃんランチ(カレー) - 520円
#
# [58/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1157
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '671'
# 栄養成分項目: '蛋⽩質（g）' = '34.2'
# 栄養成分項目: '脂質（g）' = '45.1'
# 栄養成分項目: '炭⽔化物（g）' = '34.5'
# 栄養成分項目: '糖質（g）' = '29.7'
# 栄養成分項目: '食物繊維（g）' = '4.8'
# 栄養成分項目: '⾷塩相当量（g）' = '5.6'
# 栄養成分項目: 'カリウム（mg）' = '784'
# 栄養成分項目: 'リン（mg）' = '313'
# ✓ 成功: Wしょうが焼き(肉２倍)　おかずのみ - 890円
#
# [59/141] 処理中: https://www.hottomotto.com/menu_list/info/13#!/tab/origin
# 栄養成分が見つかりませんでした
# ✓ 成功: 東京都のアレルギー・栄養成分・原産国情報 - N/A
#
# [60/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1124
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '512'
# 栄養成分項目: '蛋⽩質（g）' = '12.6'
# 栄養成分項目: '脂質（g）' = '14.7'
# 栄養成分項目: '炭⽔化物（g）' = '86.3'
# 栄養成分項目: '糖質（g）' = '78.8'
# 栄養成分項目: '食物繊維（g）' = '7.5'
# 栄養成分項目: '⾷塩相当量（g）' = '2.1'
# 栄養成分項目: 'カリウム（mg）' = '282'
# 栄養成分項目: 'リン（mg）' = '164'
# ✓ 成功: もちミニ®彩・豆腐ハンバーグ弁当 - 560円
#
# [61/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1195
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '42'
# 栄養成分項目: '蛋⽩質（g）' = '2.5'
# 栄養成分項目: '脂質（g）' = '1.0'
# 栄養成分項目: '炭⽔化物（g）' = '5.8'
# 栄養成分項目: '糖質（g）' = '4.1'
# 栄養成分項目: '食物繊維（g）' = '1.7'
# 栄養成分項目: '⾷塩相当量（g）' = '2.3'
# 栄養成分項目: 'カリウム（mg）' = '100'
# 栄養成分項目: 'リン（mg）' = '36'
# ✓ 成功: 海苔とあおさのみそ汁 - 160円
#
# [62/141] 処理中: https://www.hottomotto.com/menu_list/view/13/971
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '774'
# 栄養成分項目: '蛋⽩質（g）' = '22.8'
# 栄養成分項目: '脂質（g）' = '23.6'
# 栄養成分項目: '炭⽔化物（g）' = '117.6'
# 栄養成分項目: '糖質（g）' = '109.9'
# 栄養成分項目: '食物繊維（g）' = '7.7'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '368'
# 栄養成分項目: 'リン（mg）' = '247'
# ✓ 成功: のり弁当 - 460円
#
# [63/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1038
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '702'
# 栄養成分項目: '蛋⽩質（g）' = '27.0'
# 栄養成分項目: '脂質（g）' = '21.4'
# 栄養成分項目: '炭⽔化物（g）' = '103.3'
# 栄養成分項目: '糖質（g）' = '96.8'
# 栄養成分項目: '食物繊維（g）' = '6.5'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '483'
# 栄養成分項目: 'リン（mg）' = '304'
# ✓ 成功: とりめし弁当 - 580円
#
# [64/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1273
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '869'
# 栄養成分項目: '蛋⽩質（g）' = '40.0'
# 栄養成分項目: '脂質（g）' = '27.5'
# 栄養成分項目: '炭⽔化物（g）' = '119.0'
# 栄養成分項目: '糖質（g）' = '111.1'
# 栄養成分項目: '食物繊維（g）' = '7.9'
# 栄養成分項目: '⾷塩相当量（g）' = '5.4'
# 栄養成分項目: 'カリウム（mg）' = '761'
# 栄養成分項目: 'リン（mg）' = '439'
# ✓ 成功: 和風オニオンソースハンバーグ＆から揚弁当 - 950円
#
# [65/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1159
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '668'
# 栄養成分項目: '蛋⽩質（g）' = '23.6'
# 栄養成分項目: '脂質（g）' = '49.4'
# 栄養成分項目: '炭⽔化物（g）' = '34.8'
# 栄養成分項目: '糖質（g）' = '29.2'
# 栄養成分項目: '食物繊維（g）' = '5.6'
# 栄養成分項目: '⾷塩相当量（g）' = '5.5'
# 栄養成分項目: 'カリウム（mg）' = '604'
# 栄養成分項目: 'リン（mg）' = '233'
# ✓ 成功: W牛焼肉(肉２倍)　おかずのみ - 970円
#
# [66/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1237
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '892'
# 栄養成分項目: '蛋⽩質（g）' = '72.2'
# 栄養成分項目: '脂質（g）' = '52.8'
# 栄養成分項目: '炭⽔化物（g）' = '31.8'
# 栄養成分項目: '糖質（g）' = '29.4'
# 栄養成分項目: '食物繊維（g）' = '2.4'
# 栄養成分項目: '⾷塩相当量（g）' = '5.8'
# 栄養成分項目: 'カリウム（mg）' = '1196'
# 栄養成分項目: 'リン（mg）' = '708'
# ✓ 成功: 12コ入りチキンBOX - 990円
#
# [67/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1229
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '782'
# 栄養成分項目: '蛋⽩質（g）' = '19.3'
# 栄養成分項目: '脂質（g）' = '22.6'
# 栄養成分項目: '炭⽔化物（g）' = '128.9'
# 栄養成分項目: '糖質（g）' = '120.4'
# 栄養成分項目: '食物繊維（g）' = '8.5'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '373'
# 栄養成分項目: 'リン（mg）' = '312'
# ✓ 成功: 海鮮天ぷら弁当 - 740円
#
# [68/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1230
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '830'
# 栄養成分項目: '蛋⽩質（g）' = '22.8'
# 栄養成分項目: '脂質（g）' = '26.5'
# 栄養成分項目: '炭⽔化物（g）' = '128.5'
# 栄養成分項目: '糖質（g）' = '120.7'
# 栄養成分項目: '食物繊維（g）' = '7.8'
# 栄養成分項目: '⾷塩相当量（g）' = '3.3'
# 栄養成分項目: 'カリウム（mg）' = '344'
# 栄養成分項目: 'リン（mg）' = '367'
# ✓ 成功: 上・海鮮天丼 - 890円
#
# [69/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1191
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '336'
# 栄養成分項目: '蛋⽩質（g）' = '5.5'
# 栄養成分項目: '脂質（g）' = '0.5'
# 栄養成分項目: '炭⽔化物（g）' = '79.8'
# 栄養成分項目: '糖質（g）' = '75.2'
# 栄養成分項目: '食物繊維（g）' = '4.6'
# 栄養成分項目: '⾷塩相当量（g）' = '0.0'
# 栄養成分項目: 'カリウム（mg）' = '69'
# 栄養成分項目: 'リン（mg）' = '81'
# ✓ 成功: ライス単品(中) - 190円
#
# [70/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1291
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '539'
# 栄養成分項目: '蛋⽩質（g）' = '26.7'
# 栄養成分項目: '脂質（g）' = '26.0'
# 栄養成分項目: '炭⽔化物（g）' = '55.3'
# 栄養成分項目: '糖質（g）' = '48.4'
# 栄養成分項目: '食物繊維（g）' = '6.9'
# 栄養成分項目: '⾷塩相当量（g）' = '3.9'
# 栄養成分項目: 'カリウム（mg）' = '498'
# 栄養成分項目: 'リン（mg）' = '333'
# ✓ 成功: 特製ナポリタン＆サラダ - 500円
#
# [71/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1227
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '734'
# 栄養成分項目: '蛋⽩質（g）' = '18.0'
# 栄養成分項目: '脂質（g）' = '21.1'
# 栄養成分項目: '炭⽔化物（g）' = '121.3'
# 栄養成分項目: '糖質（g）' = '113.8'
# 栄養成分項目: '食物繊維（g）' = '7.5'
# 栄養成分項目: '⾷塩相当量（g）' = '2.9'
# 栄養成分項目: 'カリウム（mg）' = '320'
# 栄養成分項目: 'リン（mg）' = '295'
# ✓ 成功: 海鮮天丼 - 680円
#
# [72/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1256
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '850'
# 栄養成分項目: '蛋⽩質（g）' = '42.2'
# 栄養成分項目: '脂質（g）' = '28.3'
# 栄養成分項目: '炭⽔化物（g）' = '106.7'
# 栄養成分項目: '糖質（g）' = '99.7'
# 栄養成分項目: '食物繊維（g）' = '7.0'
# 栄養成分項目: '⾷塩相当量（g）' = '3.9'
# 栄養成分項目: 'カリウム（mg）' = '730'
# 栄養成分項目: 'リン（mg）' = '454'
# ✓ 成功: 6コ入り から揚弁当 - 720円
#
# [73/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1274
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '825'
# 栄養成分項目: '蛋⽩質（g）' = '26.1'
# 栄養成分項目: '脂質（g）' = '27.3'
# 栄養成分項目: '炭⽔化物（g）' = '122.0'
# 栄養成分項目: '糖質（g）' = '114.8'
# 栄養成分項目: '食物繊維（g）' = '7.2'
# 栄養成分項目: '⾷塩相当量（g）' = '3.3'
# 栄養成分項目: 'カリウム（mg）' = '512'
# 栄養成分項目: 'リン（mg）' = '277'
# ✓ 成功: ロースとんかつ弁当 - 680円
#
# [74/141] 処理中: https://www.hottomotto.com/menu_list/view/13/891
# 栄養成分が見つかりませんでした
# ✓ 成功: のり弁バーガー - 400円
#
# [75/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1228
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '843'
# 栄養成分項目: '蛋⽩質（g）' = '25.9'
# 栄養成分項目: '脂質（g）' = '26.6'
# 栄養成分項目: '炭⽔化物（g）' = '128.9'
# 栄養成分項目: '糖質（g）' = '121.6'
# 栄養成分項目: '食物繊維（g）' = '7.3'
# 栄養成分項目: '⾷塩相当量（g）' = '4.7'
# 栄養成分項目: 'カリウム（mg）' = '380'
# 栄養成分項目: 'リン（mg）' = '385'
# ✓ 成功: 海鮮天とじ丼 - 730円
#
# [76/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1096
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '139'
# 栄養成分項目: '蛋⽩質（g）' = '3.6'
# 栄養成分項目: '脂質（g）' = '1.0'
# 栄養成分項目: '炭⽔化物（g）' = '29.7'
# 栄養成分項目: '糖質（g）' = '27.8'
# 栄養成分項目: '食物繊維（g）' = '1.9'
# 栄養成分項目: '⾷塩相当量（g）' = '2.0'
# 栄養成分項目: 'カリウム（mg）' = '116'
# 栄養成分項目: 'リン（mg）' = '42'
# ✓ 成功: ミニ冷やしわかめうどん - 150円
#
# [77/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1172
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '474'
# 栄養成分項目: '蛋⽩質（g）' = '28.8'
# 栄養成分項目: '脂質（g）' = '25.5'
# 栄養成分項目: '炭⽔化物（g）' = '33.2'
# 栄養成分項目: '糖質（g）' = '31.1'
# 栄養成分項目: '食物繊維（g）' = '2.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.1'
# 栄養成分項目: 'カリウム（mg）' = '548'
# 栄養成分項目: 'リン（mg）' = '331'
# ✓ 成功: ロースかつとじ　おかずのみ - 580円
#
# [78/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1048
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '497'
# 栄養成分項目: '蛋⽩質（g）' = '34.5'
# 栄養成分項目: '脂質（g）' = '26.9'
# 栄養成分項目: '炭⽔化物（g）' = '30.4'
# 栄養成分項目: '糖質（g）' = '27.0'
# 栄養成分項目: '食物繊維（g）' = '3.4'
# 栄養成分項目: '⾷塩相当量（g）' = '4.6'
# 栄養成分項目: 'カリウム（mg）' = '662'
# 栄養成分項目: 'リン（mg）' = '348'
# ✓ 成功: デミグラスハンバーグ＆から揚　おかずのみ - 850円
#
# [79/141] 処理中: https://www.hottomotto.com/menu_list/view/13/879
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '802'
# 栄養成分項目: '蛋⽩質（g）' = '41.3'
# 栄養成分項目: '脂質（g）' = '24.4'
# 栄養成分項目: '炭⽔化物（g）' = '106.9'
# 栄養成分項目: '糖質（g）' = '99.9'
# 栄養成分項目: '食物繊維（g）' = '7.0'
# 栄養成分項目: '⾷塩相当量（g）' = '7.0'
# 栄養成分項目: 'カリウム（mg）' = '703'
# 栄養成分項目: 'リン（mg）' = '421'
# ✓ 成功: Wビーフカットステーキ重（肉2倍) - 1500円
#
# [80/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1201
# 栄養成分が見つかりませんでした
# ✓ 成功: 特注弁当　梅 - 1000円
#
# [81/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1278
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '617'
# 栄養成分項目: '蛋⽩質（g）' = '22.2'
# 栄養成分項目: '脂質（g）' = '16.9'
# 栄養成分項目: '炭⽔化物（g）' = '99.3'
# 栄養成分項目: '糖質（g）' = '89.2'
# 栄養成分項目: '食物繊維（g）' = '10.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '889'
# 栄養成分項目: 'リン（mg）' = '281'
# ✓ 成功: 肉野菜炒め弁当 - 690円
#
# [82/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1202
# 栄養成分が見つかりませんでした
# ✓ 成功: 特注弁当 - 1100円
#
# [83/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1263
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '835'
# 栄養成分項目: '蛋⽩質（g）' = '24.1'
# 栄養成分項目: '脂質（g）' = '24.5'
# 栄養成分項目: '炭⽔化物（g）' = '129.5'
# 栄養成分項目: '糖質（g）' = '122.6'
# 栄養成分項目: '食物繊維（g）' = '6.9'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '491'
# 栄養成分項目: 'リン（mg）' = '355'
# ✓ 成功: 九州チキン南蛮弁当 - 670円
#
# [84/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1155
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '569'
# 栄養成分項目: '蛋⽩質（g）' = '17.2'
# 栄養成分項目: '脂質（g）' = '38.9'
# 栄養成分項目: '炭⽔化物（g）' = '37.9'
# 栄養成分項目: '糖質（g）' = '35.5'
# 栄養成分項目: '食物繊維（g）' = '2.4'
# 栄養成分項目: '⾷塩相当量（g）' = '3.6'
# 栄養成分項目: 'カリウム（mg）' = '427'
# 栄養成分項目: 'リン（mg）' = '165'
# ✓ 成功: おろしチキン竜田　おかずのみ - 570円
#
# [85/141] 処理中: https://www.hottomotto.com/menu_list/view/13/970
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '624'
# 栄養成分項目: '蛋⽩質（g）' = '21.6'
# 栄養成分項目: '脂質（g）' = '16.5'
# 栄養成分項目: '炭⽔化物（g）' = '101.2'
# 栄養成分項目: '糖質（g）' = '94.1'
# 栄養成分項目: '食物繊維（g）' = '7.1'
# 栄養成分項目: '⾷塩相当量（g）' = '3.3'
# 栄養成分項目: 'カリウム（mg）' = '444'
# 栄養成分項目: 'リン（mg）' = '329'
# ✓ 成功: しゃけ弁当 - 640円
#
# [86/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1294
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '982'
# 栄養成分項目: '蛋⽩質（g）' = '37.0'
# 栄養成分項目: '脂質（g）' = '26.1'
# 栄養成分項目: '炭⽔化物（g）' = '158.7'
# 栄養成分項目: '糖質（g）' = '144.8'
# 栄養成分項目: '食物繊維（g）' = '13.9'
# 栄養成分項目: '⾷塩相当量（g）' = '4.7'
# 栄養成分項目: 'カリウム（mg）' = '511'
# 栄養成分項目: 'リン（mg）' = '434'
# ✓ 成功: W特製ナポリタン弁当(麺2倍) - 700円
#
# [87/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1296
# 栄養成分が見つかりませんでした
# ✓ 成功: ハンバーグスペシャルスポーツ弁当 - 990円
#
# [88/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1078
# 栄養成分が見つかりませんでした
# ✓ 成功: オードブル - 5500円
#
# [89/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1226
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '655'
# 栄養成分項目: '蛋⽩質（g）' = '15.9'
# 栄養成分項目: '脂質（g）' = '19.5'
# 栄養成分項目: '炭⽔化物（g）' = '107.3'
# 栄養成分項目: '糖質（g）' = '99.8'
# 栄養成分項目: '食物繊維（g）' = '7.5'
# 栄養成分項目: '⾷塩相当量（g）' = '2.7'
# 栄養成分項目: 'カリウム（mg）' = '311'
# 栄養成分項目: 'リン（mg）' = '272'
# ✓ 成功: もちミニ 海鮮天丼 - 620円
#
# [90/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1049
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '533'
# 栄養成分項目: '蛋⽩質（g）' = '34.5'
# 栄養成分項目: '脂質（g）' = '27.0'
# 栄養成分項目: '炭⽔化物（g）' = '39.2'
# 栄養成分項目: '糖質（g）' = '35.9'
# 栄養成分項目: '食物繊維（g）' = '3.3'
# 栄養成分項目: '⾷塩相当量（g）' = '5.4'
# 栄養成分項目: 'カリウム（mg）' = '692'
# 栄養成分項目: 'リン（mg）' = '358'
# ✓ 成功: 和風オニオンソースハンバーグ＆から揚　おかずのみ - 850円
#
# [91/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1238
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '582'
# 栄養成分項目: '蛋⽩質（g）' = '13.0'
# 栄養成分項目: '脂質（g）' = '16.2'
# 栄養成分項目: '炭⽔化物（g）' = '98.8'
# 栄養成分項目: '糖質（g）' = '92.7'
# 栄養成分項目: '食物繊維（g）' = '6.1'
# 栄養成分項目: '⾷塩相当量（g）' = '2.3'
# 栄養成分項目: 'カリウム（mg）' = '251'
# 栄養成分項目: 'リン（mg）' = '158'
# ✓ 成功: 夏のよくばり牛カレー - 670円
#
# [92/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1094
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '31'
# 栄養成分項目: '蛋⽩質（g）' = '1.6'
# 栄養成分項目: '脂質（g）' = '0.8'
# 栄養成分項目: '炭⽔化物（g）' = '5.2'
# 栄養成分項目: '糖質（g）' = '3.4'
# 栄養成分項目: '食物繊維（g）' = '1.8'
# 栄養成分項目: '⾷塩相当量（g）' = '0.6'
# 栄養成分項目: 'カリウム（mg）' = '59'
# 栄養成分項目: 'リン（mg）' = '23'
# ✓ 成功: 6種具材のひじき煮 - 180円
#
# [93/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1095
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '23'
# 栄養成分項目: '蛋⽩質（g）' = '0.3'
# 栄養成分項目: '脂質（g）' = '0.0'
# 栄養成分項目: '炭⽔化物（g）' = '5.8'
# ...
# 栄養成分項目: '脂質（g）' = '39.5'
# 栄養成分項目: '炭⽔化物（g）' = '20.2'
# 栄養成分項目: '糖質（g）' = '19.1'
# 栄養成分項目: '食物繊維（g）' = '1.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.9'
# 栄養成分項目: 'カリウム（mg）' = '508'
# 栄養成分項目: 'リン（mg）' = '508'
# ✓ 成功: WチキンBOX （から揚＆手羽から揚） - 820円
#
# [97/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1190
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '149'
# 栄養成分項目: '蛋⽩質（g）' = '3.8'
# 栄養成分項目: '脂質（g）' = '1.0'
# 栄養成分項目: '炭⽔化物（g）' = '31.3'
# 栄養成分項目: '糖質（g）' = '29.7'
# 栄養成分項目: '食物繊維（g）' = '1.6'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '168'
# 栄養成分項目: 'リン（mg）' = '40'
# ✓ 成功: ミニわかめうどん - 150円
#
# [98/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1193
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '31'
# 栄養成分項目: '蛋⽩質（g）' = '2.1'
# 栄養成分項目: '脂質（g）' = '1.5'
# 栄養成分項目: '炭⽔化物（g）' = '2.2'
# 栄養成分項目: '糖質（g）' = '0.0'
# 栄養成分項目: '食物繊維（g）' = '0.0'
# 栄養成分項目: '⾷塩相当量（g）' = '1.7'
# 栄養成分項目: 'カリウム（mg）' = '47'
# 栄養成分項目: 'リン（mg）' = '34'
# ✓ 成功: たまごスープ - 150円
#
# [99/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1160
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '319'
# 栄養成分項目: '蛋⽩質（g）' = '17.7'
# 栄養成分項目: '脂質（g）' = '15.2'
# 栄養成分項目: '炭⽔化物（g）' = '29.7'
# 栄養成分項目: '糖質（g）' = '25.1'
# 栄養成分項目: '食物繊維（g）' = '4.6'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '545'
# 栄養成分項目: 'リン（mg）' = '203'
# ✓ 成功: デミグラスハンバーグ　おかずのみ - 620円
#
# [100/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1258
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '918'
# 栄養成分項目: '蛋⽩質（g）' = '36.2'
# 栄養成分項目: '脂質（g）' = '39.2'
# 栄養成分項目: '炭⽔化物（g）' = '109.4'
# 栄養成分項目: '糖質（g）' = '100.3'
# 栄養成分項目: '食物繊維（g）' = '9.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.5'
# 栄養成分項目: 'カリウム（mg）' = '763'
# 栄養成分項目: 'リン（mg）' = '391'
# ✓ 成功: 牛焼肉＆から揚弁当 - 970円
#
# [101/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1269
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '655'
# 栄養成分項目: '蛋⽩質（g）' = '23.2'
# 栄養成分項目: '脂質（g）' = '15.7'
# 栄養成分項目: '炭⽔化物（g）' = '109.5'
# 栄養成分項目: '糖質（g）' = '100.3'
# 栄養成分項目: '食物繊維（g）' = '9.2'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '614'
# 栄養成分項目: 'リン（mg）' = '284'
# ✓ 成功: デミグラスハンバーグ弁当 - 720円
#
# [102/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1011
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '633'
# 栄養成分項目: '蛋⽩質（g）' = '9.9'
# 栄養成分項目: '脂質（g）' = '29.2'
# 栄養成分項目: '炭⽔化物（g）' = '87.5'
# 栄養成分項目: '糖質（g）' = '79.3'
# 栄養成分項目: '食物繊維（g）' = '8.2'
# 栄養成分項目: '⾷塩相当量（g）' = '1.9'
# 栄養成分項目: 'カリウム（mg）' = '1023'
# 栄養成分項目: 'リン（mg）' = '230'
# ✓ 成功: フライドポテトBOX - 500円
#
# [103/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1186
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '197'
# 栄養成分項目: '蛋⽩質（g）' = '3.1'
# 栄養成分項目: '脂質（g）' = '9.7'
# 栄養成分項目: '炭⽔化物（g）' = '25.5'
# 栄養成分項目: '糖質（g）' = '23.0'
# 栄養成分項目: '食物繊維（g）' = '2.5'
# 栄養成分項目: '⾷塩相当量（g）' = '0.5'
# 栄養成分項目: 'カリウム（mg）' = '291'
# 栄養成分項目: 'リン（mg）' = '72'
# ✓ 成功: フライドポテト - 180円
#
# [104/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1175
# 栄養成分が見つかりませんでした
# ✓ 成功: おにぎりセット - 500円
#
# [105/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1204
# 栄養成分が見つかりませんでした
# ✓ 成功: スポーツ弁当　から揚＆デミメンチ - 680円
#
# [106/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1287
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '628'
# 栄養成分項目: '蛋⽩質（g）' = '27.7'
# 栄養成分項目: '脂質（g）' = '18.0'
# 栄養成分項目: '炭⽔化物（g）' = '91.9'
# 栄養成分項目: '糖質（g）' = '85.1'
# 栄養成分項目: '食物繊維（g）' = '6.8'
# 栄養成分項目: '⾷塩相当量（g）' = '3.2'
# 栄養成分項目: 'カリウム（mg）' = '452'
# 栄養成分項目: 'リン（mg）' = '279'
# ✓ 成功: 旨だれ焼鳥つくね重 - 660円
#
# [107/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1257
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '942'
# 栄養成分項目: '蛋⽩質（g）' = '43.3'
# 栄養成分項目: '脂質（g）' = '35.8'
# 栄養成分項目: '炭⽔化物（g）' = '116.0'
# 栄養成分項目: '糖質（g）' = '107.0'
# 栄養成分項目: '食物繊維（g）' = '9.0'
# 栄養成分項目: '⾷塩相当量（g）' = '5.1'
# 栄養成分項目: 'カリウム（mg）' = '908'
# 栄養成分項目: 'リン（mg）' = '394'
# ✓ 成功: しょうが焼き＆から揚弁当 - 920円
#
# [108/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1231
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '446'
# 栄養成分項目: '蛋⽩質（g）' = '13.8'
# 栄養成分項目: '脂質（g）' = '22.1'
# 栄養成分項目: '炭⽔化物（g）' = '49.1'
# 栄養成分項目: '糖質（g）' = '45.2'
# 栄養成分項目: '食物繊維（g）' = '3.9'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '304'
# 栄養成分項目: 'リン（mg）' = '231'
# ✓ 成功: 海鮮天ぷら　おかずのみ - 640円
#
# [109/141] 処理中: https://www.hottomotto.com/menu_list/view/13/882
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '317'
# 栄養成分項目: '蛋⽩質（g）' = '20.8'
# 栄養成分項目: '脂質（g）' = '14.5'
# 栄養成分項目: '炭⽔化物（g）' = '27.2'
# 栄養成分項目: '糖質（g）' = '23.1'
# 栄養成分項目: '食物繊維（g）' = '4.1'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '579'
# 栄養成分項目: 'リン（mg）' = '220'
# ✓ 成功: ビーフカットステーキ　おかずのみ - 860円
#
# [110/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1158
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '371'
# 栄養成分項目: '蛋⽩質（g）' = '13.1'
# 栄養成分項目: '脂質（g）' = '25.6'
# 栄養成分項目: '炭⽔化物（g）' = '23.8'
# 栄養成分項目: '糖質（g）' = '20.0'
# 栄養成分項目: '食物繊維（g）' = '3.8'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '374'
# 栄養成分項目: 'リン（mg）' = '133'
# ✓ 成功: 牛焼肉　おかずのみ - 620円
#
# [111/141] 処理中: https://www.hottomotto.com/menu_list/view/13/985
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '133'
# 栄養成分項目: '蛋⽩質（g）' = '4.2'
# 栄養成分項目: '脂質（g）' = '7.4'
# 栄養成分項目: '炭⽔化物（g）' = '12.6'
# 栄養成分項目: '糖質（g）' = '12.0'
# 栄養成分項目: '食物繊維（g）' = '0.6'
# 栄養成分項目: '⾷塩相当量（g）' = '1.2'
# 栄養成分項目: 'カリウム（mg）' = '53'
# 栄養成分項目: 'リン（mg）' = '44'
# ✓ 成功: ちくわ天 - 80円
#
# [112/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1149
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '812'
# 栄養成分項目: '蛋⽩質（g）' = '34.3'
# 栄養成分項目: '脂質（g）' = '26.0'
# 栄養成分項目: '炭⽔化物（g）' = '113.6'
# 栄養成分項目: '糖質（g）' = '106.8'
# 栄養成分項目: '食物繊維（g）' = '6.8'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '624'
# 栄養成分項目: 'リン（mg）' = '414'
# ✓ 成功: ロースかつ丼 - 650円
#
# [113/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1134
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '681'
# 栄養成分項目: '蛋⽩質（g）' = '28.1'
# 栄養成分項目: '脂質（g）' = '17.1'
# 栄養成分項目: '炭⽔化物（g）' = '107.0'
# 栄養成分項目: '糖質（g）' = '99.7'
# 栄養成分項目: '食物繊維（g）' = '7.3'
# 栄養成分項目: '⾷塩相当量（g）' = '4.2'
# 栄養成分項目: 'カリウム（mg）' = '525'
# 栄養成分項目: 'リン（mg）' = '298'
# ✓ 成功: から揚カレー - 770円
#
# [114/141] 処理中: https://www.hottomotto.com/menu_list/view/13/880
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '603'
# 栄養成分項目: '蛋⽩質（g）' = '24.7'
# 栄養成分項目: '脂質（g）' = '15.1'
# 栄養成分項目: '炭⽔化物（g）' = '95.0'
# 栄養成分項目: '糖質（g）' = '88.2'
# 栄養成分項目: '食物繊維（g）' = '6.8'
# 栄養成分項目: '⾷塩相当量（g）' = '4.2'
# 栄養成分項目: 'カリウム（mg）' = '454'
# 栄養成分項目: 'リン（mg）' = '272'
# ✓ 成功: サラダ＆ビーフカットステーキコンボ - 980円
#
# [115/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1207
# 栄養成分が見つかりませんでした
# ✓ 成功: スポーツ弁当　12品目の幕の内 - 730円
#
# [116/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1044
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '366'
# 栄養成分項目: '蛋⽩質（g）' = '24.7'
# 栄養成分項目: '脂質（g）' = '19.0'
# 栄養成分項目: '炭⽔化物（g）' = '21.7'
# 栄養成分項目: '糖質（g）' = '19.7'
# 栄養成分項目: '食物繊維（g）' = '2.0'
# 栄養成分項目: '⾷塩相当量（g）' = '3.0'
# 栄養成分項目: 'カリウム（mg）' = '463'
# 栄養成分項目: 'リン（mg）' = '255'
# ✓ 成功: 4コ入り から揚　おかずのみ - 470円
#
# [117/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1200
# 栄養成分が見つかりませんでした
# ✓ 成功: 特注弁当　竹 - 1300円
#
# [118/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1196
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '81'
# 栄養成分項目: '蛋⽩質（g）' = '5.1'
# 栄養成分項目: '脂質（g）' = '2.3'
# 栄養成分項目: '炭⽔化物（g）' = '9.7'
# 栄養成分項目: '糖質（g）' = '0.0'
# 栄養成分項目: '食物繊維（g）' = '0.0'
# 栄養成分項目: '⾷塩相当量（g）' = '2.2'
# 栄養成分項目: 'カリウム（mg）' = '178'
# 栄養成分項目: 'リン（mg）' = '57'
# ✓ 成功: 豚汁 - 160円
#
# [119/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1267
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '1004'
# 栄養成分項目: '蛋⽩質（g）' = '29.1'
# 栄養成分項目: '脂質（g）' = '49.9'
# 栄養成分項目: '炭⽔化物（g）' = '114.6'
# 栄養成分項目: '糖質（g）' = '104.4'
# 栄養成分項目: '食物繊維（g）' = '10.2'
# 栄養成分項目: '⾷塩相当量（g）' = '5.5'
# 栄養成分項目: 'カリウム（mg）' = '673'
# 栄養成分項目: 'リン（mg）' = '314'
# ✓ 成功: W牛焼肉弁当(肉２倍) - 1070円
#
# [120/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1295
# 栄養成分が見つかりませんでした
# ✓ 成功: チキン南蛮スペシャルスポーツ弁当 - 990円
#
# [121/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1240
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '965'
# 栄養成分項目: '蛋⽩質（g）' = '31.7'
# 栄養成分項目: '脂質（g）' = '40.8'
# 栄養成分項目: '炭⽔化物（g）' = '121.1'
# 栄養成分項目: '糖質（g）' = '113.7'
# 栄養成分項目: '食物繊維（g）' = '7.4'
# 栄養成分項目: '⾷塩相当量（g）' = '2.9'
# 栄養成分項目: 'カリウム（mg）' = '571'
# 栄養成分項目: 'リン（mg）' = '328'
# ✓ 成功: 夏のよくばり牛カレー(ロースカツ) - 890円
#
# [122/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1199
# 栄養成分が見つかりませんでした
# ✓ 成功: 特注弁当　松 - 1600円
#
# [123/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1266
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '707'
# 栄養成分項目: '蛋⽩質（g）' = '18.6'
# 栄養成分項目: '脂質（g）' = '26.1'
# 栄養成分項目: '炭⽔化物（g）' = '103.6'
# 栄養成分項目: '糖質（g）' = '95.2'
# 栄養成分項目: '食物繊維（g）' = '8.4'
# 栄養成分項目: '⾷塩相当量（g）' = '3.4'
# 栄養成分項目: 'カリウム（mg）' = '443'
# 栄養成分項目: 'リン（mg）' = '214'
# ✓ 成功: 牛焼肉弁当 - 720円
#
# [124/141] 処理中: https://www.hottomotto.com/menu_list/view/13/878
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '590'
# 栄養成分項目: '蛋⽩質（g）' = '24.2'
# 栄養成分項目: '脂質（g）' = '13.3'
# 栄養成分項目: '炭⽔化物（g）' = '96.5'
# 栄養成分項目: '糖質（g）' = '89.9'
# 栄養成分項目: '食物繊維（g）' = '6.6'
# 栄養成分項目: '⾷塩相当量（g）' = '3.6'
# 栄養成分項目: 'カリウム（mg）' = '485'
# 栄養成分項目: 'リン（mg）' = '268'
# ✓ 成功: ビーフカットステーキ重 - 890円
#
# [125/141] 処理中: https://www.hottomotto.com/menu_list/view/13/231
# 栄養成分が見つかりませんでした
# ✓ 成功: オードブル - 3300円
#
# [126/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1046
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '606'
# 栄養成分項目: '蛋⽩質（g）' = '37.8'
# 栄養成分項目: '脂質（g）' = '35.3'
# 栄養成分項目: '炭⽔化物（g）' = '36.2'
# 栄養成分項目: '糖質（g）' = '31.8'
# 栄養成分項目: '食物繊維（g）' = '4.4'
# 栄養成分項目: '⾷塩相当量（g）' = '5.0'
# 栄養成分項目: 'カリウム（mg）' = '839'
# 栄養成分項目: 'リン（mg）' = '313'
# ✓ 成功: しょうが焼き＆から揚　おかずのみ - 820円
#
# [127/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1198
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '77'
# 栄養成分項目: '蛋⽩質（g）' = '2.1'
# 栄養成分項目: '脂質（g）' = '4.8'
# 栄養成分項目: '炭⽔化物（g）' = '6.4'
# 栄養成分項目: '糖質（g）' = '6.1'
# 栄養成分項目: '食物繊維（g）' = '0.3'
# 栄養成分項目: '⾷塩相当量（g）' = '0.6'
# 栄養成分項目: 'カリウム（mg）' = '42'
# 栄養成分項目: 'リン（mg）' = '35'
# ✓ 成功: エビフライ - 110円
#
# [128/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1290
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '989'
# 栄養成分項目: '蛋⽩質（g）' = '56.4'
# 栄養成分項目: '脂質（g）' = '41.2'
# 栄養成分項目: '炭⽔化物（g）' = '103.4'
# 栄養成分項目: '糖質（g）' = '94.9'
# 栄養成分項目: '食物繊維（g）' = '8.5'
# 栄養成分項目: '⾷塩相当量（g）' = '6.5'
# 栄養成分項目: 'カリウム（mg）' = '874'
# 栄養成分項目: 'リン（mg）' = '563'
# ✓ 成功: 温玉付きW焼鳥つくね重(肉2倍) - 1120円
#
# [129/141] 処理中: https://www.hottomotto.com/menu_list/download_pamphlet/13/09kantouA_toukai_kansaiA.pdf?id=858
# 栄養成分が見つかりませんでした
# ✓ 成功: N/A - N/A
#
# [130/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1189
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '61'
# 栄養成分項目: '蛋⽩質（g）' = '4.8'
# 栄養成分項目: '脂質（g）' = '1.4'
# 栄養成分項目: '炭⽔化物（g）' = '8.0'
# 栄養成分項目: '糖質（g）' = '6.4'
# 栄養成分項目: '食物繊維（g）' = '1.6'
# 栄養成分項目: '⾷塩相当量（g）' = '2.8'
# 栄養成分項目: 'カリウム（mg）' = '150'
# 栄養成分項目: 'リン（mg）' = '59'
# ✓ 成功: 特製豚汁 - 170円
#
# [131/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1192
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '35'
# 栄養成分項目: '蛋⽩質（g）' = '1.8'
# 栄養成分項目: '脂質（g）' = '1.3'
# 栄養成分項目: '炭⽔化物（g）' = '3.8'
# 栄養成分項目: '糖質（g）' = '0.0'
# 栄養成分項目: '食物繊維（g）' = '0.0'
# 栄養成分項目: '⾷塩相当量（g）' = '1.8'
# 栄養成分項目: 'カリウム（mg）' = '32'
# 栄養成分項目: 'リン（mg）' = '28'
# ✓ 成功: わかめスープ - 150円
#
# [132/141] 処理中: https://www.hottomotto.com/menu_list/info/13
# 栄養成分が見つかりませんでした
# ✓ 成功: 東京都のアレルギー・栄養成分・原産国情報 - N/A
#
# [133/141] 処理中: https://www.hottomotto.com/menu_list/view/13/986
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '226'
# 栄養成分項目: '蛋⽩質（g）' = '9.4'
# 栄養成分項目: '脂質（g）' = '12.1'
# 栄養成分項目: '炭⽔化物（g）' = '20.3'
# 栄養成分項目: '糖質（g）' = '19.4'
# 栄養成分項目: '食物繊維（g）' = '0.9'
# 栄養成分項目: '⾷塩相当量（g）' = '1.0'
# 栄養成分項目: 'カリウム（mg）' = '110'
# 栄養成分項目: 'リン（mg）' = '76'
# ✓ 成功: 白身フライ - 150円
#
# [134/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1249
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '337'
# 栄養成分項目: '蛋⽩質（g）' = '7.8'
# 栄養成分項目: '脂質（g）' = '4.2'
# 栄養成分項目: '炭⽔化物（g）' = '68.2'
# 栄養成分項目: '糖質（g）' = '65.9'
# 栄養成分項目: '食物繊維（g）' = '2.3'
# 栄養成分項目: '⾷塩相当量（g）' = '2.2'
# 栄養成分項目: 'カリウム（mg）' = '95'
# 栄養成分項目: 'リン（mg）' = '78'
# ✓ 成功: きのこごはん単品 - 300円
#
# [135/141] 処理中: https://www.hottomotto.com/menu_list/info/13#!/tab/eiyo
# 栄養成分が見つかりませんでした
# ✓ 成功: 東京都のアレルギー・栄養成分・原産国情報 - N/A
#
# [136/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1008
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '596'
# 栄養成分項目: '蛋⽩質（g）' = '48.2'
# 栄養成分項目: '脂質（g）' = '35.2'
# 栄養成分項目: '炭⽔化物（g）' = '21.4'
# 栄養成分項目: '糖質（g）' = '19.8'
# 栄養成分項目: '食物繊維（g）' = '1.6'
# 栄養成分項目: '⾷塩相当量（g）' = '4.2'
# 栄養成分項目: 'カリウム（mg）' = '800'
# 栄養成分項目: 'リン（mg）' = '472'
# ✓ 成功: 8コ入りチキンBOX - 750円
#
# [137/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1250
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '653'
# 栄養成分項目: '蛋⽩質（g）' = '26.3'
# 栄養成分項目: '脂質（g）' = '15.0'
# 栄養成分項目: '炭⽔化物（g）' = '107.0'
# 栄養成分項目: '糖質（g）' = '98.3'
# 栄養成分項目: '食物繊維（g）' = '8.7'
# 栄養成分項目: '⾷塩相当量（g）' = '4.3'
# 栄養成分項目: 'カリウム（mg）' = '648'
# 栄養成分項目: 'リン（mg）' = '301'
# ✓ 成功: ビーフカットステーキ弁当 - 960円
#
# [138/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1197
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '134'
# 栄養成分項目: '蛋⽩質（g）' = '4.3'
# 栄養成分項目: '脂質（g）' = '8.7'
# 栄養成分項目: '炭⽔化物（g）' = '10.0'
# 栄養成分項目: '糖質（g）' = '9.2'
# 栄養成分項目: '食物繊維（g）' = '0.8'
# 栄養成分項目: '⾷塩相当量（g）' = '1.0'
# 栄養成分項目: 'カリウム（mg）' = '111'
# 栄養成分項目: 'リン（mg）' = '44'
# ✓ 成功: メンチカツ - 100円
#
# [139/141] 処理中: https://www.hottomotto.com/menu_list/view/13/892
# 栄養成分が見つかりませんでした
# ✓ 成功: チキン南蛮バーガー - 450円
#
# [140/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1163
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '118'
# 栄養成分項目: '蛋⽩質（g）' = '4.6'
# 栄養成分項目: '脂質（g）' = '3.4'
# 栄養成分項目: '炭⽔化物（g）' = '18.3'
# 栄養成分項目: '糖質（g）' = '16.4'
# 栄養成分項目: '食物繊維（g）' = '1.9'
# 栄養成分項目: '⾷塩相当量（g）' = '2.6'
# 栄養成分項目: 'カリウム（mg）' = '146'
# 栄養成分項目: 'リン（mg）' = '35'
# ✓ 成功: カレー　ルーのみ - 490円
#
# [141/141] 処理中: https://www.hottomotto.com/menu_list/view/13/1132
# 栄養成分を 9 件発見 (セレクタ: li.c-tab__cont-item.is_show div.c-table-type01 dl.c-table__item)
# 栄養成分項目: '熱量（kcal）' = '468'
# 栄養成分項目: '蛋⽩質（g）' = '10.4'
# 栄養成分項目: '脂質（g）' = '3.9'
# 栄養成分項目: '炭⽔化物（g）' = '101.4'
# 栄養成分項目: '糖質（g）' = '94.5'
# 栄養成分項目: '食物繊維（g）' = '6.9'
# 栄養成分項目: '⾷塩相当量（g）' = '3.1'
# 栄養成分項目: 'カリウム（mg）' = '225'
# 栄養成分項目: 'リン（mg）' = '119'
# ✓ 成功: カレー - 590円
#
# === 結果 ===
# 成功: 141 件
# 失敗: 0 件
#
# CSV保存完了: hottomotto_products.csv (141件)
#
# === サンプルデータ ===
# 商品名: パリパリ春巻
# 価格: 140円
# カロリー: 172kcal
# 蛋白質: 2.6g
# 脂質: 11.8g
# 炭水化物: 14.6g
# 糖質: 13.3g
# 食物繊維: 1.3g
# 食塩相当量: 0.6g
# URL: https://www.hottomotto.com/menu_list/view/13/1007
# --------------------------------------------------
# 商品名: 旨辛特製豚汁
# 価格: 200円
# カロリー: 85kcal
# 蛋白質: 5.0g
# 脂質: 2.9g
# 炭水化物: 10.4g
# 糖質: 8.6g
# 食物繊維: 1.8g
# 食塩相当量: 3.4g
# URL: https://www.hottomotto.com/menu_list/view/13/1182
# --------------------------------------------------
# 商品名: ドラえもんランチ/ドラミちゃんランチ(ふりかけ)
# 価格: 520円
# カロリー: 415kcal
# 蛋白質: 16.9g
# 脂質: 16.7g
# 炭水化物: 51.4g
# 糖質: 47.2g
# 食物繊維: 4.2g
# 食塩相当量: 2.0g
# URL: https://www.hottomotto.com/menu_list/view/13/1064
# --------------------------------------------------
